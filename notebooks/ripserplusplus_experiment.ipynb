# %%
import ripserplusplus as rpp
import numpy as np

# %%
rpp.run("--format point-cloud",np.array([[3,2,1],[1,2,3]]))
# Out:
# {0: array([(0., 2.828427)], dtype=[('birth', '<f4'), ('death', '<f4')]),
#  1: array([], dtype=float64)}

# %%
#conda install -c conda-forge libstdcxx-ng importante para trabajar con ripserplusplus
