# %%
cd ..
# Out:
# /home/jorge/DocumentsWLS/Data_Science_Projects/Geospatial-similarity-combining-TDA-LLM-agents-and-MLOps-workflows

# %%
import pandas as pd
import geopandas as gpd
import json

# %%
df = pd.read_parquet("data/processed/cultivos/evaluacion_cultivos.parquet")
suelo = gpd.read_parquet("data/processed/suelo/suelo_merged.parquet")
df_similarity = pd.read_parquet("flask_app/results/similarity_matrix.parquet")
df_confidence = pd.read_parquet("flask_app/results/confianza_matrix.parquet")

# %%
cols_a_conservar = suelo.columns[[0, 3, 4]]  # 1, 4, 5 (índices 0-based)
cols_a_conservar = cols_a_conservar.append(suelo.columns[119:]) 
suelo = suelo[cols_a_conservar].dropna()

# %%
comunes = df['CVEGEO'].isin(suelo['CVEGEO'])
df = df[comunes]
suelo = suelo[suelo['CVEGEO'].isin(df['CVEGEO'])]

# %%
print(suelo.shape)
print(df.shape)
# Out:
# (2101, 34)
# (2101, 293)

# %%
import pandas as pd
import json

# Supongamos que tu DataFrame se llama df
# df = pd.read_csv("tu_archivo.csv") o ya lo tienes cargado

# Columnas fijas que quieres mantener siempre
fixed_columns = ["CVEGEO", "Idestado", "Idmunicipio"]

municipios_json = []

for _, row in df.iterrows():
    municipio_data = {col: row[col] for col in fixed_columns}
    
    # Solo agregar cultivos con valor > 0
    cultivos = {col: row[col] for col in df.columns if col not in fixed_columns and row[col] > 0}
    
    municipio_data["cultivos"] = cultivos
    municipios_json.append(municipio_data)
del municipio_data
# Convertimos a JSON
json_output_municipios = json.dumps(municipios_json, indent=2, ensure_ascii=False)

# %%
import pandas as pd
import json
from collections import defaultdict

# Columnas fijas
fixed_columns = ["CVEGEO", "Idestado", "Idmunicipio"]

# Diccionario para agrupar por cultivo
cultivos_dict = defaultdict(list)

for _, row in df.iterrows():
    for col in df.columns:
        if col not in fixed_columns and row[col] > 0:
            cultivos_dict[col].append({
                "CVEGEO": row["CVEGEO"],
                "Idestado": row["Idestado"],
                "Idmunicipio": row["Idmunicipio"],
                "valor": row[col]
            })

# Convertir a JSON
json_output_cultivos = json.dumps(cultivos_dict, indent=2, ensure_ascii=False)

# %%
import json
import numpy as np
# Suponiendo que json_output es un string JSON
municipios_data = json.loads(json_output_municipios)

# %%
json.load

# %%
def cultivos_comunes_mapeados(municipios_data, cvegeo1: str, cvegeo2: str) -> dict:
    """
    Devuelve los cultivos comunes entre dos municipios y sus valores, 
    usando un mapeo personalizado de valores a etiquetas.
    
    Args:
        municipios_data: lista de diccionarios de municipios.
        cvegeo1: CVEGEO del primer municipio.
        cvegeo2: CVEGEO del segundo municipio.
        mapeo: diccionario de valor numérico -> etiqueta.
    
    Returns:
        dict con cultivos comunes y valores mapeados.
    """
    mapeo = {
    1: 'Muy Malo',
    2: 'Malo',
    3: 'Regular',
    4: 'Bueno',
    5: 'Excelente'
    }
    # Buscar municipios
    m1 = next((m for m in municipios_data if m["CVEGEO"] == cvegeo1), None)
    m2 = next((m for m in municipios_data if m["CVEGEO"] == cvegeo2), None)
    
    if not m1 or not m2:
        return {"error": "Uno o ambos municipios no fueron encontrados."}
    
    cultivos1 = m1.get("cultivos", {})
    cultivos2 = m2.get("cultivos", {})
    
    comunes = set(cultivos1.keys()) & set(cultivos2.keys())
    
    if not comunes:
        return {"mensaje": f"No hay cultivos compartidos entre {cvegeo1} y {cvegeo2}."}
    
    resultado = {
        cultivo: {
            f"{cvegeo1}": f"{cultivos1[cultivo]} ({mapeo.get(cultivos1[cultivo], 'desconocido')})",
            f"{cvegeo2}": f"{cultivos2[cultivo]} ({mapeo.get(cultivos2[cultivo], 'desconocido')})",
            "diferencia": f"{abs(cultivos1[cultivo]-cultivos2[cultivo])}"
        }
        for cultivo in comunes
    }
    
    return resultado

def cultivos_comunes_df(municipios_data, cvegeo1: str, cvegeo2: str) -> pd.DataFrame:
    # Usamos tu función existente para obtener los cultivos comunes
    resultado = cultivos_comunes_mapeados(municipios_data, cvegeo1, cvegeo2)
    
    if "error" in resultado or "mensaje" in resultado:
        # Devuelve un DataFrame vacío si no hay resultados
        return pd.DataFrame()
    
    # Inicializar diccionario para filas
    data = {f"{cvegeo1}": {}, f"{cvegeo2}": {}, "diferencia": {}}
    
    for cultivo, valores in resultado.items():
        data[f"{cvegeo1}"][cultivo] = valores[f"{cvegeo1}"]
        data[f"{cvegeo2}"][cultivo] = valores[f"{cvegeo2}"]
        data["diferencia"][cultivo] =  np.float32(valores["diferencia"])
    
    # Crear DataFrame
    df = pd.DataFrame(data)
    
    return df

# Ejemplo de uso
df_comunes = cultivos_comunes_df(municipios_data, "01001", "01002")

# %%
df_comunes
# Out:
#                                     01001            01002  diferencia
# Alfalfa                       4.0 (Bueno)      4.0 (Bueno)         0.0
# Nopalitos                      2.0 (Malo)       2.0 (Malo)         0.0
# Tuna                       1.0 (Muy Malo)   1.0 (Muy Malo)         0.0
# Maíz forrajero en verde     3.0 (Regular)    3.0 (Regular)         0.0
# Brócoli                        2.0 (Malo)       2.0 (Malo)         0.0
# Chile verde                    2.0 (Malo)   1.0 (Muy Malo)         1.0
# Durazno                   5.0 (Excelente)  5.0 (Excelente)         0.0
# Frijol                     1.0 (Muy Malo)      4.0 (Bueno)         3.0
# Avena forrajera en verde    3.0 (Regular)    3.0 (Regular)         0.0
# Maíz grano                     2.0 (Malo)       2.0 (Malo)         0.0
# Tomate verde                   2.0 (Malo)    3.0 (Regular)         1.0
# Pastos y praderas              2.0 (Malo)    3.0 (Regular)         1.0
# Uva                         3.0 (Regular)      4.0 (Bueno)         1.0
# Tomate rojo (jitomate)      3.0 (Regular)       2.0 (Malo)         1.0

# %%
def obtener_nombres(df: pd.DataFrame, cvegeo1: str, cvegeo2: str) -> dict:
    suelo_df = df[['CVEGEO', 'NOMGEO', 'NOM_ENT']].copy()
    """
    Devuelve los valores de suelo para dos municipios dados sus CVEGEO.

    Args:
        suelo_df: DataFrame con columnas de suelo y 'CVEGEO'.
        cvegeo1: CVEGEO del primer municipio.
        cvegeo2: CVEGEO del segundo municipio.

    Returns:
        dict con la estructura:
        {
            "01001": {columna1: valor, columna2: valor, ...},
            "01002": {columna1: valor, columna2: valor, ...}
        }
        Si un CVEGEO no se encuentra, devuelve None en su lugar.
    """
    resultados = {}
    for cvegeo in [cvegeo1, cvegeo2]:
        fila = suelo_df[suelo_df['CVEGEO'] == cvegeo]
        if not fila.empty:
            # Convertimos la fila a diccionario de columna -> valor
            resultados[cvegeo] = fila.iloc[0].to_dict()
        else:
            resultados[cvegeo] = None
    return resultados

# %%
valores_suelo = obtener_nombres(suelo, "01001", "01002")
print(valores_suelo)
# Out:
# {'01001': {'CVEGEO': '01001', 'NOMGEO': 'Aguascalientes', 'NOM_ENT': 'Aguascalientes'}, '01002': {'CVEGEO': '01002', 'NOMGEO': 'Asientos', 'NOM_ENT': 'Aguascalientes'}}

# %%
def rename_df(df: pd.DataFrame, dictionary: dict):
    rename_dict = {}
    for col in df.columns:
        if col in dictionary:
            nombre = dictionary[col]["NOMGEO"] + ', ' + dictionary[col]["NOM_ENT"]
            rename_dict[col] = nombre
        else:
            rename_dict[col] = col  # deja el nombre original si no está en el diccionario
    df_renamed = df.rename(columns=rename_dict)
    return df_renamed

# %%
rename_df(df_comunes, valores_suelo)
# Out:
#                          Aguascalientes, Aguascalientes  \
# Alfalfa                                     4.0 (Bueno)
# Nopalitos                                    2.0 (Malo)
# Tuna                                     1.0 (Muy Malo)
# Maíz forrajero en verde                   3.0 (Regular)
# Brócoli                                      2.0 (Malo)
# Chile verde                                  2.0 (Malo)
# Durazno                                 5.0 (Excelente)
# Frijol                                   1.0 (Muy Malo)
# Avena forrajera en verde                  3.0 (Regular)
# Maíz grano                                   2.0 (Malo)
# Tomate verde                                 2.0 (Malo)
# Pastos y praderas                            2.0 (Malo)
# Uva                                       3.0 (Regular)
# Tomate rojo (jitomate)                    3.0 (Regular)
#
#                          Asientos, Aguascalientes  diferencia
# Alfalfa                               4.0 (Bueno)         0.0
# Nopalitos                              2.0 (Malo)         0.0
# Tuna                               1.0 (Muy Malo)         0.0
# Maíz forrajero en verde             3.0 (Regular)         0.0
# Brócoli                                2.0 (Malo)         0.0
# Chile verde                        1.0 (Muy Malo)         1.0
# Durazno                           5.0 (Excelente)         0.0
# Frijol                                4.0 (Bueno)         3.0
# Avena forrajera en verde            3.0 (Regular)         0.0
# Maíz grano                             2.0 (Malo)         0.0
# Tomate verde                        3.0 (Regular)         1.0
# Pastos y praderas                   3.0 (Regular)         1.0
# Uva                                   4.0 (Bueno)         1.0
# Tomate rojo (jitomate)                 2.0 (Malo)         1.0

# %% [markdown]
# # Si le preguntan sobre 01001 y 01002

# %%
from langchain.agents.middleware import SummarizationMiddleware
from langgraph.checkpoint.memory import InMemorySaver
from langchain_openai import ChatOpenAI
from langchain.agents import create_agent
from langchain.tools import tool

# %%
import json
import numpy as np
# Suponiendo que json_output es un string JSON
municipios_data = json.loads(json_output_municipios)
cultivo_data = json.loads(json_output_cultivos)

# %%
cultivo_data
# Out:
# {'Avena forrajera en verde': [{'CVEGEO': '01001',
#    'Idestado': 1,
#    'Idmunicipio': 1,
#    'valor': 3.0},
#   {'CVEGEO': '01002', 'Idestado': 1, 'Idmunicipio': 2, 'valor': 3.0},
#   {'CVEGEO': '01004', 'Idestado': 1, 'Idmunicipio': 4, 'valor': 3.0},
#   {'CVEGEO': '01005', 'Idestado': 1, 'Idmunicipio': 5, 'valor': 3.0},
#   {'CVEGEO': '01006', 'Idestado': 1, 'Idmunicipio': 6, 'valor': 3.0},
#   {'CVEGEO': '01007', 'Idestado': 1, 'Idmunicipio': 7, 'valor': 2.0},
#   {'CVEGEO': '01008', 'Idestado': 1, 'Idmunicipio': 8, 'valor': 1.0},
#   {'CVEGEO': '01009', 'Idestado': 1, 'Idmunicipio': 9, 'valor': 2.0},
#   {'CVEGEO': '01010', 'Idestado': 1, 'Idmunicipio': 10, 'valor': 2.0},
#   {'CVEGEO': '02001', 'Idestado': 2, 'Idmunicipio': 1, 'valor': 1.0},
#   {'CVEGEO': '02002', 'Idestado': 2, 'Idmunicipio': 2, 'valor': 5.0},
#   {'CVEGEO': '02003', 'Idestado': 2, 'Idmunicipio': 3, 'valor': 1.0},
#   {'CVEGEO': '02004', 'Idestado': 2, 'Idmunicipio': 4, 'valor': 1.0},
#   {'CVEGEO': '02005', 'Idestado': 2, 'Idmunicipio': 5, 'valor': 1.0},
#   {'CVEGEO': '05001', 'Idestado': 5, 'Idmunicipio': 1, 'valor': 3.0},
#   {'CVEGEO': '05002', 'Idestado': 5, 'Idmunicipio': 2, 'valor': 3.0},
#   {'CVEGEO': '05004', 'Idestado': 5, 'Idmunicipio': 4, 'valor': 3.0},
#   {'CVEGEO': '05005', 'Idestado': 5, 'Idmunicipio': 5, 'valor': 4.0},
#   {'CVEGEO': '05006', 'Idestado': 5, 'Idmunicipio': 6, 'valor': 1.0},
#   {'CVEGEO': '05007', 'Idestado': 5, 'Idmunicipio': 7, 'valor': 4.0},
#   {'CVEGEO': '05008', 'Idestado': 5, 'Idmunicipio': 8, 'valor': 3.0},
#   {'CVEGEO': '05009', 'Idestado': 5, 'Idmunicipio': 9, 'valor': 4.0},
#   {'CVEGEO': '05010', 'Idestado': 5, 'Idmunicipio': 10, 'valor': 4.0},
#   {'CVEGEO': '05011', 'Idestado': 5, 'Idmunicipio': 11, 'valor': 2.0},
#   {'CVEGEO': '05012', 'Idestado': 5, 'Idmunicipio': 12, 'valor': 3.0},
#   {'CVEGEO': '05013', 'Idestado': 5, 'Idmunicipio': 13, 'valor': 3.0},
#   {'CVEGEO': '05014', 'Idestado': 5, 'Idmunicipio': 14, 'valor': 3.0},
#   {'CVEGEO': '05015', 'Idestado': 5, 'Idmunicipio': 15, 'valor': 2.0},
#   {'CVEGEO': '05016', 'Idestado': 5, 'Idmunicipio': 16, 'valor': 3.0},
#   {'CVEGEO': '05018', 'Idestado': 5, 'Idmunicipio': 18, 'valor': 4.0},
#   {'CVEGEO': '05020', 'Idestado': 5, 'Idmunicipio': 20, 'valor': 2.0},
#   {'CVEGEO': '05021', 'Idestado': 5, 'Idmunicipio': 21, 'valor': 3.0},
#   {'CVEGEO': '05022', 'Idestado': 5, 'Idmunicipio': 22, 'valor': 3.0},
#   {'CVEGEO': '05023', 'Idestado': 5, 'Idmunicipio': 23, 'valor': 3.0},
#   {'CVEGEO': '05024', 'Idestado': 5, 'Idmunicipio': 24, 'valor': 2.0},
#   {'CVEGEO': '05025', 'Idestado': 5, 'Idmunicipio': 25, 'valor': 3.0},
#   {'CVEGEO': '05026', 'Idestado': 5, 'Idmunicipio': 26, 'valor': 2.0},
#   {'CVEGEO': '05027', 'Idestado': 5, 'Idmunicipio': 27, 'valor': 2.0},
#   {'CVEGEO': '05028', 'Idestado': 5, 'Idmunicipio': 28, 'valor': 3.0},
#   {'CVEGEO': '05029', 'Idestado': 5, 'Idmunicipio': 29, 'valor': 3.0},
#   {'CVEGEO': '05030', 'Idestado': 5, 'Idmunicipio': 30, 'valor': 2.0},
#   {'CVEGEO': '05031', 'Idestado': 5, 'Idmunicipio': 31, 'valor': 3.0},
#   {'CVEGEO': '05032', 'Idestado': 5, 'Idmunicipio': 32, 'valor': 2.0},
#   {'CVEGEO': '05033', 'Idestado': 5, 'Idmunicipio': 33, 'valor': 4.0},
#   {'CVEGEO': '05034', 'Idestado': 5, 'Idmunicipio': 34, 'valor': 3.0},
#   {'CVEGEO': '05035', 'Idestado': 5, 'Idmunicipio': 35, 'valor': 4.0},
#   {'CVEGEO': '05036', 'Idestado': 5, 'Idmunicipio': 36, 'valor': 3.0},
#   {'CVEGEO': '05037', 'Idestado': 5, 'Idmunicipio': 37, 'valor': 3.0},
#   {'CVEGEO': '05038', 'Idestado': 5, 'Idmunicipio': 38, 'valor': 3.0},
#   {'CVEGEO': '08001', 'Idestado': 8, 'Idmunicipio': 1, 'valor': 3.0},
#   {'CVEGEO': '08002', 'Idestado': 8, 'Idmunicipio': 2, 'valor': 3.0},
#   {'CVEGEO': '08003', 'Idestado': 8, 'Idmunicipio': 3, 'valor': 2.0},
#   {'CVEGEO': '08005', 'Idestado': 8, 'Idmunicipio': 5, 'valor': 3.0},
#   {'CVEGEO': '08006', 'Idestado': 8, 'Idmunicipio': 6, 'valor': 2.0},
#   {'CVEGEO': '08007', 'Idestado': 8, 'Idmunicipio': 7, 'valor': 2.0},
#   {'CVEGEO': '08008', 'Idestado': 8, 'Idmunicipio': 8, 'valor': 1.0},
#   {'CVEGEO': '08009', 'Idestado': 8, 'Idmunicipio': 9, 'valor': 1.0},
#   {'CVEGEO': '08010', 'Idestado': 8, 'Idmunicipio': 10, 'valor': 3.0},
#   {'CVEGEO': '08011', 'Idestado': 8, 'Idmunicipio': 11, 'valor': 4.0},
#   {'CVEGEO': '08012', 'Idestado': 8, 'Idmunicipio': 12, 'valor': 1.0},
#   {'CVEGEO': '08013', 'Idestado': 8, 'Idmunicipio': 13, 'valor': 1.0},
#   {'CVEGEO': '08014', 'Idestado': 8, 'Idmunicipio': 14, 'valor': 4.0},
#   {'CVEGEO': '08015', 'Idestado': 8, 'Idmunicipio': 15, 'valor': 3.0},
#   {'CVEGEO': '08016', 'Idestado': 8, 'Idmunicipio': 16, 'valor': 4.0},
#   {'CVEGEO': '08017', 'Idestado': 8, 'Idmunicipio': 17, 'valor': 2.0},
#   {'CVEGEO': '08018', 'Idestado': 8, 'Idmunicipio': 18, 'valor': 2.0},
#   {'CVEGEO': '08019', 'Idestado': 8, 'Idmunicipio': 19, 'valor': 2.0},
#   {'CVEGEO': '08020', 'Idestado': 8, 'Idmunicipio': 20, 'valor': 1.0},
#   {'CVEGEO': '08021', 'Idestado': 8, 'Idmunicipio': 21, 'valor': 4.0},
#   {'CVEGEO': '08022', 'Idestado': 8, 'Idmunicipio': 22, 'valor': 1.0},
#   {'CVEGEO': '08024', 'Idestado': 8, 'Idmunicipio': 24, 'valor': 1.0},
#   {'CVEGEO': '08025', 'Idestado': 8, 'Idmunicipio': 25, 'valor': 1.0},
#   {'CVEGEO': '08026', 'Idestado': 8, 'Idmunicipio': 26, 'valor': 2.0},
#   {'CVEGEO': '08028', 'Idestado': 8, 'Idmunicipio': 28, 'valor': 3.0},
#   {'CVEGEO': '08031', 'Idestado': 8, 'Idmunicipio': 31, 'valor': 1.0},
#   {'CVEGEO': '08032', 'Idestado': 8, 'Idmunicipio': 32, 'valor': 2.0},
#   {'CVEGEO': '08033', 'Idestado': 8, 'Idmunicipio': 33, 'valor': 2.0},
#   {'CVEGEO': '08034', 'Idestado': 8, 'Idmunicipio': 34, 'valor': 1.0},
#   {'CVEGEO': '08035', 'Idestado': 8, 'Idmunicipio': 35, 'valor': 2.0},
#   {'CVEGEO': '08036', 'Idestado': 8, 'Idmunicipio': 36, 'valor': 4.0},
#   {'CVEGEO': '08037', 'Idestado': 8, 'Idmunicipio': 37, 'valor': 3.0},
#   {'CVEGEO': '08038', 'Idestado': 8, 'Idmunicipio': 38, 'valor': 4.0},
#   {'CVEGEO': '08039', 'Idestado': 8, 'Idmunicipio': 39, 'valor': 4.0},
#   {'CVEGEO': '08040', 'Idestado': 8, 'Idmunicipio': 40, 'valor': 1.0},
#   {'CVEGEO': '08041', 'Idestado': 8, 'Idmunicipio': 41, 'valor': 1.0},
#   {'CVEGEO': '08042', 'Idestado': 8, 'Idmunicipio': 42, 'valor': 2.0},
#   {'CVEGEO': '08043', 'Idestado': 8, 'Idmunicipio': 43, 'valor': 1.0},
#   {'CVEGEO': '08044', 'Idestado': 8, 'Idmunicipio': 44, 'valor': 2.0},
#   {'CVEGEO': '08046', 'Idestado': 8, 'Idmunicipio': 46, 'valor': 1.0},
#   {'CVEGEO': '08047', 'Idestado': 8, 'Idmunicipio': 47, 'valor': 1.0},
#   {'CVEGEO': '08048', 'Idestado': 8, 'Idmunicipio': 48, 'valor': 1.0},
#   {'CVEGEO': '08049', 'Idestado': 8, 'Idmunicipio': 49, 'valor': 2.0},
#   {'CVEGEO': '08050', 'Idestado': 8, 'Idmunicipio': 50, 'valor': 3.0},
#   {'CVEGEO': '08051', 'Idestado': 8, 'Idmunicipio': 51, 'valor': 1.0},
#   {'CVEGEO': '08052', 'Idestado': 8, 'Idmunicipio': 52, 'valor': 3.0},
#   {'CVEGEO': '08053', 'Idestado': 8, 'Idmunicipio': 53, 'valor': 3.0},
#   {'CVEGEO': '08054', 'Idestado': 8, 'Idmunicipio': 54, 'valor': 2.0},
#   {'CVEGEO': '08055', 'Idestado': 8, 'Idmunicipio': 55, 'valor': 4.0},
#   {'CVEGEO': '08056', 'Idestado': 8, 'Idmunicipio': 56, 'valor': 2.0},
#   {'CVEGEO': '08057', 'Idestado': 8, 'Idmunicipio': 57, 'valor': 2.0},
#   {'CVEGEO': '08058', 'Idestado': 8, 'Idmunicipio': 58, 'valor': 4.0},
#   {'CVEGEO': '08059', 'Idestado': 8, 'Idmunicipio': 59, 'valor': 1.0},
#   {'CVEGEO': '08060', 'Idestado': 8, 'Idmunicipio': 60, 'valor': 2.0},
#   {'CVEGEO': '08061', 'Idestado': 8, 'Idmunicipio': 61, 'valor': 2.0},
#   {'CVEGEO': '08062', 'Idestado': 8, 'Idmunicipio': 62, 'valor': 4.0},
#   {'CVEGEO': '08063', 'Idestado': 8, 'Idmunicipio': 63, 'valor': 1.0},
#   {'CVEGEO': '08064', 'Idestado': 8, 'Idmunicipio': 64, 'valor': 2.0},
#   {'CVEGEO': '08065', 'Idestado': 8, 'Idmunicipio': 65, 'valor': 1.0},
#   {'CVEGEO': '08067', 'Idestado': 8, 'Idmunicipio': 67, 'valor': 3.0},
#   {'CVEGEO': '09004', 'Idestado': 9, 'Idmunicipio': 4, 'valor': 2.0},
#   {'CVEGEO': '09008', 'Idestado': 9, 'Idmunicipio': 8, 'valor': 2.0},
#   {'CVEGEO': '09009', 'Idestado': 9, 'Idmunicipio': 9, 'valor': 2.0},
#   {'CVEGEO': '09010', 'Idestado': 9, 'Idmunicipio': 10, 'valor': 2.0},
#   {'CVEGEO': '09011', 'Idestado': 9, 'Idmunicipio': 11, 'valor': 2.0},
#   {'CVEGEO': '09012', 'Idestado': 9, 'Idmunicipio': 12, 'valor': 3.0},
#   {'CVEGEO': '09013', 'Idestado': 9, 'Idmunicipio': 13, 'valor': 2.0},
#   {'CVEGEO': '10001', 'Idestado': 10, 'Idmunicipio': 1, 'valor': 1.0},
#   {'CVEGEO': '10002', 'Idestado': 10, 'Idmunicipio': 2, 'valor': 2.0},
#   {'CVEGEO': '10003', 'Idestado': 10, 'Idmunicipio': 3, 'valor': 2.0},
#   {'CVEGEO': '10004', 'Idestado': 10, 'Idmunicipio': 4, 'valor': 2.0},
#   {'CVEGEO': '10005', 'Idestado': 10, 'Idmunicipio': 5, 'valor': 2.0},
#   {'CVEGEO': '10006', 'Idestado': 10, 'Idmunicipio': 6, 'valor': 3.0},
#   {'CVEGEO': '10007', 'Idestado': 10, 'Idmunicipio': 7, 'valor': 4.0},
#   {'CVEGEO': '10008', 'Idestado': 10, 'Idmunicipio': 8, 'valor': 2.0},
#   {'CVEGEO': '10009', 'Idestado': 10, 'Idmunicipio': 9, 'valor': 2.0},
#   {'CVEGEO': '10010', 'Idestado': 10, 'Idmunicipio': 10, 'valor': 1.0},
#   {'CVEGEO': '10011', 'Idestado': 10, 'Idmunicipio': 11, 'valor': 1.0},
#   {'CVEGEO': '10012', 'Idestado': 10, 'Idmunicipio': 12, 'valor': 3.0},
#   {'CVEGEO': '10013', 'Idestado': 10, 'Idmunicipio': 13, 'valor': 3.0},
#   {'CVEGEO': '10014', 'Idestado': 10, 'Idmunicipio': 14, 'valor': 2.0},
#   {'CVEGEO': '10015', 'Idestado': 10, 'Idmunicipio': 15, 'valor': 3.0},
#   {'CVEGEO': '10016', 'Idestado': 10, 'Idmunicipio': 16, 'valor': 2.0},
#   {'CVEGEO': '10017', 'Idestado': 10, 'Idmunicipio': 17, 'valor': 1.0},
#   {'CVEGEO': '10018', 'Idestado': 10, 'Idmunicipio': 18, 'valor': 2.0},
#   {'CVEGEO': '10019', 'Idestado': 10, 'Idmunicipio': 19, 'valor': 1.0},
#   {'CVEGEO': '10020', 'Idestado': 10, 'Idmunicipio': 20, 'valor': 2.0},
#   {'CVEGEO': '10021', 'Idestado': 10, 'Idmunicipio': 21, 'valor': 2.0},
#   {'CVEGEO': '10022', 'Idestado': 10, 'Idmunicipio': 22, 'valor': 2.0},
#   {'CVEGEO': '10023', 'Idestado': 10, 'Idmunicipio': 23, 'valor': 2.0},
#   {'CVEGEO': '10024', 'Idestado': 10, 'Idmunicipio': 24, 'valor': 1.0},
#   {'CVEGEO': '10025', 'Idestado': 10, 'Idmunicipio': 25, 'valor': 1.0},
#   {'CVEGEO': '10026', 'Idestado': 10, 'Idmunicipio': 26, 'valor': 1.0},
#   {'CVEGEO': '10027', 'Idestado': 10, 'Idmunicipio': 27, 'valor': 3.0},
#   {'CVEGEO': '10028', 'Idestado': 10, 'Idmunicipio': 28, 'valor': 2.0},
#   {'CVEGEO': '10030', 'Idestado': 10, 'Idmunicipio': 30, 'valor': 2.0},
#   {'CVEGEO': '10031', 'Idestado': 10, 'Idmunicipio': 31, 'valor': 2.0},
#   {'CVEGEO': '10032', 'Idestado': 10, 'Idmunicipio': 32, 'valor': 1.0},
#   {'CVEGEO': '10033', 'Idestado': 10, 'Idmunicipio': 33, 'valor': 2.0},
#   {'CVEGEO': '10034', 'Idestado': 10, 'Idmunicipio': 34, 'valor': 2.0},
#   {'CVEGEO': '10035', 'Idestado': 10, 'Idmunicipio': 35, 'valor': 2.0},
#   {'CVEGEO': '10036', 'Idestado': 10, 'Idmunicipio': 36, 'valor': 5.0},
#   {'CVEGEO': '10037', 'Idestado': 10, 'Idmunicipio': 37, 'valor': 2.0},
#   {'CVEGEO': '10038', 'Idestado': 10, 'Idmunicipio': 38, 'valor': 2.0},
#   {'CVEGEO': '10039', 'Idestado': 10, 'Idmunicipio': 39, 'valor': 1.0},
#   {'CVEGEO': '11001', 'Idestado': 11, 'Idmunicipio': 1, 'valor': 4.0},
#   {'CVEGEO': '11002', 'Idestado': 11, 'Idmunicipio': 2, 'valor': 3.0},
#   {'CVEGEO': '11003', 'Idestado': 11, 'Idmunicipio': 3, 'valor': 2.0},
#   {'CVEGEO': '11004', 'Idestado': 11, 'Idmunicipio': 4, 'valor': 3.0},
#   {'CVEGEO': '11005', 'Idestado': 11, 'Idmunicipio': 5, 'valor': 3.0},
#   {'CVEGEO': '11007', 'Idestado': 11, 'Idmunicipio': 7, 'valor': 3.0},
#   {'CVEGEO': '11008', 'Idestado': 11, 'Idmunicipio': 8, 'valor': 3.0},
#   {'CVEGEO': '11010', 'Idestado': 11, 'Idmunicipio': 10, 'valor': 2.0},
#   {'CVEGEO': '11011', 'Idestado': 11, 'Idmunicipio': 11, 'valor': 4.0},
#   {'CVEGEO': '11012', 'Idestado': 11, 'Idmunicipio': 12, 'valor': 4.0},
#   {'CVEGEO': '11013', 'Idestado': 11, 'Idmunicipio': 13, 'valor': 3.0},
#   {'CVEGEO': '11014', 'Idestado': 11, 'Idmunicipio': 14, 'valor': 3.0},
#   {'CVEGEO': '11015', 'Idestado': 11, 'Idmunicipio': 15, 'valor': 4.0},
#   {'CVEGEO': '11016', 'Idestado': 11, 'Idmunicipio': 16, 'valor': 4.0},
#   {'CVEGEO': '11017', 'Idestado': 11, 'Idmunicipio': 17, 'valor': 4.0},
#   {'CVEGEO': '11018', 'Idestado': 11, 'Idmunicipio': 18, 'valor': 3.0},
#   {'CVEGEO': '11019', 'Idestado': 11, 'Idmunicipio': 19, 'valor': 2.0},
#   {'CVEGEO': '11020', 'Idestado': 11, 'Idmunicipio': 20, 'valor': 4.0},
#   {'CVEGEO': '11021', 'Idestado': 11, 'Idmunicipio': 21, 'valor': 3.0},
#   {'CVEGEO': '11022', 'Idestado': 11, 'Idmunicipio': 22, 'valor': 2.0},
#   {'CVEGEO': '11023', 'Idestado': 11, 'Idmunicipio': 23, 'valor': 4.0},
#   {'CVEGEO': '11024', 'Idestado': 11, 'Idmunicipio': 24, 'valor': 3.0},
#   {'CVEGEO': '11025', 'Idestado': 11, 'Idmunicipio': 25, 'valor': 3.0},
#   {'CVEGEO': '11026', 'Idestado': 11, 'Idmunicipio': 26, 'valor': 4.0},
#   {'CVEGEO': '11027', 'Idestado': 11, 'Idmunicipio': 27, 'valor': 4.0},
#   {'CVEGEO': '11028', 'Idestado': 11, 'Idmunicipio': 28, 'valor': 3.0},
#   {'CVEGEO': '11029', 'Idestado': 11, 'Idmunicipio': 29, 'valor': 3.0},
#   {'CVEGEO': '11030', 'Idestado': 11, 'Idmunicipio': 30, 'valor': 3.0},
#   {'CVEGEO': '11032', 'Idestado': 11, 'Idmunicipio': 32, 'valor': 3.0},
#   {'CVEGEO': '11033', 'Idestado': 11, 'Idmunicipio': 33, 'valor': 3.0},
#   {'CVEGEO': '11035', 'Idestado': 11, 'Idmunicipio': 35, 'valor': 3.0},
#   {'CVEGEO': '11037', 'Idestado': 11, 'Idmunicipio': 37, 'valor': 4.0},
#   {'CVEGEO': '11038', 'Idestado': 11, 'Idmunicipio': 38, 'valor': 3.0},
#   {'CVEGEO': '11039', 'Idestado': 11, 'Idmunicipio': 39, 'valor': 3.0},
#   {'CVEGEO': '11041', 'Idestado': 11, 'Idmunicipio': 41, 'valor': 2.0},
#   {'CVEGEO': '11042', 'Idestado': 11, 'Idmunicipio': 42, 'valor': 4.0},
#   {'CVEGEO': '11044', 'Idestado': 11, 'Idmunicipio': 44, 'valor': 3.0},
#   {'CVEGEO': '11046', 'Idestado': 11, 'Idmunicipio': 46, 'valor': 2.0},
#   {'CVEGEO': '12049', 'Idestado': 12, 'Idmunicipio': 49, 'valor': 2.0},
#   {'CVEGEO': '12055', 'Idestado': 12, 'Idmunicipio': 55, 'valor': 2.0},
#   {'CVEGEO': '13001', 'Idestado': 13, 'Idmunicipio': 1, 'valor': 2.0},
#   {'CVEGEO': '13002', 'Idestado': 13, 'Idmunicipio': 2, 'valor': 2.0},
#   {'CVEGEO': '13003', 'Idestado': 13, 'Idmunicipio': 3, 'valor': 4.0},
#   {'CVEGEO': '13006', 'Idestado': 13, 'Idmunicipio': 6, 'valor': 3.0},
#   {'CVEGEO': '13009', 'Idestado': 13, 'Idmunicipio': 9, 'valor': 4.0},
#   {'CVEGEO': '13012', 'Idestado': 13, 'Idmunicipio': 12, 'valor': 1.0},
#   {'CVEGEO': '13015', 'Idestado': 13, 'Idmunicipio': 15, 'valor': 4.0},
#   {'CVEGEO': '13016', 'Idestado': 13, 'Idmunicipio': 16, 'valor': 2.0},
#   {'CVEGEO': '13017', 'Idestado': 13, 'Idmunicipio': 17, 'valor': 2.0},
#   {'CVEGEO': '13019', 'Idestado': 13, 'Idmunicipio': 19, 'valor': 4.0},
#   {'CVEGEO': '13021', 'Idestado': 13, 'Idmunicipio': 21, 'valor': 1.0},
#   {'CVEGEO': '13023', 'Idestado': 13, 'Idmunicipio': 23, 'valor': 4.0},
#   {'CVEGEO': '13024', 'Idestado': 13, 'Idmunicipio': 24, 'valor': 1.0},
#   {'CVEGEO': '13029', 'Idestado': 13, 'Idmunicipio': 29, 'valor': 2.0},
#   {'CVEGEO': '13030', 'Idestado': 13, 'Idmunicipio': 30, 'valor': 4.0},
#   {'CVEGEO': '13035', 'Idestado': 13, 'Idmunicipio': 35, 'valor': 2.0},
#   {'CVEGEO': '13036', 'Idestado': 13, 'Idmunicipio': 36, 'valor': 1.0},
#   {'CVEGEO': '13037', 'Idestado': 13, 'Idmunicipio': 37, 'valor': 2.0},
#   {'CVEGEO': '13038', 'Idestado': 13, 'Idmunicipio': 38, 'valor': 1.0},
#   {'CVEGEO': '13039', 'Idestado': 13, 'Idmunicipio': 39, 'valor': 1.0},
#   {'CVEGEO': '13041', 'Idestado': 13, 'Idmunicipio': 41, 'valor': 4.0},
#   {'CVEGEO': '13044', 'Idestado': 13, 'Idmunicipio': 44, 'valor': 2.0},
#   {'CVEGEO': '13045', 'Idestado': 13, 'Idmunicipio': 45, 'valor': 1.0},
#   {'CVEGEO': '13047', 'Idestado': 13, 'Idmunicipio': 47, 'valor': 2.0},
#   {'CVEGEO': '13048', 'Idestado': 13, 'Idmunicipio': 48, 'valor': 1.0},
#   {'CVEGEO': '13050', 'Idestado': 13, 'Idmunicipio': 50, 'valor': 4.0},
#   {'CVEGEO': '13051', 'Idestado': 13, 'Idmunicipio': 51, 'valor': 2.0},
#   {'CVEGEO': '13054', 'Idestado': 13, 'Idmunicipio': 54, 'valor': 4.0},
#   {'CVEGEO': '13055', 'Idestado': 13, 'Idmunicipio': 55, 'valor': 4.0},
#   {'CVEGEO': '13056', 'Idestado': 13, 'Idmunicipio': 56, 'valor': 2.0},
#   {'CVEGEO': '13059', 'Idestado': 13, 'Idmunicipio': 59, 'valor': 2.0},
#   {'CVEGEO': '13064', 'Idestado': 13, 'Idmunicipio': 64, 'valor': 4.0},
#   {'CVEGEO': '13067', 'Idestado': 13, 'Idmunicipio': 67, 'valor': 4.0},
#   {'CVEGEO': '13069', 'Idestado': 13, 'Idmunicipio': 69, 'valor': 1.0},
#   {'CVEGEO': '13070', 'Idestado': 13, 'Idmunicipio': 70, 'valor': 5.0},
#   {'CVEGEO': '13076', 'Idestado': 13, 'Idmunicipio': 76, 'valor': 3.0},
#   {'CVEGEO': '13077', 'Idestado': 13, 'Idmunicipio': 77, 'valor': 2.0},
#   {'CVEGEO': '13081', 'Idestado': 13, 'Idmunicipio': 81, 'valor': 1.0},
#   {'CVEGEO': '13084', 'Idestado': 13, 'Idmunicipio': 84, 'valor': 2.0},
#   {'CVEGEO': '14001', 'Idestado': 14, 'Idmunicipio': 1, 'valor': 3.0},
#   {'CVEGEO': '14004', 'Idestado': 14, 'Idmunicipio': 4, 'valor': 3.0},
#   {'CVEGEO': '14008', 'Idestado': 14, 'Idmunicipio': 8, 'valor': 3.0},
#   {'CVEGEO': '14009', 'Idestado': 14, 'Idmunicipio': 9, 'valor': 2.0},
#   {'CVEGEO': '14010', 'Idestado': 14, 'Idmunicipio': 10, 'valor': 3.0},
#   {'CVEGEO': '14011', 'Idestado': 14, 'Idmunicipio': 11, 'valor': 3.0},
#   {'CVEGEO': '14012', 'Idestado': 14, 'Idmunicipio': 12, 'valor': 3.0},
#   {'CVEGEO': '14014', 'Idestado': 14, 'Idmunicipio': 14, 'valor': 3.0},
#   {'CVEGEO': '14016', 'Idestado': 14, 'Idmunicipio': 16, 'valor': 3.0},
#   {'CVEGEO': '14017', 'Idestado': 14, 'Idmunicipio': 17, 'valor': 4.0},
#   {'CVEGEO': '14018', 'Idestado': 14, 'Idmunicipio': 18, 'valor': 4.0},
#   {'CVEGEO': '14019', 'Idestado': 14, 'Idmunicipio': 19, 'valor': 3.0},
#   {'CVEGEO': '14025', 'Idestado': 14, 'Idmunicipio': 25, 'valor': 3.0},
#   {'CVEGEO': '14026', 'Idestado': 14, 'Idmunicipio': 26, 'valor': 3.0},
#   {'CVEGEO': '14028', 'Idestado': 14, 'Idmunicipio': 28, 'valor': 3.0},
#   {'CVEGEO': '14029', 'Idestado': 14, 'Idmunicipio': 29, 'valor': 3.0},
#   {'CVEGEO': '14030', 'Idestado': 14, 'Idmunicipio': 30, 'valor': 3.0},
#   {'CVEGEO': '14031', 'Idestado': 14, 'Idmunicipio': 31, 'valor': 3.0},
#   {'CVEGEO': '14032', 'Idestado': 14, 'Idmunicipio': 32, 'valor': 3.0},
#   {'CVEGEO': '14033', 'Idestado': 14, 'Idmunicipio': 33, 'valor': 5.0},
#   {'CVEGEO': '14035', 'Idestado': 14, 'Idmunicipio': 35, 'valor': 3.0},
#   {'CVEGEO': '14036', 'Idestado': 14, 'Idmunicipio': 36, 'valor': 3.0},
#   {'CVEGEO': '14038', 'Idestado': 14, 'Idmunicipio': 38, 'valor': 3.0},
#   {'CVEGEO': '14040', 'Idestado': 14, 'Idmunicipio': 40, 'valor': 4.0},
#   {'CVEGEO': '14041', 'Idestado': 14, 'Idmunicipio': 41, 'valor': 3.0},
#   {'CVEGEO': '14042', 'Idestado': 14, 'Idmunicipio': 42, 'valor': 3.0},
#   {'CVEGEO': '14044', 'Idestado': 14, 'Idmunicipio': 44, 'valor': 5.0},
#   {'CVEGEO': '14045', 'Idestado': 14, 'Idmunicipio': 45, 'valor': 3.0},
#   {'CVEGEO': '14047', 'Idestado': 14, 'Idmunicipio': 47, 'valor': 3.0},
#   {'CVEGEO': '14048', 'Idestado': 14, 'Idmunicipio': 48, 'valor': 3.0},
#   {'CVEGEO': '14051', 'Idestado': 14, 'Idmunicipio': 51, 'valor': 4.0},
#   {'CVEGEO': '14052', 'Idestado': 14, 'Idmunicipio': 52, 'valor': 2.0},
#   {'CVEGEO': '14053', 'Idestado': 14, 'Idmunicipio': 53, 'valor': 3.0},
#   {'CVEGEO': '14055', 'Idestado': 14, 'Idmunicipio': 55, 'valor': 3.0},
#   {'CVEGEO': '14057', 'Idestado': 14, 'Idmunicipio': 57, 'valor': 2.0},
#   {'CVEGEO': '14058', 'Idestado': 14, 'Idmunicipio': 58, 'valor': 3.0},
#   {'CVEGEO': '14059', 'Idestado': 14, 'Idmunicipio': 59, 'valor': 3.0},
#   {'CVEGEO': '14060', 'Idestado': 14, 'Idmunicipio': 60, 'valor': 3.0},
#   {'CVEGEO': '14061', 'Idestado': 14, 'Idmunicipio': 61, 'valor': 3.0},
#   {'CVEGEO': '14062', 'Idestado': 14, 'Idmunicipio': 62, 'valor': 3.0},
#   {'CVEGEO': '14064', 'Idestado': 14, 'Idmunicipio': 64, 'valor': 2.0},
#   {'CVEGEO': '14069', 'Idestado': 14, 'Idmunicipio': 69, 'valor': 3.0},
#   {'CVEGEO': '14070', 'Idestado': 14, 'Idmunicipio': 70, 'valor': 3.0},
#   {'CVEGEO': '14071', 'Idestado': 14, 'Idmunicipio': 71, 'valor': 3.0},
#   {'CVEGEO': '14072', 'Idestado': 14, 'Idmunicipio': 72, 'valor': 3.0},
#   {'CVEGEO': '14073', 'Idestado': 14, 'Idmunicipio': 73, 'valor': 3.0},
#   {'CVEGEO': '14074', 'Idestado': 14, 'Idmunicipio': 74, 'valor': 3.0},
#   {'CVEGEO': '14076', 'Idestado': 14, 'Idmunicipio': 76, 'valor': 3.0},
#   {'CVEGEO': '14078', 'Idestado': 14, 'Idmunicipio': 78, 'valor': 3.0},
#   {'CVEGEO': '14079', 'Idestado': 14, 'Idmunicipio': 79, 'valor': 3.0},
#   {'CVEGEO': '14081', 'Idestado': 14, 'Idmunicipio': 81, 'valor': 3.0},
#   {'CVEGEO': '14082', 'Idestado': 14, 'Idmunicipio': 82, 'valor': 3.0},
#   {'CVEGEO': '14083', 'Idestado': 14, 'Idmunicipio': 83, 'valor': 2.0},
#   {'CVEGEO': '14084', 'Idestado': 14, 'Idmunicipio': 84, 'valor': 3.0},
#   {'CVEGEO': '14086', 'Idestado': 14, 'Idmunicipio': 86, 'valor': 3.0},
#   {'CVEGEO': '14088', 'Idestado': 14, 'Idmunicipio': 88, 'valor': 3.0},
#   {'CVEGEO': '14090', 'Idestado': 14, 'Idmunicipio': 90, 'valor': 3.0},
#   {'CVEGEO': '14091', 'Idestado': 14, 'Idmunicipio': 91, 'valor': 3.0},
#   {'CVEGEO': '14092', 'Idestado': 14, 'Idmunicipio': 92, 'valor': 3.0},
#   {'CVEGEO': '14093', 'Idestado': 14, 'Idmunicipio': 93, 'valor': 3.0},
#   {'CVEGEO': '14097', 'Idestado': 14, 'Idmunicipio': 97, 'valor': 3.0},
#   {'CVEGEO': '14098', 'Idestado': 14, 'Idmunicipio': 98, 'valor': 3.0},
#   {'CVEGEO': '14104', 'Idestado': 14, 'Idmunicipio': 104, 'valor': 2.0},
#   {'CVEGEO': '14109', 'Idestado': 14, 'Idmunicipio': 109, 'valor': 3.0},
#   {'CVEGEO': '14110', 'Idestado': 14, 'Idmunicipio': 110, 'valor': 3.0},
#   {'CVEGEO': '14111', 'Idestado': 14, 'Idmunicipio': 111, 'valor': 3.0},
#   {'CVEGEO': '14112', 'Idestado': 14, 'Idmunicipio': 112, 'valor': 3.0},
#   {'CVEGEO': '14114', 'Idestado': 14, 'Idmunicipio': 114, 'valor': 3.0},
#   {'CVEGEO': '14115', 'Idestado': 14, 'Idmunicipio': 115, 'valor': 3.0},
#   {'CVEGEO': '14116', 'Idestado': 14, 'Idmunicipio': 116, 'valor': 3.0},
#   {'CVEGEO': '14117', 'Idestado': 14, 'Idmunicipio': 117, 'valor': 3.0},
#   {'CVEGEO': '14118', 'Idestado': 14, 'Idmunicipio': 118, 'valor': 3.0},
#   {'CVEGEO': '14120', 'Idestado': 14, 'Idmunicipio': 120, 'valor': 3.0},
#   {'CVEGEO': '14123', 'Idestado': 14, 'Idmunicipio': 123, 'valor': 4.0},
#   {'CVEGEO': '14124', 'Idestado': 14, 'Idmunicipio': 124, 'valor': 3.0},
#   {'CVEGEO': '15001', 'Idestado': 15, 'Idmunicipio': 1, 'valor': 2.0},
#   {'CVEGEO': '15002', 'Idestado': 15, 'Idmunicipio': 2, 'valor': 2.0},
#   {'CVEGEO': '15003', 'Idestado': 15, 'Idmunicipio': 3, 'valor': 3.0},
#   {'CVEGEO': '15004', 'Idestado': 15, 'Idmunicipio': 4, 'valor': 3.0},
#   {'CVEGEO': '15006', 'Idestado': 15, 'Idmunicipio': 6, 'valor': 3.0},
#   {'CVEGEO': '15009', 'Idestado': 15, 'Idmunicipio': 9, 'valor': 3.0},
#   {'CVEGEO': '15011', 'Idestado': 15, 'Idmunicipio': 11, 'valor': 3.0},
#   {'CVEGEO': '15012', 'Idestado': 15, 'Idmunicipio': 12, 'valor': 3.0},
#   {'CVEGEO': '15013', 'Idestado': 15, 'Idmunicipio': 13, 'valor': 2.0},
#   {'CVEGEO': '15014', 'Idestado': 15, 'Idmunicipio': 14, 'valor': 3.0},
#   {'CVEGEO': '15015', 'Idestado': 15, 'Idmunicipio': 15, 'valor': 3.0},
#   {'CVEGEO': '15017', 'Idestado': 15, 'Idmunicipio': 17, 'valor': 2.0},
#   {'CVEGEO': '15018', 'Idestado': 15, 'Idmunicipio': 18, 'valor': 2.0},
#   {'CVEGEO': '15019', 'Idestado': 15, 'Idmunicipio': 19, 'valor': 3.0},
#   {'CVEGEO': '15020', 'Idestado': 15, 'Idmunicipio': 20, 'valor': 3.0},
#   {'CVEGEO': '15021', 'Idestado': 15, 'Idmunicipio': 21, 'valor': 3.0},
#   {'CVEGEO': '15022', 'Idestado': 15, 'Idmunicipio': 22, 'valor': 2.0},
#   {'CVEGEO': '15023', 'Idestado': 15, 'Idmunicipio': 23, 'valor': 2.0},
#   {'CVEGEO': '15024', 'Idestado': 15, 'Idmunicipio': 24, 'valor': 3.0},
#   {'CVEGEO': '15025', 'Idestado': 15, 'Idmunicipio': 25, 'valor': 2.0},
#   {'CVEGEO': '15027', 'Idestado': 15, 'Idmunicipio': 27, 'valor': 2.0},
#   {'CVEGEO': '15028', 'Idestado': 15, 'Idmunicipio': 28, 'valor': 3.0},
#   {'CVEGEO': '15029', 'Idestado': 15, 'Idmunicipio': 29, 'valor': 3.0},
#   {'CVEGEO': '15030', 'Idestado': 15, 'Idmunicipio': 30, 'valor': 3.0},
#   {'CVEGEO': '15032', 'Idestado': 15, 'Idmunicipio': 32, 'valor': 2.0},
#   {'CVEGEO': '15033', 'Idestado': 15, 'Idmunicipio': 33, 'valor': 3.0},
#   {'CVEGEO': '15034', 'Idestado': 15, 'Idmunicipio': 34, 'valor': 3.0},
#   {'CVEGEO': '15035', 'Idestado': 15, 'Idmunicipio': 35, 'valor': 3.0},
#   {'CVEGEO': '15037', 'Idestado': 15, 'Idmunicipio': 37, 'valor': 3.0},
#   {'CVEGEO': '15038', 'Idestado': 15, 'Idmunicipio': 38, 'valor': 3.0},
#   {'CVEGEO': '15039', 'Idestado': 15, 'Idmunicipio': 39, 'valor': 3.0},
#   {'CVEGEO': '15040', 'Idestado': 15, 'Idmunicipio': 40, 'valor': 3.0},
#   {'CVEGEO': '15041', 'Idestado': 15, 'Idmunicipio': 41, 'valor': 2.0},
#   {'CVEGEO': '15043', 'Idestado': 15, 'Idmunicipio': 43, 'valor': 3.0},
#   {'CVEGEO': '15044', 'Idestado': 15, 'Idmunicipio': 44, 'valor': 3.0},
#   {'CVEGEO': '15045', 'Idestado': 15, 'Idmunicipio': 45, 'valor': 3.0},
#   {'CVEGEO': '15046', 'Idestado': 15, 'Idmunicipio': 46, 'valor': 2.0},
#   {'CVEGEO': '15050', 'Idestado': 15, 'Idmunicipio': 50, 'valor': 3.0},
#   {'CVEGEO': '15051', 'Idestado': 15, 'Idmunicipio': 51, 'valor': 3.0},
#   {'CVEGEO': '15052', 'Idestado': 15, 'Idmunicipio': 52, 'valor': 2.0},
#   {'CVEGEO': '15053', 'Idestado': 15, 'Idmunicipio': 53, 'valor': 3.0},
#   {'CVEGEO': '15054', 'Idestado': 15, 'Idmunicipio': 54, 'valor': 3.0},
#   {'CVEGEO': '15055', 'Idestado': 15, 'Idmunicipio': 55, 'valor': 2.0},
#   {'CVEGEO': '15057', 'Idestado': 15, 'Idmunicipio': 57, 'valor': 2.0},
#   {'CVEGEO': '15059', 'Idestado': 15, 'Idmunicipio': 59, 'valor': 3.0},
#   {'CVEGEO': '15060', 'Idestado': 15, 'Idmunicipio': 60, 'valor': 2.0},
#   {'CVEGEO': '15062', 'Idestado': 15, 'Idmunicipio': 62, 'valor': 3.0},
#   {'CVEGEO': '15063', 'Idestado': 15, 'Idmunicipio': 63, 'valor': 2.0},
#   {'CVEGEO': '15065', 'Idestado': 15, 'Idmunicipio': 65, 'valor': 2.0},
#   {'CVEGEO': '15066', 'Idestado': 15, 'Idmunicipio': 66, 'valor': 3.0},
#   {'CVEGEO': '15067', 'Idestado': 15, 'Idmunicipio': 67, 'valor': 3.0},
#   {'CVEGEO': '15068', 'Idestado': 15, 'Idmunicipio': 68, 'valor': 3.0},
#   {'CVEGEO': '15069', 'Idestado': 15, 'Idmunicipio': 69, 'valor': 3.0},
#   {'CVEGEO': '15071', 'Idestado': 15, 'Idmunicipio': 71, 'valor': 3.0},
#   {'CVEGEO': '15073', 'Idestado': 15, 'Idmunicipio': 73, 'valor': 3.0},
#   {'CVEGEO': '15075', 'Idestado': 15, 'Idmunicipio': 75, 'valor': 2.0},
#   {'CVEGEO': '15076', 'Idestado': 15, 'Idmunicipio': 76, 'valor': 3.0},
#   {'CVEGEO': '15077', 'Idestado': 15, 'Idmunicipio': 77, 'valor': 3.0},
#   {'CVEGEO': '15079', 'Idestado': 15, 'Idmunicipio': 79, 'valor': 3.0},
#   {'CVEGEO': '15080', 'Idestado': 15, 'Idmunicipio': 80, 'valor': 3.0},
#   {'CVEGEO': '15081', 'Idestado': 15, 'Idmunicipio': 81, 'valor': 3.0},
#   {'CVEGEO': '15083', 'Idestado': 15, 'Idmunicipio': 83, 'valor': 2.0},
#   {'CVEGEO': '15084', 'Idestado': 15, 'Idmunicipio': 84, 'valor': 2.0},
#   {'CVEGEO': '15085', 'Idestado': 15, 'Idmunicipio': 85, 'valor': 3.0},
#   {'CVEGEO': '15086', 'Idestado': 15, 'Idmunicipio': 86, 'valor': 3.0},
#   {'CVEGEO': '15088', 'Idestado': 15, 'Idmunicipio': 88, 'valor': 3.0},
#   {'CVEGEO': '15089', 'Idestado': 15, 'Idmunicipio': 89, 'valor': 2.0},
#   {'CVEGEO': '15090', 'Idestado': 15, 'Idmunicipio': 90, 'valor': 3.0},
#   {'CVEGEO': '15091', 'Idestado': 15, 'Idmunicipio': 91, 'valor': 3.0},
#   {'CVEGEO': '15092', 'Idestado': 15, 'Idmunicipio': 92, 'valor': 3.0},
#   {'CVEGEO': '15093', 'Idestado': 15, 'Idmunicipio': 93, 'valor': 3.0},
#   {'CVEGEO': '15094', 'Idestado': 15, 'Idmunicipio': 94, 'valor': 3.0},
#   {'CVEGEO': '15095', 'Idestado': 15, 'Idmunicipio': 95, 'valor': 3.0},
#   {'CVEGEO': '15097', 'Idestado': 15, 'Idmunicipio': 97, 'valor': 3.0},
#   {'CVEGEO': '15098', 'Idestado': 15, 'Idmunicipio': 98, 'valor': 3.0},
#   {'CVEGEO': '15099', 'Idestado': 15, 'Idmunicipio': 99, 'valor': 3.0},
#   {'CVEGEO': '15100', 'Idestado': 15, 'Idmunicipio': 100, 'valor': 2.0},
#   {'CVEGEO': '15101', 'Idestado': 15, 'Idmunicipio': 101, 'valor': 3.0},
#   {'CVEGEO': '15102', 'Idestado': 15, 'Idmunicipio': 102, 'valor': 2.0},
#   {'CVEGEO': '15103', 'Idestado': 15, 'Idmunicipio': 103, 'valor': 2.0},
#   {'CVEGEO': '15104', 'Idestado': 15, 'Idmunicipio': 104, 'valor': 2.0},
#   {'CVEGEO': '15107', 'Idestado': 15, 'Idmunicipio': 107, 'valor': 3.0},
#   {'CVEGEO': '15108', 'Idestado': 15, 'Idmunicipio': 108, 'valor': 3.0},
#   {'CVEGEO': '15109', 'Idestado': 15, 'Idmunicipio': 109, 'valor': 3.0},
#   {'CVEGEO': '15110', 'Idestado': 15, 'Idmunicipio': 110, 'valor': 3.0},
#   {'CVEGEO': '15111', 'Idestado': 15, 'Idmunicipio': 111, 'valor': 3.0},
#   {'CVEGEO': '15112', 'Idestado': 15, 'Idmunicipio': 112, 'valor': 3.0},
#   {'CVEGEO': '15115', 'Idestado': 15, 'Idmunicipio': 115, 'valor': 3.0},
#   {'CVEGEO': '15117', 'Idestado': 15, 'Idmunicipio': 117, 'valor': 3.0},
#   {'CVEGEO': '15119', 'Idestado': 15, 'Idmunicipio': 119, 'valor': 3.0},
#   {'CVEGEO': '15120', 'Idestado': 15, 'Idmunicipio': 120, 'valor': 3.0},
#   {'CVEGEO': '15121', 'Idestado': 15, 'Idmunicipio': 121, 'valor': 3.0},
#   {'CVEGEO': '15125', 'Idestado': 15, 'Idmunicipio': 125, 'valor': 3.0},
#   {'CVEGEO': '16003', 'Idestado': 16, 'Idmunicipio': 3, 'valor': 2.0},
#   {'CVEGEO': '16004', 'Idestado': 16, 'Idmunicipio': 4, 'valor': 2.0},
#   {'CVEGEO': '16005', 'Idestado': 16, 'Idmunicipio': 5, 'valor': 2.0},
#   {'CVEGEO': '16007', 'Idestado': 16, 'Idmunicipio': 7, 'valor': 3.0},
#   {'CVEGEO': '16009', 'Idestado': 16, 'Idmunicipio': 9, 'valor': 2.0},
#   {'CVEGEO': '16011', 'Idestado': 16, 'Idmunicipio': 11, 'valor': 3.0},
#   {'CVEGEO': '16017', 'Idestado': 16, 'Idmunicipio': 17, 'valor': 3.0},
#   {'CVEGEO': '16020', 'Idestado': 16, 'Idmunicipio': 20, 'valor': 2.0},
#   {'CVEGEO': '16021', 'Idestado': 16, 'Idmunicipio': 21, 'valor': 2.0},
#   {'CVEGEO': '16022', 'Idestado': 16, 'Idmunicipio': 22, 'valor': 2.0},
#   {'CVEGEO': '16024', 'Idestado': 16, 'Idmunicipio': 24, 'valor': 2.0},
#   {'CVEGEO': '16025', 'Idestado': 16, 'Idmunicipio': 25, 'valor': 3.0},
#   {'CVEGEO': '16027', 'Idestado': 16, 'Idmunicipio': 27, 'valor': 2.0},
#   {'CVEGEO': '16028', 'Idestado': 16, 'Idmunicipio': 28, 'valor': 4.0},
#   {'CVEGEO': '16031', 'Idestado': 16, 'Idmunicipio': 31, 'valor': 3.0},
#   {'CVEGEO': '16032', 'Idestado': 16, 'Idmunicipio': 32, 'valor': 2.0},
#   {'CVEGEO': '16034', 'Idestado': 16, 'Idmunicipio': 34, 'valor': 3.0},
#   {'CVEGEO': '16036', 'Idestado': 16, 'Idmunicipio': 36, 'valor': 3.0},
#   {'CVEGEO': '16037', 'Idestado': 16, 'Idmunicipio': 37, 'valor': 2.0},
#   {'CVEGEO': '16039', 'Idestado': 16, 'Idmunicipio': 39, 'valor': 2.0},
#   {'CVEGEO': '16040', 'Idestado': 16, 'Idmunicipio': 40, 'valor': 2.0},
#   {'CVEGEO': '16041', 'Idestado': 16, 'Idmunicipio': 41, 'valor': 3.0},
#   {'CVEGEO': '16042', 'Idestado': 16, 'Idmunicipio': 42, 'valor': 3.0},
#   {'CVEGEO': '16045', 'Idestado': 16, 'Idmunicipio': 45, 'valor': 4.0},
#   {'CVEGEO': '16048', 'Idestado': 16, 'Idmunicipio': 48, 'valor': 2.0},
#   {'CVEGEO': '16049', 'Idestado': 16, 'Idmunicipio': 49, 'valor': 2.0},
#   {'CVEGEO': '16050', 'Idestado': 16, 'Idmunicipio': 50, 'valor': 3.0},
#   {'CVEGEO': '16053', 'Idestado': 16, 'Idmunicipio': 53, 'valor': 2.0},
#   {'CVEGEO': '16054', 'Idestado': 16, 'Idmunicipio': 54, 'valor': 2.0},
#   {'CVEGEO': '16056', 'Idestado': 16, 'Idmunicipio': 56, 'valor': 2.0},
#   {'CVEGEO': '16060', 'Idestado': 16, 'Idmunicipio': 60, 'valor': 4.0},
#   {'CVEGEO': '16061', 'Idestado': 16, 'Idmunicipio': 61, 'valor': 3.0},
#   {'CVEGEO': '16062', 'Idestado': 16, 'Idmunicipio': 62, 'valor': 4.0},
#   {'CVEGEO': '16063', 'Idestado': 16, 'Idmunicipio': 63, 'valor': 2.0},
#   {'CVEGEO': '16065', 'Idestado': 16, 'Idmunicipio': 65, 'valor': 2.0},
#   {'CVEGEO': '16066', 'Idestado': 16, 'Idmunicipio': 66, 'valor': 2.0},
#   {'CVEGEO': '16067', 'Idestado': 16, 'Idmunicipio': 67, 'valor': 4.0},
#   {'CVEGEO': '16068', 'Idestado': 16, 'Idmunicipio': 68, 'valor': 2.0},
#   {'CVEGEO': '16069', 'Idestado': 16, 'Idmunicipio': 69, 'valor': 4.0},
#   {'CVEGEO': '16071', 'Idestado': 16, 'Idmunicipio': 71, 'valor': 2.0},
#   {'CVEGEO': '16072', 'Idestado': 16, 'Idmunicipio': 72, 'valor': 2.0},
#   {'CVEGEO': '16074', 'Idestado': 16, 'Idmunicipio': 74, 'valor': 3.0},
#   {'CVEGEO': '16075', 'Idestado': 16, 'Idmunicipio': 75, 'valor': 2.0},
#   {'CVEGEO': '16076', 'Idestado': 16, 'Idmunicipio': 76, 'valor': 3.0},
#   {'CVEGEO': '16078', 'Idestado': 16, 'Idmunicipio': 78, 'valor': 2.0},
#   {'CVEGEO': '16079', 'Idestado': 16, 'Idmunicipio': 79, 'valor': 2.0},
#   {'CVEGEO': '16080', 'Idestado': 16, 'Idmunicipio': 80, 'valor': 2.0},
#   {'CVEGEO': '16082', 'Idestado': 16, 'Idmunicipio': 82, 'valor': 2.0},
#   {'CVEGEO': '16083', 'Idestado': 16, 'Idmunicipio': 83, 'valor': 2.0},
#   {'CVEGEO': '16085', 'Idestado': 16, 'Idmunicipio': 85, 'valor': 3.0},
#   {'CVEGEO': '16086', 'Idestado': 16, 'Idmunicipio': 86, 'valor': 3.0},
#   {'CVEGEO': '16088', 'Idestado': 16, 'Idmunicipio': 88, 'valor': 3.0},
#   {'CVEGEO': '16090', 'Idestado': 16, 'Idmunicipio': 90, 'valor': 2.0},
#   {'CVEGEO': '16093', 'Idestado': 16, 'Idmunicipio': 93, 'valor': 3.0},
#   {'CVEGEO': '16094', 'Idestado': 16, 'Idmunicipio': 94, 'valor': 2.0},
#   {'CVEGEO': '16097', 'Idestado': 16, 'Idmunicipio': 97, 'valor': 2.0},
#   {'CVEGEO': '16098', 'Idestado': 16, 'Idmunicipio': 98, 'valor': 3.0},
#   {'CVEGEO': '16100', 'Idestado': 16, 'Idmunicipio': 100, 'valor': 2.0},
#   {'CVEGEO': '16103', 'Idestado': 16, 'Idmunicipio': 103, 'valor': 4.0},
#   {'CVEGEO': '16104', 'Idestado': 16, 'Idmunicipio': 104, 'valor': 3.0},
#   {'CVEGEO': '16105', 'Idestado': 16, 'Idmunicipio': 105, 'valor': 3.0},
#   {'CVEGEO': '16106', 'Idestado': 16, 'Idmunicipio': 106, 'valor': 3.0},
#   {'CVEGEO': '16110', 'Idestado': 16, 'Idmunicipio': 110, 'valor': 2.0},
#   {'CVEGEO': '16111', 'Idestado': 16, 'Idmunicipio': 111, 'valor': 2.0},
#   {'CVEGEO': '16113', 'Idestado': 16, 'Idmunicipio': 113, 'valor': 2.0},
#   {'CVEGEO': '17009', 'Idestado': 17, 'Idmunicipio': 9, 'valor': 2.0},
#   {'CVEGEO': '17016', 'Idestado': 17, 'Idmunicipio': 16, 'valor': 2.0},
#   {'CVEGEO': '17020', 'Idestado': 17, 'Idmunicipio': 20, 'valor': 2.0},
#   {'CVEGEO': '17022', 'Idestado': 17, 'Idmunicipio': 22, 'valor': 2.0},
#   {'CVEGEO': '17023', 'Idestado': 17, 'Idmunicipio': 23, 'valor': 2.0},
#   {'CVEGEO': '17027', 'Idestado': 17, 'Idmunicipio': 27, 'valor': 2.0},
#   {'CVEGEO': '19005', 'Idestado': 19, 'Idmunicipio': 5, 'valor': 1.0},
#   {'CVEGEO': '19006', 'Idestado': 19, 'Idmunicipio': 6, 'valor': 3.0},
#   {'CVEGEO': '19011', 'Idestado': 19, 'Idmunicipio': 11, 'valor': 3.0},
#   {'CVEGEO': '19016', 'Idestado': 19, 'Idmunicipio': 16, 'valor': 2.0},
#   {'CVEGEO': '19018', 'Idestado': 19, 'Idmunicipio': 18, 'valor': 2.0},
#   {'CVEGEO': '19021', 'Idestado': 19, 'Idmunicipio': 21, 'valor': 3.0},
#   {'CVEGEO': '19025', 'Idestado': 19, 'Idmunicipio': 25, 'valor': 2.0},
#   {'CVEGEO': '19037', 'Idestado': 19, 'Idmunicipio': 37, 'valor': 2.0},
#   {'CVEGEO': '19041', 'Idestado': 19, 'Idmunicipio': 41, 'valor': 2.0},
#   {'CVEGEO': '19042', 'Idestado': 19, 'Idmunicipio': 42, 'valor': 3.0},
#   {'CVEGEO': '19044', 'Idestado': 19, 'Idmunicipio': 44, 'valor': 3.0},
#   {'CVEGEO': '19045', 'Idestado': 19, 'Idmunicipio': 45, 'valor': 2.0},
#   {'CVEGEO': '19047', 'Idestado': 19, 'Idmunicipio': 47, 'valor': 2.0},
#   {'CVEGEO': '19050', 'Idestado': 19, 'Idmunicipio': 50, 'valor': 2.0},
#   {'CVEGEO': '20006', 'Idestado': 20, 'Idmunicipio': 6, 'valor': 3.0},
#   {'CVEGEO': '20026', 'Idestado': 20, 'Idmunicipio': 26, 'valor': 2.0},
#   {'CVEGEO': '20054', 'Idestado': 20, 'Idmunicipio': 54, 'valor': 3.0},
#   {'CVEGEO': '20078', 'Idestado': 20, 'Idmunicipio': 78, 'valor': 4.0},
#   {'CVEGEO': '20096', 'Idestado': 20, 'Idmunicipio': 96, 'valor': 2.0},
#   {'CVEGEO': '20107', 'Idestado': 20, 'Idmunicipio': 107, 'valor': 5.0},
#   {'CVEGEO': '20140', 'Idestado': 20, 'Idmunicipio': 140, 'valor': 3.0},
#   {'CVEGEO': '20144', 'Idestado': 20, 'Idmunicipio': 144, 'valor': 2.0},
#   {'CVEGEO': '20215', 'Idestado': 20, 'Idmunicipio': 215, 'valor': 3.0},
#   {'CVEGEO': '20224', 'Idestado': 20, 'Idmunicipio': 224, 'valor': 2.0},
#   {'CVEGEO': '20250', 'Idestado': 20, 'Idmunicipio': 250, 'valor': 3.0},
#   {'CVEGEO': '20273', 'Idestado': 20, 'Idmunicipio': 273, 'valor': 4.0},
#   {'CVEGEO': '20281', 'Idestado': 20, 'Idmunicipio': 281, 'valor': 3.0},
#   {'CVEGEO': '20310', 'Idestado': 20, 'Idmunicipio': 310, 'valor': 5.0},
#   {'CVEGEO': '20385', 'Idestado': 20, 'Idmunicipio': 385, 'valor': 5.0},
#   {'CVEGEO': '20399', 'Idestado': 20, 'Idmunicipio': 399, 'valor': 5.0},
#   {'CVEGEO': '20404', 'Idestado': 20, 'Idmunicipio': 404, 'valor': 2.0},
#   {'CVEGEO': '20451', 'Idestado': 20, 'Idmunicipio': 451, 'valor': 2.0},
#   {'CVEGEO': '20462', 'Idestado': 20, 'Idmunicipio': 462, 'valor': 2.0},
#   {'CVEGEO': '20493', 'Idestado': 20, 'Idmunicipio': 493, 'valor': 3.0},
#   {'CVEGEO': '20500', 'Idestado': 20, 'Idmunicipio': 500, 'valor': 2.0},
#   {'CVEGEO': '20531', 'Idestado': 20, 'Idmunicipio': 531, 'valor': 4.0},
#   {'CVEGEO': '20549', 'Idestado': 20, 'Idmunicipio': 549, 'valor': 2.0},
#   {'CVEGEO': '20555', 'Idestado': 20, 'Idmunicipio': 555, 'valor': 5.0},
#   {'CVEGEO': '20570', 'Idestado': 20, 'Idmunicipio': 570, 'valor': 5.0},
#   {'CVEGEO': '21008', 'Idestado': 21, 'Idmunicipio': 8, 'valor': 1.0},
#   {'CVEGEO': '21010', 'Idestado': 21, 'Idmunicipio': 10, 'valor': 1.0},
#   {'CVEGEO': '21012', 'Idestado': 21, 'Idmunicipio': 12, 'valor': 2.0},
#   {'CVEGEO': '21015', 'Idestado': 21, 'Idmunicipio': 15, 'valor': 2.0},
#   {'CVEGEO': '21016', 'Idestado': 21, 'Idmunicipio': 16, 'valor': 2.0},
#   {'CVEGEO': '21019', 'Idestado': 21, 'Idmunicipio': 19, 'valor': 3.0},
#   {'CVEGEO': '21020', 'Idestado': 21, 'Idmunicipio': 20, 'valor': 3.0},
#   {'CVEGEO': '21023', 'Idestado': 21, 'Idmunicipio': 23, 'valor': 2.0},
#   {'CVEGEO': '21026', 'Idestado': 21, 'Idmunicipio': 26, 'valor': 2.0},
#   {'CVEGEO': '21034', 'Idestado': 21, 'Idmunicipio': 34, 'valor': 2.0},
#   {'CVEGEO': '21038', 'Idestado': 21, 'Idmunicipio': 38, 'valor': 2.0},
#   {'CVEGEO': '21040', 'Idestado': 21, 'Idmunicipio': 40, 'valor': 2.0},
#   {'CVEGEO': '21041', 'Idestado': 21, 'Idmunicipio': 41, 'valor': 3.0},
#   {'CVEGEO': '21044', 'Idestado': 21, 'Idmunicipio': 44, 'valor': 2.0},
#   {'CVEGEO': '21048', 'Idestado': 21, 'Idmunicipio': 48, 'valor': 2.0},
#   {'CVEGEO': '21050', 'Idestado': 21, 'Idmunicipio': 50, 'valor': 2.0},
#   {'CVEGEO': '21053', 'Idestado': 21, 'Idmunicipio': 53, 'valor': 2.0},
#   {'CVEGEO': '21054', 'Idestado': 21, 'Idmunicipio': 54, 'valor': 1.0},
#   {'CVEGEO': '21058', 'Idestado': 21, 'Idmunicipio': 58, 'valor': 2.0},
#   {'CVEGEO': '21063', 'Idestado': 21, 'Idmunicipio': 63, 'valor': 2.0},
#   {'CVEGEO': '21067', 'Idestado': 21, 'Idmunicipio': 67, 'valor': 2.0},
#   {'CVEGEO': '21074', 'Idestado': 21, 'Idmunicipio': 74, 'valor': 2.0},
#   {'CVEGEO': '21079', 'Idestado': 21, 'Idmunicipio': 79, 'valor': 3.0},
#   {'CVEGEO': '21083', 'Idestado': 21, 'Idmunicipio': 83, 'valor': 2.0},
#   {'CVEGEO': '21090', 'Idestado': 21, 'Idmunicipio': 90, 'valor': 2.0},
#   {'CVEGEO': '21093', 'Idestado': 21, 'Idmunicipio': 93, 'valor': 2.0},
#   {'CVEGEO': '21094', 'Idestado': 21, 'Idmunicipio': 94, 'valor': 2.0},
#   {'CVEGEO': '21099', 'Idestado': 21, 'Idmunicipio': 99, 'valor': 2.0},
#   {'CVEGEO': '21104', 'Idestado': 21, 'Idmunicipio': 104, 'valor': 2.0},
#   {'CVEGEO': '21106', 'Idestado': 21, 'Idmunicipio': 106, 'valor': 3.0},
#   {'CVEGEO': '21108', 'Idestado': 21, 'Idmunicipio': 108, 'valor': 2.0},
#   {'CVEGEO': '21110', 'Idestado': 21, 'Idmunicipio': 110, 'valor': 4.0},
#   {'CVEGEO': '21115', 'Idestado': 21, 'Idmunicipio': 115, 'valor': 4.0},
#   {'CVEGEO': '21116', 'Idestado': 21, 'Idmunicipio': 116, 'valor': 2.0},
#   {'CVEGEO': '21122', 'Idestado': 21, 'Idmunicipio': 122, 'valor': 2.0},
#   {'CVEGEO': '21128', 'Idestado': 21, 'Idmunicipio': 128, 'valor': 2.0},
#   {'CVEGEO': '21132', 'Idestado': 21, 'Idmunicipio': 132, 'valor': 2.0},
#   {'CVEGEO': '21134', 'Idestado': 21, 'Idmunicipio': 134, 'valor': 2.0},
#   {'CVEGEO': '21137', 'Idestado': 21, 'Idmunicipio': 137, 'valor': 2.0},
#   {'CVEGEO': '21140', 'Idestado': 21, 'Idmunicipio': 140, 'valor': 2.0},
#   {'CVEGEO': '21142', 'Idestado': 21, 'Idmunicipio': 142, 'valor': 2.0},
#   {'CVEGEO': '21143', 'Idestado': 21, 'Idmunicipio': 143, 'valor': 3.0},
#   {'CVEGEO': '21148', 'Idestado': 21, 'Idmunicipio': 148, 'valor': 2.0},
#   {'CVEGEO': '21149', 'Idestado': 21, 'Idmunicipio': 149, 'valor': 3.0},
#   {'CVEGEO': '21151', 'Idestado': 21, 'Idmunicipio': 151, 'valor': 4.0},
#   {'CVEGEO': '21153', 'Idestado': 21, 'Idmunicipio': 153, 'valor': 2.0},
#   {'CVEGEO': '21154', 'Idestado': 21, 'Idmunicipio': 154, 'valor': 3.0},
#   {'CVEGEO': '21156', 'Idestado': 21, 'Idmunicipio': 156, 'valor': 4.0},
#   {'CVEGEO': '21161', 'Idestado': 21, 'Idmunicipio': 161, 'valor': 4.0},
#   {'CVEGEO': '21164', 'Idestado': 21, 'Idmunicipio': 164, 'valor': 3.0},
#   {'CVEGEO': '21171', 'Idestado': 21, 'Idmunicipio': 171, 'valor': 4.0},
#   {'CVEGEO': '21172', 'Idestado': 21, 'Idmunicipio': 172, 'valor': 2.0},
#   {'CVEGEO': '21180', 'Idestado': 21, 'Idmunicipio': 180, 'valor': 2.0},
#   {'CVEGEO': '21181', 'Idestado': 21, 'Idmunicipio': 181, 'valor': 3.0},
#   {'CVEGEO': '21182', 'Idestado': 21, 'Idmunicipio': 182, 'valor': 3.0},
#   {'CVEGEO': '21186', 'Idestado': 21, 'Idmunicipio': 186, 'valor': 1.0},
#   {'CVEGEO': '21189', 'Idestado': 21, 'Idmunicipio': 189, 'valor': 3.0},
#   {'CVEGEO': '21195', 'Idestado': 21, 'Idmunicipio': 195, 'valor': 1.0},
#   {'CVEGEO': '21199', 'Idestado': 21, 'Idmunicipio': 199, 'valor': 1.0},
#   {'CVEGEO': '21203', 'Idestado': 21, 'Idmunicipio': 203, 'valor': 3.0},
#   {'CVEGEO': '21205', 'Idestado': 21, 'Idmunicipio': 205, 'valor': 4.0},
#   {'CVEGEO': '21207', 'Idestado': 21, 'Idmunicipio': 207, 'valor': 1.0},
#   {'CVEGEO': '21208', 'Idestado': 21, 'Idmunicipio': 208, 'valor': 2.0},
#   {'CVEGEO': '21211', 'Idestado': 21, 'Idmunicipio': 211, 'valor': 1.0},
#   {'CVEGEO': '21212', 'Idestado': 21, 'Idmunicipio': 212, 'valor': 1.0},
#   {'CVEGEO': '22001', 'Idestado': 22, 'Idmunicipio': 1, 'valor': 2.0},
#   {'CVEGEO': '22004', 'Idestado': 22, 'Idmunicipio': 4, 'valor': 2.0},
#   {'CVEGEO': '22005', 'Idestado': 22, 'Idmunicipio': 5, 'valor': 2.0},
#   {'CVEGEO': '22006', 'Idestado': 22, 'Idmunicipio': 6, 'valor': 2.0},
#   {'CVEGEO': '22008', 'Idestado': 22, 'Idmunicipio': 8, 'valor': 3.0},
#   {'CVEGEO': '22010', 'Idestado': 22, 'Idmunicipio': 10, 'valor': 1.0},
#   {'CVEGEO': '22011', 'Idestado': 22, 'Idmunicipio': 11, 'valor': 2.0},
#   {'CVEGEO': '22012', 'Idestado': 22, 'Idmunicipio': 12, 'valor': 3.0},
#   {'CVEGEO': '22014', 'Idestado': 22, 'Idmunicipio': 14, 'valor': 4.0},
#   {'CVEGEO': '22015', 'Idestado': 22, 'Idmunicipio': 15, 'valor': 1.0},
#   {'CVEGEO': '22016', 'Idestado': 22, 'Idmunicipio': 16, 'valor': 3.0},
#   {'CVEGEO': '22018', 'Idestado': 22, 'Idmunicipio': 18, 'valor': 2.0},
#   {'CVEGEO': '24001', 'Idestado': 24, 'Idmunicipio': 1, 'valor': 2.0},
#   {'CVEGEO': '24004', 'Idestado': 24, 'Idmunicipio': 4, 'valor': 2.0},
#   {'CVEGEO': '24005', 'Idestado': 24, 'Idmunicipio': 5, 'valor': 2.0},
#   {'CVEGEO': '24006', 'Idestado': 24, 'Idmunicipio': 6, 'valor': 3.0},
#   {'CVEGEO': '24007', 'Idestado': 24, 'Idmunicipio': 7, 'valor': 4.0},
#   {'CVEGEO': '24008', 'Idestado': 24, 'Idmunicipio': 8, 'valor': 2.0},
#   {'CVEGEO': '24009', 'Idestado': 24, 'Idmunicipio': 9, 'valor': 1.0},
#   {'CVEGEO': '24010', 'Idestado': 24, 'Idmunicipio': 10, 'valor': 2.0},
#   {'CVEGEO': '24011', 'Idestado': 24, 'Idmunicipio': 11, 'valor': 4.0},
#   {'CVEGEO': '24015', 'Idestado': 24, 'Idmunicipio': 15, 'valor': 2.0},
#   {'CVEGEO': '24017', 'Idestado': 24, 'Idmunicipio': 17, 'valor': 2.0},
#   {'CVEGEO': '24019', 'Idestado': 24, 'Idmunicipio': 19, 'valor': 1.0},
#   {'CVEGEO': '24020', 'Idestado': 24, 'Idmunicipio': 20, 'valor': 3.0},
#   {'CVEGEO': '24021', 'Idestado': 24, 'Idmunicipio': 21, 'valor': 2.0},
#   {'CVEGEO': '24022', 'Idestado': 24, 'Idmunicipio': 22, 'valor': 2.0},
#   {'CVEGEO': '24023', 'Idestado': 24, 'Idmunicipio': 23, 'valor': 1.0},
#   {'CVEGEO': '24024', 'Idestado': 24, 'Idmunicipio': 24, 'valor': 3.0},
#   {'CVEGEO': '24025', 'Idestado': 24, 'Idmunicipio': 25, 'valor': 1.0},
#   {'CVEGEO': '24027', 'Idestado': 24, 'Idmunicipio': 27, 'valor': 4.0},
#   {'CVEGEO': '24028', 'Idestado': 24, 'Idmunicipio': 28, 'valor': 2.0},
#   {'CVEGEO': '24031', 'Idestado': 24, 'Idmunicipio': 31, 'valor': 1.0},
#   {'CVEGEO': '24032', 'Idestado': 24, 'Idmunicipio': 32, 'valor': 2.0},
#   {'CVEGEO': '24033', 'Idestado': 24, 'Idmunicipio': 33, 'valor': 1.0},
#   {'CVEGEO': '24035', 'Idestado': 24, 'Idmunicipio': 35, 'valor': 2.0},
#   {'CVEGEO': '24043', 'Idestado': 24, 'Idmunicipio': 43, 'valor': 2.0},
#   {'CVEGEO': '24044', 'Idestado': 24, 'Idmunicipio': 44, 'valor': 3.0},
#   {'CVEGEO': '24045', 'Idestado': 24, 'Idmunicipio': 45, 'valor': 3.0},
#   {'CVEGEO': '24046', 'Idestado': 24, 'Idmunicipio': 46, 'valor': 2.0},
#   {'CVEGEO': '24047', 'Idestado': 24, 'Idmunicipio': 47, 'valor': 3.0},
#   {'CVEGEO': '24049', 'Idestado': 24, 'Idmunicipio': 49, 'valor': 2.0},
#   {'CVEGEO': '24050', 'Idestado': 24, 'Idmunicipio': 50, 'valor': 2.0},
#   {'CVEGEO': '24051', 'Idestado': 24, 'Idmunicipio': 51, 'valor': 2.0},
#   {'CVEGEO': '24052', 'Idestado': 24, 'Idmunicipio': 52, 'valor': 2.0},
#   {'CVEGEO': '24055', 'Idestado': 24, 'Idmunicipio': 55, 'valor': 1.0},
#   {'CVEGEO': '24056', 'Idestado': 24, 'Idmunicipio': 56, 'valor': 2.0},
#   {'CVEGEO': '26001', 'Idestado': 26, 'Idmunicipio': 1, 'valor': 5.0},
#   {'CVEGEO': '26002', 'Idestado': 26, 'Idmunicipio': 2, 'valor': 3.0},
#   {'CVEGEO': '26004', 'Idestado': 26, 'Idmunicipio': 4, 'valor': 3.0},
#   {'CVEGEO': '26005', 'Idestado': 26, 'Idmunicipio': 5, 'valor': 5.0},
#   {'CVEGEO': '26006', 'Idestado': 26, 'Idmunicipio': 6, 'valor': 5.0},
#   {'CVEGEO': '26007', 'Idestado': 26, 'Idmunicipio': 7, 'valor': 3.0},
#   {'CVEGEO': '26009', 'Idestado': 26, 'Idmunicipio': 9, 'valor': 5.0},
#   {'CVEGEO': '26010', 'Idestado': 26, 'Idmunicipio': 10, 'valor': 3.0},
#   {'CVEGEO': '26011', 'Idestado': 26, 'Idmunicipio': 11, 'valor': 3.0},
#   {'CVEGEO': '26012', 'Idestado': 26, 'Idmunicipio': 12, 'valor': 2.0},
#   {'CVEGEO': '26013', 'Idestado': 26, 'Idmunicipio': 13, 'valor': 5.0},
#   {'CVEGEO': '26014', 'Idestado': 26, 'Idmunicipio': 14, 'valor': 5.0},
#   {'CVEGEO': '26015', 'Idestado': 26, 'Idmunicipio': 15, 'valor': 3.0},
#   {'CVEGEO': '26016', 'Idestado': 26, 'Idmunicipio': 16, 'valor': 2.0},
#   {'CVEGEO': '26017', 'Idestado': 26, 'Idmunicipio': 17, 'valor': 3.0},
#   {'CVEGEO': '26018', 'Idestado': 26, 'Idmunicipio': 18, 'valor': 2.0},
#   {'CVEGEO': '26019', 'Idestado': 26, 'Idmunicipio': 19, 'valor': 3.0},
#   {'CVEGEO': '26020', 'Idestado': 26, 'Idmunicipio': 20, 'valor': 5.0},
#   {'CVEGEO': '26021', 'Idestado': 26, 'Idmunicipio': 21, 'valor': 3.0},
#   {'CVEGEO': '26022', 'Idestado': 26, 'Idmunicipio': 22, 'valor': 2.0},
#   {'CVEGEO': '26023', 'Idestado': 26, 'Idmunicipio': 23, 'valor': 3.0},
#   {'CVEGEO': '26024', 'Idestado': 26, 'Idmunicipio': 24, 'valor': 3.0},
#   {'CVEGEO': '26025', 'Idestado': 26, 'Idmunicipio': 25, 'valor': 2.0},
#   {'CVEGEO': '26027', 'Idestado': 26, 'Idmunicipio': 27, 'valor': 3.0},
#   {'CVEGEO': '26028', 'Idestado': 26, 'Idmunicipio': 28, 'valor': 3.0},
#   {'CVEGEO': '26029', 'Idestado': 26, 'Idmunicipio': 29, 'valor': 2.0},
#   {'CVEGEO': '26030', 'Idestado': 26, 'Idmunicipio': 30, 'valor': 5.0},
#   {'CVEGEO': '26031', 'Idestado': 26, 'Idmunicipio': 31, 'valor': 3.0},
#   {'CVEGEO': '26032', 'Idestado': 26, 'Idmunicipio': 32, 'valor': 3.0},
#   {'CVEGEO': '26033', 'Idestado': 26, 'Idmunicipio': 33, 'valor': 2.0},
#   {'CVEGEO': '26034', 'Idestado': 26, 'Idmunicipio': 34, 'valor': 5.0},
#   {'CVEGEO': '26035', 'Idestado': 26, 'Idmunicipio': 35, 'valor': 2.0},
#   {'CVEGEO': '26036', 'Idestado': 26, 'Idmunicipio': 36, 'valor': 2.0},
#   {'CVEGEO': '26037', 'Idestado': 26, 'Idmunicipio': 37, 'valor': 3.0},
#   {'CVEGEO': '26038', 'Idestado': 26, 'Idmunicipio': 38, 'valor': 3.0},
#   {'CVEGEO': '26039', 'Idestado': 26, 'Idmunicipio': 39, 'valor': 3.0},
#   {'CVEGEO': '26040', 'Idestado': 26, 'Idmunicipio': 40, 'valor': 3.0},
#   {'CVEGEO': '26042', 'Idestado': 26, 'Idmunicipio': 42, 'valor': 2.0},
#   {'CVEGEO': '26043', 'Idestado': 26, 'Idmunicipio': 43, 'valor': 2.0},
#   {'CVEGEO': '26045', 'Idestado': 26, 'Idmunicipio': 45, 'valor': 5.0},
#   {'CVEGEO': '26047', 'Idestado': 26, 'Idmunicipio': 47, 'valor': 3.0},
#   {'CVEGEO': '26050', 'Idestado': 26, 'Idmunicipio': 50, 'valor': 5.0},
#   {'CVEGEO': '26052', 'Idestado': 26, 'Idmunicipio': 52, 'valor': 5.0},
#   {'CVEGEO': '26053', 'Idestado': 26, 'Idmunicipio': 53, 'valor': 5.0},
# ...
#   {'CVEGEO': '30211', 'Idestado': 30, 'Idmunicipio': 211, 'valor': 4.0}],
#  'Arrayán': [{'CVEGEO': '18005',
#    'Idestado': 18,
#    'Idmunicipio': 5,
#    'valor': 5.0},
#   {'CVEGEO': '18010', 'Idestado': 18, 'Idmunicipio': 10, 'valor': 1.0},
#   {'CVEGEO': '18011', 'Idestado': 18, 'Idmunicipio': 11, 'valor': 1.0}],
#  'Melón amargo': [{'CVEGEO': '18010',
#    'Idestado': 18,
#    'Idmunicipio': 10,
#    'valor': 2.0},
#   {'CVEGEO': '18015', 'Idestado': 18, 'Idmunicipio': 15, 'valor': 5.0},
#   {'CVEGEO': '18018', 'Idestado': 18, 'Idmunicipio': 18, 'valor': 4.0},
#   {'CVEGEO': '25006', 'Idestado': 25, 'Idmunicipio': 6, 'valor': 1.0}],
#  'Plantero de tabaco ': [{'CVEGEO': '18010',
#    'Idestado': 18,
#    'Idmunicipio': 10,
#    'valor': 5.0},
#   {'CVEGEO': '18011', 'Idestado': 18, 'Idmunicipio': 11, 'valor': 4.0},
#   {'CVEGEO': '18015', 'Idestado': 18, 'Idmunicipio': 15, 'valor': 5.0},
#   {'CVEGEO': '18016', 'Idestado': 18, 'Idmunicipio': 16, 'valor': 1.0},
#   {'CVEGEO': '18018', 'Idestado': 18, 'Idmunicipio': 18, 'valor': 4.0}],
#  'Semilla de jícama': [{'CVEGEO': '18010',
#    'Idestado': 18,
#    'Idmunicipio': 10,
#    'valor': 1.0},
#   {'CVEGEO': '18015', 'Idestado': 18, 'Idmunicipio': 15, 'valor': 1.0},
#   {'CVEGEO': '18017', 'Idestado': 18, 'Idmunicipio': 17, 'valor': 5.0}],
#  'Guamúchil': [{'CVEGEO': '18010',
#    'Idestado': 18,
#    'Idmunicipio': 10,
#    'valor': 1.0}],
#  'Gai lan (kay laan)': [{'CVEGEO': '18012',
#    'Idestado': 18,
#    'Idmunicipio': 12,
#    'valor': 5.0},
#   {'CVEGEO': '18015', 'Idestado': 18, 'Idmunicipio': 15, 'valor': 1.0},
#   {'CVEGEO': '25006', 'Idestado': 25, 'Idmunicipio': 6, 'valor': 1.0},
#   {'CVEGEO': '25018', 'Idestado': 25, 'Idmunicipio': 18, 'valor': 1.0}],
#  'Baby back choi': [{'CVEGEO': '18012',
#    'Idestado': 18,
#    'Idmunicipio': 12,
#    'valor': 1.0},
#   {'CVEGEO': '18015', 'Idestado': 18, 'Idmunicipio': 15, 'valor': 3.0},
#   {'CVEGEO': '25006', 'Idestado': 25, 'Idmunicipio': 6, 'valor': 5.0},
#   {'CVEGEO': '25018', 'Idestado': 25, 'Idmunicipio': 18, 'valor': 5.0}],
#  'Yu-choy': [{'CVEGEO': '18012',
#    'Idestado': 18,
#    'Idmunicipio': 12,
#    'valor': 5.0},
#   {'CVEGEO': '18015', 'Idestado': 18, 'Idmunicipio': 15, 'valor': 4.0},
#   {'CVEGEO': '25006', 'Idestado': 25, 'Idmunicipio': 6, 'valor': 1.0},
#   {'CVEGEO': '25018', 'Idestado': 25, 'Idmunicipio': 18, 'valor': 1.0}],
#  'Shangai-bock-choy': [{'CVEGEO': '18012',
#    'Idestado': 18,
#    'Idmunicipio': 12,
#    'valor': 1.0}],
#  'Hierbabuena': [{'CVEGEO': '18017',
#    'Idestado': 18,
#    'Idmunicipio': 17,
#    'valor': 1.0},
#   {'CVEGEO': '21019', 'Idestado': 21, 'Idmunicipio': 19, 'valor': 3.0},
#   {'CVEGEO': '21118', 'Idestado': 21, 'Idmunicipio': 118, 'valor': 5.0},
#   {'CVEGEO': '21148', 'Idestado': 21, 'Idmunicipio': 148, 'valor': 1.0},
#   {'CVEGEO': '24021', 'Idestado': 24, 'Idmunicipio': 21, 'valor': 5.0}],
#  'Vainilla': [{'CVEGEO': '20021',
#    'Idestado': 20,
#    'Idmunicipio': 21,
#    'valor': 3.0},
#   {'CVEGEO': '20169', 'Idestado': 20, 'Idmunicipio': 169, 'valor': 3.0},
#   {'CVEGEO': '20309', 'Idestado': 20, 'Idmunicipio': 309, 'valor': 2.0},
#   {'CVEGEO': '21002', 'Idestado': 21, 'Idmunicipio': 2, 'valor': 1.0},
#   {'CVEGEO': '21025', 'Idestado': 21, 'Idmunicipio': 25, 'valor': 1.0},
#   {'CVEGEO': '21043', 'Idestado': 21, 'Idmunicipio': 43, 'valor': 1.0},
#   {'CVEGEO': '21064', 'Idestado': 21, 'Idmunicipio': 64, 'valor': 5.0},
#   {'CVEGEO': '21076', 'Idestado': 21, 'Idmunicipio': 76, 'valor': 1.0},
#   {'CVEGEO': '21086', 'Idestado': 21, 'Idmunicipio': 86, 'valor': 5.0},
#   {'CVEGEO': '21111', 'Idestado': 21, 'Idmunicipio': 111, 'valor': 5.0},
#   {'CVEGEO': '21158', 'Idestado': 21, 'Idmunicipio': 158, 'valor': 1.0},
#   {'CVEGEO': '21194', 'Idestado': 21, 'Idmunicipio': 194, 'valor': 5.0},
#   {'CVEGEO': '21197', 'Idestado': 21, 'Idmunicipio': 197, 'valor': 4.0},
#   {'CVEGEO': '30023', 'Idestado': 30, 'Idmunicipio': 23, 'valor': 3.0},
#   {'CVEGEO': '30042', 'Idestado': 30, 'Idmunicipio': 42, 'valor': 2.0},
#   {'CVEGEO': '30095', 'Idestado': 30, 'Idmunicipio': 95, 'valor': 2.0},
#   {'CVEGEO': '30109', 'Idestado': 30, 'Idmunicipio': 109, 'valor': 2.0},
#   {'CVEGEO': '30114', 'Idestado': 30, 'Idmunicipio': 114, 'valor': 3.0},
#   {'CVEGEO': '30151', 'Idestado': 30, 'Idmunicipio': 151, 'valor': 3.0},
#   {'CVEGEO': '30157', 'Idestado': 30, 'Idmunicipio': 157, 'valor': 1.0},
#   {'CVEGEO': '30183', 'Idestado': 30, 'Idmunicipio': 183, 'valor': 2.0},
#   {'CVEGEO': '30189', 'Idestado': 30, 'Idmunicipio': 189, 'valor': 3.0},
#   {'CVEGEO': '30211', 'Idestado': 30, 'Idmunicipio': 211, 'valor': 3.0}],
#  'Alpiste grano': [{'CVEGEO': '20523',
#    'Idestado': 20,
#    'Idmunicipio': 523,
#    'valor': 1.0}],
#  'Piñón': [{'CVEGEO': '21010',
#    'Idestado': 21,
#    'Idmunicipio': 10,
#    'valor': 4.0},
#   {'CVEGEO': '21045', 'Idestado': 21, 'Idmunicipio': 45, 'valor': 1.0},
#   {'CVEGEO': '21067', 'Idestado': 21, 'Idmunicipio': 67, 'valor': 4.0},
#   {'CVEGEO': '21120', 'Idestado': 21, 'Idmunicipio': 120, 'valor': 5.0},
#   {'CVEGEO': '21195', 'Idestado': 21, 'Idmunicipio': 195, 'valor': 4.0},
#   {'CVEGEO': '30010', 'Idestado': 30, 'Idmunicipio': 10, 'valor': 5.0},
#   {'CVEGEO': '30128', 'Idestado': 30, 'Idmunicipio': 128, 'valor': 5.0}],
#  'Albricia': [{'CVEGEO': '21019',
#    'Idestado': 21,
#    'Idmunicipio': 19,
#    'valor': 1.0},
#   {'CVEGEO': '21069', 'Idestado': 21, 'Idmunicipio': 69, 'valor': 2.0},
#   {'CVEGEO': '21188', 'Idestado': 21, 'Idmunicipio': 188, 'valor': 5.0}],
#  'Té limón': [{'CVEGEO': '21019',
#    'Idestado': 21,
#    'Idmunicipio': 19,
#    'valor': 5.0},
#   {'CVEGEO': '21069', 'Idestado': 21, 'Idmunicipio': 69, 'valor': 1.0}],
#  'Bambú': [{'CVEGEO': '21025',
#    'Idestado': 21,
#    'Idmunicipio': 25,
#    'valor': 1.0},
#   {'CVEGEO': '21043', 'Idestado': 21, 'Idmunicipio': 43, 'valor': 5.0},
#   {'CVEGEO': '21076', 'Idestado': 21, 'Idmunicipio': 76, 'valor': 2.0},
#   {'CVEGEO': '21158', 'Idestado': 21, 'Idmunicipio': 158, 'valor': 1.0},
#   {'CVEGEO': '21186', 'Idestado': 21, 'Idmunicipio': 186, 'valor': 3.0}],
#  'Nabo': [{'CVEGEO': '21079', 'Idestado': 21, 'Idmunicipio': 79, 'valor': 1.0},
#   {'CVEGEO': '21115', 'Idestado': 21, 'Idmunicipio': 115, 'valor': 1.0},
#   {'CVEGEO': '21154', 'Idestado': 21, 'Idmunicipio': 154, 'valor': 1.0},
#   {'CVEGEO': '21164', 'Idestado': 21, 'Idmunicipio': 164, 'valor': 5.0},
#   {'CVEGEO': '21189', 'Idestado': 21, 'Idmunicipio': 189, 'valor': 1.0},
#   {'CVEGEO': '21205', 'Idestado': 21, 'Idmunicipio': 205, 'valor': 1.0}],
#  'Colza': [{'CVEGEO': '21122',
#    'Idestado': 21,
#    'Idmunicipio': 122,
#    'valor': 1.0},
#   {'CVEGEO': '21132', 'Idestado': 21, 'Idmunicipio': 132, 'valor': 5.0}],
#  'Pipicha': [{'CVEGEO': '21150',
#    'Idestado': 21,
#    'Idmunicipio': 150,
#    'valor': 1.0}],
#  'Achiote': [{'CVEGEO': '23002',
#    'Idestado': 23,
#    'Idmunicipio': 2,
#    'valor': 1.0},
#   {'CVEGEO': '23006', 'Idestado': 23, 'Idmunicipio': 6, 'valor': 2.0},
#   {'CVEGEO': '27001', 'Idestado': 27, 'Idmunicipio': 1, 'valor': 1.0},
#   {'CVEGEO': '27005', 'Idestado': 27, 'Idmunicipio': 5, 'valor': 1.0},
#   {'CVEGEO': '27007', 'Idestado': 27, 'Idmunicipio': 7, 'valor': 1.0},
#   {'CVEGEO': '27010', 'Idestado': 27, 'Idmunicipio': 10, 'valor': 1.0},
#   {'CVEGEO': '27017', 'Idestado': 27, 'Idmunicipio': 17, 'valor': 1.0},
#   {'CVEGEO': '31003', 'Idestado': 31, 'Idmunicipio': 3, 'valor': 5.0},
#   {'CVEGEO': '31056', 'Idestado': 31, 'Idmunicipio': 56, 'valor': 5.0},
#   {'CVEGEO': '31058', 'Idestado': 31, 'Idmunicipio': 58, 'valor': 3.0},
#   {'CVEGEO': '31079', 'Idestado': 31, 'Idmunicipio': 79, 'valor': 3.0},
#   {'CVEGEO': '31098', 'Idestado': 31, 'Idmunicipio': 98, 'valor': 3.0}],
#  'Frijol x pelón': [{'CVEGEO': '23006',
#    'Idestado': 23,
#    'Idmunicipio': 6,
#    'valor': 1.0},
#   {'CVEGEO': '31003', 'Idestado': 31, 'Idmunicipio': 3, 'valor': 4.0},
#   {'CVEGEO': '31004', 'Idestado': 31, 'Idmunicipio': 4, 'valor': 3.0},
#   {'CVEGEO': '31009', 'Idestado': 31, 'Idmunicipio': 9, 'valor': 3.0},
#   {'CVEGEO': '31013', 'Idestado': 31, 'Idmunicipio': 13, 'valor': 3.0},
#   {'CVEGEO': '31020', 'Idestado': 31, 'Idmunicipio': 20, 'valor': 4.0},
#   {'CVEGEO': '31025', 'Idestado': 31, 'Idmunicipio': 25, 'valor': 4.0},
#   {'CVEGEO': '31026', 'Idestado': 31, 'Idmunicipio': 26, 'valor': 4.0},
#   {'CVEGEO': '31027', 'Idestado': 31, 'Idmunicipio': 27, 'valor': 5.0},
#   {'CVEGEO': '31029', 'Idestado': 31, 'Idmunicipio': 29, 'valor': 5.0},
#   {'CVEGEO': '31032', 'Idestado': 31, 'Idmunicipio': 32, 'valor': 2.0},
#   {'CVEGEO': '31033', 'Idestado': 31, 'Idmunicipio': 33, 'valor': 4.0},
#   {'CVEGEO': '31038', 'Idestado': 31, 'Idmunicipio': 38, 'valor': 4.0},
#   {'CVEGEO': '31039', 'Idestado': 31, 'Idmunicipio': 39, 'valor': 4.0},
#   {'CVEGEO': '31047', 'Idestado': 31, 'Idmunicipio': 47, 'valor': 4.0},
#   {'CVEGEO': '31051', 'Idestado': 31, 'Idmunicipio': 51, 'valor': 4.0},
#   {'CVEGEO': '31052', 'Idestado': 31, 'Idmunicipio': 52, 'valor': 4.0},
#   {'CVEGEO': '31054', 'Idestado': 31, 'Idmunicipio': 54, 'valor': 4.0},
#   {'CVEGEO': '31056', 'Idestado': 31, 'Idmunicipio': 56, 'valor': 4.0},
#   {'CVEGEO': '31068', 'Idestado': 31, 'Idmunicipio': 68, 'valor': 4.0},
#   {'CVEGEO': '31089', 'Idestado': 31, 'Idmunicipio': 89, 'valor': 4.0},
#   {'CVEGEO': '31093', 'Idestado': 31, 'Idmunicipio': 93, 'valor': 3.0},
#   {'CVEGEO': '31095', 'Idestado': 31, 'Idmunicipio': 95, 'valor': 4.0},
#   {'CVEGEO': '31105', 'Idestado': 31, 'Idmunicipio': 105, 'valor': 4.0},
#   {'CVEGEO': '31106', 'Idestado': 31, 'Idmunicipio': 106, 'valor': 3.0}],
#  'Hoja de plátano (belillo)': [{'CVEGEO': '23010',
#    'Idestado': 23,
#    'Idmunicipio': 10,
#    'valor': 1.0},
#   {'CVEGEO': '30022', 'Idestado': 30, 'Idmunicipio': 22, 'valor': 5.0},
#   {'CVEGEO': '30052', 'Idestado': 30, 'Idmunicipio': 52, 'valor': 5.0},
#   {'CVEGEO': '30055', 'Idestado': 30, 'Idmunicipio': 55, 'valor': 3.0},
#   {'CVEGEO': '30056', 'Idestado': 30, 'Idmunicipio': 56, 'valor': 3.0},
#   {'CVEGEO': '30062', 'Idestado': 30, 'Idmunicipio': 62, 'valor': 2.0},
#   {'CVEGEO': '30068', 'Idestado': 30, 'Idmunicipio': 68, 'valor': 3.0},
#   {'CVEGEO': '30078', 'Idestado': 30, 'Idmunicipio': 78, 'valor': 3.0},
#   {'CVEGEO': '30080', 'Idestado': 30, 'Idmunicipio': 80, 'valor': 4.0},
#   {'CVEGEO': '30117', 'Idestado': 30, 'Idmunicipio': 117, 'valor': 5.0},
#   {'CVEGEO': '30129', 'Idestado': 30, 'Idmunicipio': 129, 'valor': 3.0},
#   {'CVEGEO': '30155', 'Idestado': 30, 'Idmunicipio': 155, 'valor': 3.0},
#   {'CVEGEO': '30173', 'Idestado': 30, 'Idmunicipio': 173, 'valor': 5.0},
#   {'CVEGEO': '30186', 'Idestado': 30, 'Idmunicipio': 186, 'valor': 4.0}],
#  'Boi choi': [{'CVEGEO': '25006',
#    'Idestado': 25,
#    'Idmunicipio': 6,
#    'valor': 1.0},
#   {'CVEGEO': '25018', 'Idestado': 25, 'Idmunicipio': 18, 'valor': 5.0}],
#  'Kohlrabi': [{'CVEGEO': '25006',
#    'Idestado': 25,
#    'Idmunicipio': 6,
#    'valor': 1.0}],
#  'Limón real': [{'CVEGEO': '26003',
#    'Idestado': 26,
#    'Idmunicipio': 3,
#    'valor': 1.0},
#   {'CVEGEO': '26029', 'Idestado': 26, 'Idmunicipio': 29, 'valor': 1.0},
#   {'CVEGEO': '26030', 'Idestado': 26, 'Idmunicipio': 30, 'valor': 4.0},
#   {'CVEGEO': '26056', 'Idestado': 26, 'Idmunicipio': 56, 'valor': 5.0}],
#  'Persimonio': [{'CVEGEO': '26020',
#    'Idestado': 26,
#    'Idmunicipio': 20,
#    'valor': 5.0},
#   {'CVEGEO': '26030', 'Idestado': 26, 'Idmunicipio': 30, 'valor': 1.0},
#   {'CVEGEO': '26035', 'Idestado': 26, 'Idmunicipio': 35, 'valor': 1.0},
#   {'CVEGEO': '26036', 'Idestado': 26, 'Idmunicipio': 36, 'valor': 1.0}],
#  'Higuerilla': [{'CVEGEO': '26029',
#    'Idestado': 26,
#    'Idmunicipio': 29,
#    'valor': 1.0},
#   {'CVEGEO': '26030', 'Idestado': 26, 'Idmunicipio': 30, 'valor': 1.0},
#   {'CVEGEO': '26071', 'Idestado': 26, 'Idmunicipio': 71, 'valor': 5.0}],
#  'Shop suey': [{'CVEGEO': '26030',
#    'Idestado': 26,
#    'Idmunicipio': 30,
#    'valor': 5.0},
#   {'CVEGEO': '28021', 'Idestado': 28, 'Idmunicipio': 21, 'valor': 1.0}],
#  'Clyptoria': [{'CVEGEO': '28003',
#    'Idestado': 28,
#    'Idmunicipio': 3,
#    'valor': 1.0}],
#  'Henequén': [{'CVEGEO': '28012',
#    'Idestado': 28,
#    'Idmunicipio': 12,
#    'valor': 1.0},
#   {'CVEGEO': '28013', 'Idestado': 28, 'Idmunicipio': 13, 'valor': 1.0},
#   {'CVEGEO': '28041', 'Idestado': 28, 'Idmunicipio': 41, 'valor': 1.0},
#   {'CVEGEO': '31002', 'Idestado': 31, 'Idmunicipio': 2, 'valor': 5.0},
#   {'CVEGEO': '31004', 'Idestado': 31, 'Idmunicipio': 4, 'valor': 5.0},
#   {'CVEGEO': '31009', 'Idestado': 31, 'Idmunicipio': 9, 'valor': 5.0},
#   {'CVEGEO': '31020', 'Idestado': 31, 'Idmunicipio': 20, 'valor': 5.0},
#   {'CVEGEO': '31026', 'Idestado': 31, 'Idmunicipio': 26, 'valor': 5.0},
#   {'CVEGEO': '31027', 'Idestado': 31, 'Idmunicipio': 27, 'valor': 5.0},
#   {'CVEGEO': '31031', 'Idestado': 31, 'Idmunicipio': 31, 'valor': 5.0},
#   {'CVEGEO': '31034', 'Idestado': 31, 'Idmunicipio': 34, 'valor': 5.0},
#   {'CVEGEO': '31035', 'Idestado': 31, 'Idmunicipio': 35, 'valor': 5.0},
#   {'CVEGEO': '31036', 'Idestado': 31, 'Idmunicipio': 36, 'valor': 4.0},
#   {'CVEGEO': '31037', 'Idestado': 31, 'Idmunicipio': 37, 'valor': 4.0},
#   {'CVEGEO': '31038', 'Idestado': 31, 'Idmunicipio': 38, 'valor': 5.0},
#   {'CVEGEO': '31040', 'Idestado': 31, 'Idmunicipio': 40, 'valor': 5.0},
#   {'CVEGEO': '31042', 'Idestado': 31, 'Idmunicipio': 42, 'valor': 5.0},
#   {'CVEGEO': '31044', 'Idestado': 31, 'Idmunicipio': 44, 'valor': 5.0},
#   {'CVEGEO': '31052', 'Idestado': 31, 'Idmunicipio': 52, 'valor': 5.0},
#   {'CVEGEO': '31054', 'Idestado': 31, 'Idmunicipio': 54, 'valor': 5.0},
#   {'CVEGEO': '31064', 'Idestado': 31, 'Idmunicipio': 64, 'valor': 5.0},
#   {'CVEGEO': '31067', 'Idestado': 31, 'Idmunicipio': 67, 'valor': 5.0},
#   {'CVEGEO': '31068', 'Idestado': 31, 'Idmunicipio': 68, 'valor': 5.0},
#   {'CVEGEO': '31071', 'Idestado': 31, 'Idmunicipio': 71, 'valor': 5.0},
#   {'CVEGEO': '31072', 'Idestado': 31, 'Idmunicipio': 72, 'valor': 5.0},
#   {'CVEGEO': '31074', 'Idestado': 31, 'Idmunicipio': 74, 'valor': 5.0},
#   {'CVEGEO': '31077', 'Idestado': 31, 'Idmunicipio': 77, 'valor': 5.0},
#   {'CVEGEO': '31078', 'Idestado': 31, 'Idmunicipio': 78, 'valor': 5.0},
#   {'CVEGEO': '31082', 'Idestado': 31, 'Idmunicipio': 82, 'valor': 5.0},
#   {'CVEGEO': '31084', 'Idestado': 31, 'Idmunicipio': 84, 'valor': 5.0},
#   {'CVEGEO': '31086', 'Idestado': 31, 'Idmunicipio': 86, 'valor': 5.0},
#   {'CVEGEO': '31087', 'Idestado': 31, 'Idmunicipio': 87, 'valor': 5.0},
#   {'CVEGEO': '31088', 'Idestado': 31, 'Idmunicipio': 88, 'valor': 5.0},
#   {'CVEGEO': '31093', 'Idestado': 31, 'Idmunicipio': 93, 'valor': 5.0},
#   {'CVEGEO': '31095', 'Idestado': 31, 'Idmunicipio': 95, 'valor': 5.0},
#   {'CVEGEO': '31103', 'Idestado': 31, 'Idmunicipio': 103, 'valor': 5.0},
#   {'CVEGEO': '31105', 'Idestado': 31, 'Idmunicipio': 105, 'valor': 5.0},
#   {'CVEGEO': '31106', 'Idestado': 31, 'Idmunicipio': 106, 'valor': 5.0}],
#  'Maíz palomero': [{'CVEGEO': '28015',
#    'Idestado': 28,
#    'Idmunicipio': 15,
#    'valor': 1.0}],
#  'Canola forrajera': [{'CVEGEO': '29030',
#    'Idestado': 29,
#    'Idmunicipio': 30,
#    'valor': 1.0}],
#  'Malanga': [{'CVEGEO': '30004',
#    'Idestado': 30,
#    'Idmunicipio': 4,
#    'valor': 5.0},
#   {'CVEGEO': '30191', 'Idestado': 30, 'Idmunicipio': 191, 'valor': 1.0}],
#  'Ebo (janamargo o veza) grano': [{'CVEGEO': '30010',
#    'Idestado': 30,
#    'Idmunicipio': 10,
#    'valor': 1.0},
#   {'CVEGEO': '30128', 'Idestado': 30, 'Idmunicipio': 128, 'valor': 1.0},
#   {'CVEGEO': '30132', 'Idestado': 30, 'Idmunicipio': 132, 'valor': 5.0},
#   {'CVEGEO': '30194', 'Idestado': 30, 'Idmunicipio': 194, 'valor': 3.0}],
#  'Tangelo': [{'CVEGEO': '30023',
#    'Idestado': 30,
#    'Idmunicipio': 23,
#    'valor': 5.0},
#   {'CVEGEO': '30102', 'Idestado': 30, 'Idmunicipio': 102, 'valor': 5.0},
#   {'CVEGEO': '30109', 'Idestado': 30, 'Idmunicipio': 109, 'valor': 4.0},
#   {'CVEGEO': '30114', 'Idestado': 30, 'Idmunicipio': 114, 'valor': 2.0},
#   {'CVEGEO': '30183', 'Idestado': 30, 'Idmunicipio': 183, 'valor': 5.0},
#   {'CVEGEO': '30211', 'Idestado': 30, 'Idmunicipio': 211, 'valor': 5.0}],
#  'Zapupe': [{'CVEGEO': '30155',
#    'Idestado': 30,
#    'Idmunicipio': 155,
#    'valor': 1.0}],
#  'Saramuyo': [{'CVEGEO': '31003',
#    'Idestado': 31,
#    'Idmunicipio': 3,
#    'valor': 5.0},
#   {'CVEGEO': '31047', 'Idestado': 31, 'Idmunicipio': 47, 'valor': 1.0},
#   {'CVEGEO': '31056', 'Idestado': 31, 'Idmunicipio': 56, 'valor': 5.0}]}

# %%
columns_for_agent = [
    "CVEGEO", "NOMGEO", "NOM_ENT",
    "ALTITUD",
    "PH", "CE", "CO", "CIC", "SB", "SNA",
    "K", "CA", "NA", "MG", "CACO3", "CASO4",
    "DREN_EXT", "DREN_INT",
    "R", "L", "A"
]
suelo = suelo[columns_for_agent]

# %%
suelo
# Out:
#      CVEGEO                        NOMGEO         NOM_ENT      ALTITUD  \
# 0     01008            San José de Gracia  Aguascalientes  2300.000000
# 1     01009                      Tepezalá  Aguascalientes  2189.333252
# 2     01010                      El Llano  Aguascalientes  2037.500000
# 4     01001                Aguascalientes  Aguascalientes  2000.000000
# 5     01002                      Asientos  Aguascalientes  2029.666626
# ...     ...                           ...             ...          ...
# 2469  32036                   Ojocaliente       Zacatecas  2221.500000
# 2470  32014  General Francisco R. Murguía       Zacatecas  1866.555542
# 2472  32045                   Tepechitlán       Zacatecas  1860.000000
# 2473  32046                     Tepetongo       Zacatecas  1950.000000
# 2474  32047       Teúl de González Ortega       Zacatecas  1923.250000
#
#             PH        CE        CO        CIC         SB        SNA  ...  \
# 0     6.087500  1.750000  0.762500   9.425000  81.824997   2.987500  ...
# 1     5.125000  0.716667  0.283333  10.166667  66.666664   3.900000  ...
# 2     5.425000  0.100000  0.675000  10.175000  71.074997   4.275000  ...
# 4     3.100000  1.000000  0.600000   5.500000  45.900002   3.200000  ...
# 5     4.395555  0.532778  0.275000   7.955555  56.042221   4.400000  ...
# ...        ...       ...       ...        ...        ...        ...  ...
# 2469  3.016667  0.058333  0.658333   9.466666  39.083332   0.900000  ...
# 2470  6.842778  3.518889  0.594815  20.939444  80.762962  18.122963  ...
# 2472  5.366667  1.000000  0.400000  10.300000  87.566666   8.800000  ...
# 2473  6.475000  2.000000  0.800000  32.549999  78.275002   1.625000  ...
# 2474  4.292500  0.026667  0.600417  16.762501  37.859165   1.396667  ...
#
#              CA        NA        MG     CACO3  CASO4  DREN_EXT  DREN_INT  \
# 0      7.262500  0.312500  4.412500  0.000000    0.0  4.500000  3.625000
# 1     10.891666  0.491667  1.791667  0.000000    0.0  3.333333  3.333333
# 2      4.900000  0.437500  1.450000  0.000000    0.0  2.500000  3.250000
# 4      3.200000  0.350000  0.850000  0.000000    0.0  4.000000  2.500000
# 5      6.183333  0.553333  1.236667  0.000000    0.0  3.666667  2.966667
# ...         ...       ...       ...       ...    ...       ...       ...
# 2469  12.633333  0.183333  0.816667  0.000000    0.0  3.500000  2.750000
# 2470  27.555000  5.050926  2.313704  7.508889    0.0  3.222222  2.944444
# 2472   3.766667  0.900000  5.666667  0.000000    0.0  3.000000  4.000000
# 2473  14.750000  0.500000  8.600000  0.000000    0.0  3.000000  3.250000
# 2474   4.353750  0.297500  2.186667  0.000000    0.0  4.500000  3.475000
#
#               R          L          A
# 0     19.750000  19.000000  48.750000
# 1     10.833333  14.833333  41.000000
# 2     16.625000  19.375000  51.500000
# 4      4.000000  13.000000  33.000000
# 5     14.011111  11.088889  32.122223
# ...         ...        ...        ...
# 2469  10.666667  11.166667  19.833334
# 2470  24.785185  16.129629  41.492592
# 2472  24.000000  14.000000  62.000000
# 2473  48.500000  28.500000  23.000000
# 2474  16.225000  12.854167  42.170834
#
# [2101 rows x 21 columns]

# %% [markdown]
# ## Dado un cultivo, dar sugerencias nuevas de donde plantar

# %%
def municipios_similares_iniciales(cultivos_dict, similarity, confidence, cultivo, min_valor=4, top_k=5, min_score=0.70):
    """
    Devuelve municipios similares distintos para un cultivo, ordenados por score descendente:
    - Solo originales con valor >= min_valor
    - Calcula score = similarity * confidence
    - Considera hasta top_k similares por cada original
    - Mantiene solo el mejor score por municipio similar
    - Indica a qué municipio original se parece
    - Excluye similares que ya tienen valor registrado (solo N/A)
    - Filtra los similares con score < min_score
    """
    if cultivo not in cultivos_dict:
         return {
        "originales": [],
        "similares_distintos": [],
        "mensaje": f"El cultivo '{cultivo}' no se encontró en los datos disponibles."
    }
    
    valores_cultivo = {m["CVEGEO"]: m["valor"] for m in cultivos_dict[cultivo]}

    # Filtrar originales válidos
    originales = [
        {"CVEGEO": m, "value": v}
        for m, v in valores_cultivo.items()
        if v >= min_valor and m in similarity.columns
    ]
    if not originales:
        return {
            "originales": [],
            "similares_distintos": [],
            "mensaje": (
                f"El cultivo '{cultivo}' existe en los datos, pero ningún municipio "
                f"cumple con el valor mínimo requerido (≥ {min_valor})."
            )
        }

    orig_cvegeos = [o["CVEGEO"] for o in originales]
    similares_map = {}

    for m_orig in orig_cvegeos:
        if m_orig not in similarity.index:
            continue

        # Calcular score = similarity * confidence
        sim_scores = (similarity.loc[m_orig] * confidence.loc[m_orig]).drop(m_orig)
        sim_scores_sorted = sim_scores.sort_values(ascending=False).head(top_k)

        for m_sim, score_val in sim_scores_sorted.items():
            sim_val = similarity.loc[m_orig, m_sim]
            conf_val = confidence.loc[m_orig, m_sim]
            valor_sim = valores_cultivo.get(m_sim, "N/A")

            # Solo mantener similares sin valor registrado (N/A)
            if valor_sim != "N/A":
                continue

            # Guardar solo el mejor score para cada similar
            if m_sim not in similares_map or score_val > similares_map[m_sim]["score"]:
                similares_map[m_sim] = {
                    "CVEGEO": m_sim,
                    "similarity": sim_val,
                    "confidence": conf_val,
                    "score": score_val,
                    "value": valor_sim,
                    "similar_to": m_orig
                }

    # Convertir a lista y filtrar por min_score
    similares_distintos = [
        v for v in similares_map.values() if v["score"] >= min_score *100
    ]

    # Ordenar por score descendente
    similares_distintos = sorted(similares_distintos, key=lambda x: x["score"], reverse=True)

    return {
        "originales": originales,
        "similares_distintos": similares_distintos
    }
def recomendar_municipios_por_cultivo_1(cultivos_dict, similarity, confidence, cultivo,
                                        suelo: pd.DataFrame, min_valor=4, top_k=3, min_score=0.70) -> dict:
    """
    Finds distinct municipalities with agro-environmental conditions suitable for a given crop.
    - Considers only original municipalities with value ≥ min_valor.
    - Computes a composite score = similarity * confidence.
    - Keeps only the best match per similar municipality and filters by min_score.
    - Excludes municipalities that already cultivate the crop (only "N/A" values are considered similar).
    - Adds soil feature vectors for both originals and similar municipalities, excluding the redundant 'CVEGEO' column.
    Focuses primarily on identifying **new potential areas for cultivation** while also listing
    **current producing municipalities** and how well they perform.
    """
    
    resultado_cultivo = municipios_similares_iniciales(cultivos_dict, similarity, confidence, cultivo, min_valor, top_k, min_score)

    # Función interna para obtener features de un solo municipio
    def obtener_features(cvegeo: str) -> dict:
        fila = suelo[suelo['CVEGEO'] == cvegeo]
        if fila.empty:
            return None
        features = fila.iloc[0].to_dict()
        features.pop("CVEGEO", None)  # Eliminar CVEGEO si existe
        return features

    # Agregar features a originales
    for orig in resultado_cultivo.get("originales", []):
        cve = orig["CVEGEO"]
        orig["features_suelo"] = obtener_features(cve)

    # Agregar features a similares
    for sim in resultado_cultivo.get("similares_distintos", []):
        cve = sim["CVEGEO"]
        sim["features_suelo"] = obtener_features(cve)

    return resultado_cultivo

# %%
recomendar_municipios_por_cultivo_1(cultivo_data, df_similarity, df_confidence, "Manzana", suelo, min_valor=4, min_score=0.7)
# Out:
# {'originales': [{'CVEGEO': '01002',
#    'value': 5.0,
#    'features_suelo': {'NOMGEO': 'Asientos',
#     'NOM_ENT': 'Aguascalientes',
#     'ALTITUD': 2029.6666259765625,
#     'PH': 4.39555549621582,
#     'CE': 0.5327777862548828,
#     'CO': 0.2750000059604645,
#     'CIC': 7.955555438995361,
#     'SB': 56.04222106933594,
#     'SNA': 4.400000095367432,
#     'K': 1.2644444704055786,
#     'CA': 6.183333396911621,
#     'NA': 0.5533333420753479,
#     'MG': 1.2366666793823242,
#     'CACO3': 0.0,
#     'CASO4': 0.0,
#     'DREN_EXT': 3.6666667461395264,
#     'DREN_INT': 2.9666666984558105,
#     'R': 14.01111125946045,
#     'L': 11.088889122009277,
#     'A': 32.122222900390625}},
#   {'CVEGEO': '08031',
#    'value': 5.0,
#    'features_suelo': {'NOMGEO': 'Guerrero',
#     'NOM_ENT': 'Chihuahua',
#     'ALTITUD': 2152.142822265625,
#     'PH': 6.023928642272949,
#     'CE': 1.1659523248672485,
#     'CO': 0.6935714483261108,
#     'CIC': 18.163095474243164,
#     'SB': 71.96023559570312,
#     'SNA': 3.081904649734497,
#     'K': 0.6054762005805969,
#     'CA': 7.2096428871154785,
#     'NA': 0.4523809552192688,
#     'MG': 6.237857341766357,
#     'CACO3': 0.0,
#     'CASO4': 0.0,
#     'DREN_EXT': 3.7142856121063232,
#     'DREN_INT': 3.857142925262451,
#     'R': 17.227380752563477,
#     'L': 19.260713577270508,
#     'A': 59.345237731933594}}],
#  'similares_distintos': [{'CVEGEO': '16085',
#    'similarity': 0.8067035,
#    'confidence': 99.42035,
#    'score': 80.20274353027344,
#    'value': 'N/A',
#    'similar_to': '01002',
#    'features_suelo': {'NOMGEO': 'Tangancícuaro',
#     'NOM_ENT': 'Michoacán de Ocampo',
#     'ALTITUD': 2075.0,
#     'PH': 6.860000133514404,
#     'CE': 0.6000000238418579,
#     'CO': 0.8299999833106995,
#     'CIC': 41.84000015258789,
#     'SB': 65.9800033569336,
#     'SNA': 1.399999976158142,
#     'K': 0.8399999737739563,
#     'CA': 6.050000190734863,
#     'NA': 0.6000000238418579,
#     'MG': 5.840000152587891,
#     'CACO3': 0.0,
#     'CASO4': 0.0,
#     'DREN_EXT': 4.0,
#     'DREN_INT': 4.0,
#     'R': 26.0,
#     'L': 29.0,
#     'A': 45.0}},
#   {'CVEGEO': '29015',
#    'similarity': 0.7989112,
#    'confidence': 99.008766,
#    'score': 79.09921264648438,
#    'value': 'N/A',
#    'similar_to': '01002',
#    'features_suelo': {'NOMGEO': 'Ixtacuixtla de Mariano Matamoros',
#     'NOM_ENT': 'Tlaxcala',
#     'ALTITUD': 2423.5,
#     'PH': 3.8125,
#     'CE': 0.05000000074505806,
#     'CO': 1.1124999523162842,
#     'CIC': 21.450000762939453,
#     'SB': 38.61249923706055,
#     'SNA': 0.7250000238418579,
#     'K': 1.1375000476837158,
#     'CA': 6.412499904632568,
#     'NA': 0.20000000298023224,
#     'MG': 3.9000000953674316,
#     'CACO3': 0.0,
#     'CASO4': 0.0,
#     'DREN_EXT': 4.5,
#     'DREN_INT': 2.5,
#     'R': 23.0,
#     'L': 11.75,
#     'A': 27.75}},
#   {'CVEGEO': '29019',
#    'similarity': 0.79761004,
#    'confidence': 98.878654,
#    'score': 78.86660766601562,
#    'value': 'N/A',
#    'similar_to': '01002',
#    'features_suelo': {'NOMGEO': 'Tepetitla de Lardizábal',
#     'NOM_ENT': 'Tlaxcala',
#     'ALTITUD': 2306.5,
#     'PH': 5.25,
#     'CE': 0.06499999761581421,
#     'CO': 0.925000011920929,
#     'CIC': 17.860000610351562,
#     'SB': 51.0,
#     'SNA': 1.7350000143051147,
#     'K': 1.2450000047683716,
#     'CA': 5.164999961853027,
#     'NA': 0.22499999403953552,
#     'MG': 2.994999885559082,
#     'CACO3': 0.0,
#     'CASO4': 0.0,
#     'DREN_EXT': 5.0,
#     'DREN_INT': 3.25,
#     'R': 14.899999618530273,
#     'L': 11.399999618530273,
#     'A': 48.70000076293945}}]}

# %% [markdown]
# ## Dado un municipio, dar sugerencia de donde hay otro similar y que plantar en este

# %%
def top_cultivos_recomendados_iniciales(cvegeo, similarity, confidence, municipios_data, top_n=3, min_valor=4.0):
    """
    Devuelve:
    - original: CVEGEO dado
    - similares: lista de los top_n municipios más parecidos con similarity, confidence y score
    - cultivos_recomendados: lista de cultivos con valor en el municipio original >= min_valor
    """
    if cvegeo not in similarity.columns:
        return {"error": f"{cvegeo} no está en similarity columns"}
    
    # Calcular score
    sim_scores = similarity.loc[cvegeo] * confidence.loc[cvegeo]
    sim_scores[cvegeo] = -1  # no contarse a sí mismo
    
    # Obtener los top_n más similares
    top_similares_cvegeos = sim_scores.nlargest(top_n).index.tolist()
    
    # Construir lista de similares con similarity, confidence y score
    similares_list = []
    for sim_cvegeo in top_similares_cvegeos:
        sim_val = similarity.loc[cvegeo, sim_cvegeo]
        conf_val = confidence.loc[cvegeo, sim_cvegeo]
        score_val = sim_val * conf_val
        similares_list.append({
            "CVEGEO": sim_cvegeo,
            "similarity": sim_val,
            "confidence": conf_val,
            "score": score_val
        })
    
    # Obtener cultivos recomendados según el municipio original
    orig_data = next((m for m in municipios_data if m["CVEGEO"] == cvegeo), None)
    cultivos_recomendados = []
    if orig_data:
        for cultivo, valor in orig_data["cultivos"].items():
            if valor >= min_valor:
                cultivos_recomendados.append({"cultivo": cultivo, "value_original": valor})
    
    return {
        "original": cvegeo,
        "similares": similares_list,
        "cultivos_recomendados_inicialmente": cultivos_recomendados
    }

def recomendar_cultivos_por_municipio_1(cvegeo, similarity, confidence, municipios_data, suelo: pd.DataFrame, top_n=3, min_valor=4.0) -> dict:
    """
    Devuelve:
    - original: CVEGEO dado
    - similares: lista de los top_n municipios más parecidos con similarity, confidence y score
    - Para cada similar:
        * cultivos_nuevos: cultivos recomendados que no cultiva actualmente
        * cultivos_compartidos: cultivos comunes con valor_original, valor_similar y diferencia
    Añade los features de suelo al original y a los similares de un resultado de cultivo,
    eliminando la columna 'CVEGEO' de los features para evitar redundancia.
    """
    resultado_cultivo = top_cultivos_recomendados_iniciales(
        cvegeo, similarity, confidence, municipios_data, top_n, min_valor
    )

    # Función interna para obtener features de un solo municipio
    def obtener_features(cvegeo: str) -> dict:
        fila = suelo[suelo['CVEGEO'] == cvegeo]
        if fila.empty:
            return None
        features = fila.iloc[0].to_dict()
        features.pop("CVEGEO", None)  # Eliminar CVEGEO si existe
        return features

    # Agregar features al original
    if "original" in resultado_cultivo:
        cve = resultado_cultivo["original"]
        resultado_cultivo["features_suelo_original"] = obtener_features(cve)

    # Obtener cultivos del original
    orig_data = next((m for m in municipios_data if m["CVEGEO"] == cvegeo), None)
    cultivos_original = orig_data["cultivos"] if orig_data else {}

    # Agregar features y cultivos nuevos/compartidos a los similares
    for sim in resultado_cultivo.get("similares", []):
        cve = sim["CVEGEO"]
        sim["features_suelo"] = obtener_features(cve)

        # Buscar cultivos del similar
        sim_data = next((m for m in municipios_data if m["CVEGEO"] == cve), None)
        if sim_data:
            cultivos_similar = sim_data["cultivos"]
            cultivos_existentes = set(cultivos_similar.keys())

            cultivos_nuevos = []
            cultivos_compartidos = []

            for cultivo, valor_orig in cultivos_original.items():
                if valor_orig >= min_valor:
                    if cultivo in cultivos_existentes:
                        valor_sim = cultivos_similar[cultivo]
                        diferencia = float(valor_sim) - float(valor_orig)
                        cultivos_compartidos.append({
                            "cultivo": cultivo,
                            "value_original": valor_orig,
                            "value_similar": valor_sim,
                            "difference": abs(diferencia)
                        })
                    else:
                        cultivos_nuevos.append({
                            "cultivo": cultivo,
                            "value_original": valor_orig
                        })

            sim["cultivos_nuevos"] = cultivos_nuevos
            sim["cultivos_compartidos"] = cultivos_compartidos

    # Quitar lista intermedia del resultado
    resultado_cultivo.pop("cultivos_recomendados_inicialmente", None)

    return resultado_cultivo

# %%
recomendar_cultivos_por_municipio_1("01001", df_similarity, df_confidence, municipios_data, suelo, top_n=1, min_valor=4)
# Out:
# {'error': '01001 no está en similarity columns'}

# %%
def cultivos_comunes_mapeados(municipios_data, cvegeo1: str, cvegeo2: str) -> dict:
    """
    Returns the common crops between two municipalities and their values,
    using a custom mapping of values to labels.
    
    Args:
        cvegeo1: CVEGEO del primer municipio.
        cvegeo2: CVEGEO del segundo municipio.
    
    Returns:
        dict con cultivos comunes y valores mapeados.
    """
    mapeo = {
    1: 'Muy Malo',
    2: 'Malo',
    3: 'Regular',
    4: 'Bueno',
    5: 'Excelente'
    }
    # Buscar municipios
    m1 = next((m for m in municipios_data if m["CVEGEO"] == cvegeo1), None)
    m2 = next((m for m in municipios_data if m["CVEGEO"] == cvegeo2), None)
    
    if not m1 or not m2:
        return {"error": "Uno o ambos municipios no fueron encontrados."}
    
    cultivos1 = m1.get("cultivos", {})
    cultivos2 = m2.get("cultivos", {})
    
    comunes = set(cultivos1.keys()) & set(cultivos2.keys())
    
    if not comunes:
        return {"mensaje": f"No hay cultivos compartidos entre {cvegeo1} y {cvegeo2}."}
    
    resultado = {
        cultivo: {
            f"{cvegeo1}": f"{cultivos1[cultivo]} ({mapeo.get(cultivos1[cultivo], 'desconocido')})",
            f"{cvegeo2}": f"{cultivos2[cultivo]} ({mapeo.get(cultivos2[cultivo], 'desconocido')})",
            "diferencia": f"{abs(cultivos1[cultivo]-cultivos2[cultivo])}"
        }
        for cultivo in comunes
    }
    
    return resultado

def cultivos_comunes_dict_1(municipios_data, cvegeo1: str, cvegeo2: str) -> dict:
    """
    Devuelve un diccionario con los cultivos comunes entre dos municipios (cvegeo1 y cvegeo2),
    sus valores y la diferencia.

    Args:
        municipios_data: lista de diccionarios con información de los municipios
        cvegeo1: CVEGEO del primer municipio
        cvegeo2: CVEGEO del segundo municipio

    Returns:
        dict con estructura:
        {
            "cultivo1": {cvegeo1: valor1, cvegeo2: valor2, "diferencia": diff},
            "cultivo2": {...},
            ...
        }
    """
    # Usamos tu función existente para obtener los cultivos comunes
    resultado = cultivos_comunes_mapeados(municipios_data, cvegeo1, cvegeo2)
    
    if "error" in resultado or "mensaje" in resultado:
        return {}  # Devuelve dict vacío si no hay resultados

    data = {}
    for cultivo, valores in resultado.items():
        data[cultivo] = {
            cvegeo1: valores.get(cvegeo1, None),
            cvegeo2: valores.get(cvegeo2, None),
            "diferencia": np.float32(valores.get("diferencia", 0.0))
        }
    
    return data

# %%
cultivos_comunes_dict_1(municipios_data, "01001", "01002")
# Out:
# {'Maíz forrajero en verde': {'01001': '3.0 (Regular)',
#   '01002': '3.0 (Regular)',
#   'diferencia': 0.0},
#  'Uva': {'01001': '3.0 (Regular)', '01002': '4.0 (Bueno)', 'diferencia': 1.0},
#  'Tomate verde': {'01001': '2.0 (Malo)',
#   '01002': '3.0 (Regular)',
#   'diferencia': 1.0},
#  'Alfalfa': {'01001': '4.0 (Bueno)',
#   '01002': '4.0 (Bueno)',
#   'diferencia': 0.0},
#  'Frijol': {'01001': '1.0 (Muy Malo)',
#   '01002': '4.0 (Bueno)',
#   'diferencia': 3.0},
#  'Durazno': {'01001': '5.0 (Excelente)',
#   '01002': '5.0 (Excelente)',
#   'diferencia': 0.0},
#  'Avena forrajera en verde': {'01001': '3.0 (Regular)',
#   '01002': '3.0 (Regular)',
#   'diferencia': 0.0},
#  'Brócoli': {'01001': '2.0 (Malo)', '01002': '2.0 (Malo)', 'diferencia': 0.0},
#  'Nopalitos': {'01001': '2.0 (Malo)',
#   '01002': '2.0 (Malo)',
#   'diferencia': 0.0},
#  'Pastos y praderas': {'01001': '2.0 (Malo)',
#   '01002': '3.0 (Regular)',
#   'diferencia': 1.0},
#  'Maíz grano': {'01001': '2.0 (Malo)',
#   '01002': '2.0 (Malo)',
#   'diferencia': 0.0},
#  'Tuna': {'01001': '1.0 (Muy Malo)',
#   '01002': '1.0 (Muy Malo)',
#   'diferencia': 0.0},
#  'Tomate rojo (jitomate)': {'01001': '3.0 (Regular)',
#   '01002': '2.0 (Malo)',
#   'diferencia': 1.0},
#  'Chile verde': {'01001': '2.0 (Malo)',
#   '01002': '1.0 (Muy Malo)',
#   'diferencia': 1.0}}

# %%
from langchain.tools import tool
@tool 
def recomendar_municipios_por_cultivo(cultivo: str, min_value: float = 4.0, top_k=3, min_score=0.70) -> dict:
    """
    Given a crop, identifies municipalities with similar agro-environmental conditions 
    suitable for its cultivation.  
    Focuses on finding **new potential areas (similares)** while also listing 
    **current producing municipalities (originales)** and how well they perform.  
    Uses a score = similarity*confidence and includes detailed soil feature vectors for each.

    Parameters:
      • cultivo — Crop name to analyze and find suitable municipalities for.  
      • min_value — Minimum cultivation value to consider a municipality as an “original” producer (default: 4.0).  
      • top_k — Number of top similar municipalities to include in the recommendation (default: 3).  
                 Helps prevent cases where no similar municipality meets the conditions.  
      • min_score — Minimum similarity-confidence score to keep a municipality as valid (default: 0.70).  
    """
    return recomendar_municipios_por_cultivo_1(cultivo_data, df_similarity, df_confidence, cultivo, suelo, min_value, top_k, min_score)

@tool
def recomendar_cultivos_por_municipio(cvegeo: str, top_n: int = 1, min_value: float = 4.0) -> dict:
    """
    Given a municipality (CVEGEO), identifies the most similar municipalities based on 
    similarity*confidence scores.  
    For each similar municipality, it provides:
      • **New crops** that are promising but not currently cultivated.  
      • **Shared crops** with their respective values in both municipalities and the difference.  
    Also includes detailed soil feature vectors for both the original and similar municipalities.

    Parameters:
      • cvegeo — Unique municipality identifier (CVEGEO) to use as the reference.  
      • top_n — Number of top similar municipalities to include in the analysis (default: 1).  
      • min_value — Minimum cultivation value required for a crop to be considered significant 
                    in the similarity and recommendation process (default: 4.0).  
    """
    return recomendar_cultivos_por_municipio_1(cvegeo, df_similarity, df_confidence, municipios_data, suelo, top_n, min_value)
@tool
def cultivos_comunes(cvegeo1: str, cvegeo2: str) -> dict:
    """
    Compares two municipalities (CVEGEO1 and CVEGEO2) and returns the crops they share in common,
    including their respective values and the performance difference.
    Numeric suitability values are mapped to qualitative labels (e.g., “Excelente”, “Regular”, “Malo”) for easier interpretation.
    """
    return cultivos_comunes_dict_1(municipios_data, cvegeo1, cvegeo2)

# %%
lista_cultivos = list(df.columns)
lista_cultivos = lista_cultivos[3:]

# %%
lista_municipios = list(df_similarity.columns)

# %%
df_filtrado = suelo[suelo["CVEGEO"].isin(lista_municipios)]

# Crear diccionario en el formato deseado
dict_cvegeo = {
    row["CVEGEO"]: f"{row['NOMGEO']}, {row['NOM_ENT']}"
    for _, row in df_filtrado.iterrows()
}

# %%
selector_prompt = (
    "You are an expert agronomy assistant specialized in crop suitability and soil analysis for Mexican municipalities. "
    "You have access to three analytical tools that use similarity, confidence, and soil characteristics:\n\n"
    "Important: Each crop has a 'value' score (1-5) indicating suitability, which can be mapped to qualitative levels "
    "such as: 5=Excelente, 4=Bueno, 3=Regular, 2=Malo, 1=Muy Malo, and 'N/A' meaning the crop is not currently cultivated "
    "or lacks recorded data in that municipality.\n\n"
    "1. recomendar_municipios_por_cultivo(cultivo, min_value=4.0, top_k=3, min_score=0.70):\n"
    "   Finds municipalities with similar agro-environmental conditions for a given crop.\n"
    "   - Returns current producers (originales) and potential new areas (similares_distintos) with soil features.\n"
    "   - Use results to argue where the crop would likely thrive and why, referencing soil, similarity, confidence, and score.\n\n"
    "2. recomendar_cultivos_por_municipio(cvegeo, top_n=1, min_value=4.0):\n"
    "   For a municipality, identifies top similar regions and recommends promising or shared crops.\n"
    "   - Use shared crops as a baseline and reason which new crops could succeed based on data and agronomic logic.\n"
    "   - You may propose additional crops if justified by soil or environmental similarity "
    "(take into account the average difference in shared crops).\n\n"
    "3. cultivos_comunes(cvegeo1, cvegeo2):\n"
    "   Compares two municipalities and lists shared crops with performance differences and qualitative ratings.\n"
    "   - When used, provide a concise summary of shared crops and what that implies about their conditions.\n\n"
    "Always select the most relevant tool, interpret the output critically, and craft conclusions that combine data-driven reasoning with expert judgment."
)

# Inicializa el LLM
selector_model = ChatOpenAI(
    model="gpt-5-nano",
    reasoning_effort='medium')

selector_agent = create_agent(
    model=selector_model,
    tools=[recomendar_municipios_por_cultivo, recomendar_cultivos_por_municipio, cultivos_comunes],
    system_prompt=selector_prompt
)

# %%
query = "Where is the best place to plant Manzana"

for step in selector_agent.stream(
    {"messages": [{"role": "user", "content": query}]}
):
    for update in step.values():
        if not update:  # 👈 Evita errores con None
            continue
        for message in update.get("messages", []):
            message.pretty_print()
# Out:
# ================================== Ai Message ==================================
# Tool Calls:
#   recomendar_municipios_por_cultivo (call_w4P6vnewAIO9dAnTCsOvjsAy)
#  Call ID: call_w4P6vnewAIO9dAnTCsOvjsAy
#   Args:
#     cultivo: Manzana
#     min_value: 4.0
#     top_k: 3
#     min_score: 0.7
# ================================= Tool Message =================================
# Name: recomendar_municipios_por_cultivo
#
# {'originales': [{'CVEGEO': '01002', 'value': 5.0, 'features_suelo': {'NOMGEO': 'Asientos', 'NOM_ENT': 'Aguascalientes', 'ALTITUD': 2029.6666259765625, 'PH': 4.39555549621582, 'CE': 0.5327777862548828, 'CO': 0.2750000059604645, 'CIC': 7.955555438995361, 'SB': 56.04222106933594, 'SNA': 4.400000095367432, 'K': 1.2644444704055786, 'CA': 6.183333396911621, 'NA': 0.5533333420753479, 'MG': 1.2366666793823242, 'CACO3': 0.0, 'CASO4': 0.0, 'DREN_EXT': 3.6666667461395264, 'DREN_INT': 2.9666666984558105, 'R': 14.01111125946045, 'L': 11.088889122009277, 'A': 32.122222900390625}}, {'CVEGEO': '08031', 'value': 5.0, 'features_suelo': {'NOMGEO': 'Guerrero', 'NOM_ENT': 'Chihuahua', 'ALTITUD': 2152.142822265625, 'PH': 6.023928642272949, 'CE': 1.1659523248672485, 'CO': 0.6935714483261108, 'CIC': 18.163095474243164, 'SB': 71.96023559570312, 'SNA': 3.081904649734497, 'K': 0.6054762005805969, 'CA': 7.2096428871154785, 'NA': 0.4523809552192688, 'MG': 6.237857341766357, 'CACO3': 0.0, 'CASO4': 0.0, 'DREN_EXT': 3.7142856121063232, 'DREN_INT': 3.857142925262451, 'R': 17.227380752563477, 'L': 19.260713577270508, 'A': 59.345237731933594}}], 'similares_distintos': [{'CVEGEO': '16085', 'similarity': 0.8067035, 'confidence': 99.42035, 'score': 80.20274353027344, 'value': 'N/A', 'similar_to': '01002', 'features_suelo': {'NOMGEO': 'Tangancícuaro', 'NOM_ENT': 'Michoacán de Ocampo', 'ALTITUD': 2075.0, 'PH': 6.860000133514404, 'CE': 0.6000000238418579, 'CO': 0.8299999833106995, 'CIC': 41.84000015258789, 'SB': 65.9800033569336, 'SNA': 1.399999976158142, 'K': 0.8399999737739563, 'CA': 6.050000190734863, 'NA': 0.6000000238418579, 'MG': 5.840000152587891, 'CACO3': 0.0, 'CASO4': 0.0, 'DREN_EXT': 4.0, 'DREN_INT': 4.0, 'R': 26.0, 'L': 29.0, 'A': 45.0}}, {'CVEGEO': '29015', 'similarity': 0.7989112, 'confidence': 99.008766, 'score': 79.09921264648438, 'value': 'N/A', 'similar_to': '01002', 'features_suelo': {'NOMGEO': 'Ixtacuixtla de Mariano Matamoros', 'NOM_ENT': 'Tlaxcala', 'ALTITUD': 2423.5, 'PH': 3.8125, 'CE': 0.05000000074505806, 'CO': 1.1124999523162842, 'CIC': 21.450000762939453, 'SB': 38.61249923706055, 'SNA': 0.7250000238418579, 'K': 1.1375000476837158, 'CA': 6.412499904632568, 'NA': 0.20000000298023224, 'MG': 3.9000000953674316, 'CACO3': 0.0, 'CASO4': 0.0, 'DREN_EXT': 4.5, 'DREN_INT': 2.5, 'R': 23.0, 'L': 11.75, 'A': 27.75}}, {'CVEGEO': '29019', 'similarity': 0.79761004, 'confidence': 98.878654, 'score': 78.86660766601562, 'value': 'N/A', 'similar_to': '01002', 'features_suelo': {'NOMGEO': 'Tepetitla de Lardizábal', 'NOM_ENT': 'Tlaxcala', 'ALTITUD': 2306.5, 'PH': 5.25, 'CE': 0.06499999761581421, 'CO': 0.925000011920929, 'CIC': 17.860000610351562, 'SB': 51.0, 'SNA': 1.7350000143051147, 'K': 1.2450000047683716, 'CA': 5.164999961853027, 'NA': 0.22499999403953552, 'MG': 2.994999885559082, 'CACO3': 0.0, 'CASO4': 0.0, 'DREN_EXT': 5.0, 'DREN_INT': 3.25, 'R': 14.899999618530273, 'L': 11.399999618530273, 'A': 48.70000076293945}}]}
# ================================== Ai Message ==================================
#
# Basándome en la evaluación de similitud agroambiental para Manzana, estas son las mejores ubicaciones según el último análisis:
#
# Lugares actuales con mayor potencial (originales)
# - Asientos, Aguascalientes (CVEGEO 01002)
#   - Valor de cultivo: 5.0 (muy adecuado)
#   - Altitud: ~2030 m
#   - Suelo: pH ~4.40 (muy ácido), otros rasgos indicados (DREN_ext 3.67, DREN_int 2.97, etc.)
#   - Comentario: clima y altitud son favorables para manzana, pero el pH es ácido y requeriría encalado para alcanzar un rango óptimo (≈6.0–6.5). Drenaje adecuado y otros rasgos también útiles para manejo.
#
# - Guerrero, Chihuahua (CVEGEO 08031)
#   - Valor de cultivo: 5.0
#   - Altitud: ~2152 m
#   - Suelo: pH ~6.02 (más favorable para manzana), otros rasgos moderados
#   - Comentario: condición de suelo más compatible para manzana sin necesidad tan marcada de corrección de pH como en Asientos.
#
# Lugares similares-distintos (potenciales para ampliar áreas de cultivo)
# - Tangancícuaro, Michoacán (CVEGEO 16085)
#   - Similaridad 0.806, confianza ~99%, score ~80.2
#   - Altitud ~2075 m; pH ~6.86; buen drenaje y rasgos de suelo razonables
#   - Comentario: el terreno y el microclima son cercanos a las áreas actuales; adecuado para iniciar pruebas de cultivo con manejo de pH si fuera necesario.
#
# - Ixtacuixtla de Mariano Matamoros, Tlaxcala (CVEGEO 29015)
#   - Similaridad 0.799, confianza ~99%, score ~79.1
#   - Altitud ~2423 m; pH ~3.81 (muy ácido)
#   - Comentario: alta altitud y clima pueden favorecer, pero el pH extremo requeriría corrección significativa del suelo y manejo cuidadoso de nutrientes.
#
# - Tepetitla de Lardizábal, Tlaxcala (CVEGEO 29019)
#   - Similaridad 0.798, confianza ~99%, score ~78.9
#   - Altitud ~2307 m; pH ~5.25
#   - Comentario: mejor que Tlaxcala con respecto al pH que Ixtacuixtla, pero aún por debajo del rango ideal sin ajuste de pH.
#
# Conclusión práctica
# - Mejor lugar inmediato para Manzana entre los actuales productores: Asientos (01002) y Guerrero (08031). Guerrero tiene suelo ya más cercano al pH óptimo; Asientos podría requerir encalado para optimizar el pH.
# - Mejores opciones para expansión (sin abandonar buenas prácticas de manejo): Tangancícuaro (16085) es el candidato nuevo con mayor similitud y un pH razonablemente favorable, por lo que sería el primer lugar a considerar para pruebas y escalamiento con corrección de pH si es necesario.
# - Cuestionamientos a considerar antes de plantar en Tlaxcala: Ixtacuixtla y Tepetitla ofrecen alta similitud pero Tlaxcala presenta suelos con pH muy bajo (Ixtacuixtla) o moderadamente ácido (Tepetitla). Si se opta por estos sitios, se debe planificar corrección de pH y estrategias de manejo de suelos (liming, muestreo periódico, control de drenaje).
#
# Recomendaciones rápidas de acción
# - Si ya estás en áreas de Asientos o Guerrero: realiza un muestreo de pH profundo y plan de encalado si está por debajo de ~6.0; verifica drenaje y disponibilidad de agua para la época de reposo.
# - Si consideras expandirte a Tangancícuaro: planifica un programa piloto con monitoreo de rendimiento y verifica disponibilidad de agua y microclima; ajusta la fisiología de la variedad a los requerimientos de frío y nutrición.
# - Si se evalúan Tlaxcala: prioriza corrección de pH y drenaje, y elige variedades de manzana con menor requerimiento de frío si ese es un factor local.
#
# ¿Te gustaría que detalle un plan de manejo de suelo y un listado de variedades de Manzana que suelen tolerar rangos de pH más amplios para cada sitio (Asientos, Guerrero y Tangancícuaro)? También puedo correr una segunda ronda con más sitios (top_k mayor) para ampliar opciones.

# %%
query = "What places are similar to 01002?"

for step in selector_agent.stream(
    {"messages": [{"role": "user", "content": query}]}
):
    for update in step.values():
        if not update:  # 👈 Evita errores con None
            continue
        for message in update.get("messages", []):
            message.pretty_print()
# Out:
# ================================== Ai Message ==================================
# Tool Calls:
#   recomendar_cultivos_por_municipio (call_UgsOHK9q7UAdd0H0hcaISTIU)
#  Call ID: call_UgsOHK9q7UAdd0H0hcaISTIU
#   Args:
#     cvegeo: 01002
#     top_n: 3
#     min_value: 4.0
# ================================= Tool Message =================================
# Name: recomendar_cultivos_por_municipio
#
# {'original': '01002', 'similares': [{'CVEGEO': '16085', 'similarity': 0.8067035, 'confidence': 99.42035, 'score': 80.20274, 'features_suelo': {'NOMGEO': 'Tangancícuaro', 'NOM_ENT': 'Michoacán de Ocampo', 'ALTITUD': 2075.0, 'PH': 6.860000133514404, 'CE': 0.6000000238418579, 'CO': 0.8299999833106995, 'CIC': 41.84000015258789, 'SB': 65.9800033569336, 'SNA': 1.399999976158142, 'K': 0.8399999737739563, 'CA': 6.050000190734863, 'NA': 0.6000000238418579, 'MG': 5.840000152587891, 'CACO3': 0.0, 'CASO4': 0.0, 'DREN_EXT': 4.0, 'DREN_INT': 4.0, 'R': 26.0, 'L': 29.0, 'A': 45.0}, 'cultivos_nuevos': [{'cultivo': 'Frijol', 'value_original': 4.0}, {'cultivo': 'Alfalfa', 'value_original': 4.0}, {'cultivo': 'Durazno', 'value_original': 5.0}, {'cultivo': 'Uva', 'value_original': 4.0}, {'cultivo': 'Ejote', 'value_original': 4.0}, {'cultivo': 'Manzana', 'value_original': 5.0}, {'cultivo': 'Ajo', 'value_original': 4.0}, {'cultivo': 'Nopal forrajero', 'value_original': 5.0}], 'cultivos_compartidos': [{'cultivo': 'Calabacita', 'value_original': 4.0, 'value_similar': 3.0, 'difference': 1.0}, {'cultivo': 'Elote', 'value_original': 4.0, 'value_similar': 3.0, 'difference': 1.0}]}, {'CVEGEO': '29015', 'similarity': 0.7989112, 'confidence': 99.008766, 'score': 79.09921, 'features_suelo': {'NOMGEO': 'Ixtacuixtla de Mariano Matamoros', 'NOM_ENT': 'Tlaxcala', 'ALTITUD': 2423.5, 'PH': 3.8125, 'CE': 0.05000000074505806, 'CO': 1.1124999523162842, 'CIC': 21.450000762939453, 'SB': 38.61249923706055, 'SNA': 0.7250000238418579, 'K': 1.1375000476837158, 'CA': 6.412499904632568, 'NA': 0.20000000298023224, 'MG': 3.9000000953674316, 'CACO3': 0.0, 'CASO4': 0.0, 'DREN_EXT': 4.5, 'DREN_INT': 2.5, 'R': 23.0, 'L': 11.75, 'A': 27.75}, 'cultivos_nuevos': [{'cultivo': 'Durazno', 'value_original': 5.0}, {'cultivo': 'Uva', 'value_original': 4.0}, {'cultivo': 'Ejote', 'value_original': 4.0}, {'cultivo': 'Manzana', 'value_original': 5.0}, {'cultivo': 'Nopal forrajero', 'value_original': 5.0}], 'cultivos_compartidos': [{'cultivo': 'Frijol', 'value_original': 4.0, 'value_similar': 3.0, 'difference': 1.0}, {'cultivo': 'Alfalfa', 'value_original': 4.0, 'value_similar': 3.0, 'difference': 1.0}, {'cultivo': 'Calabacita', 'value_original': 4.0, 'value_similar': 2.0, 'difference': 2.0}, {'cultivo': 'Elote', 'value_original': 4.0, 'value_similar': 3.0, 'difference': 1.0}, {'cultivo': 'Ajo', 'value_original': 4.0, 'value_similar': 2.0, 'difference': 2.0}]}, {'CVEGEO': '29019', 'similarity': 0.79761004, 'confidence': 98.878654, 'score': 78.86661, 'features_suelo': {'NOMGEO': 'Tepetitla de Lardizábal', 'NOM_ENT': 'Tlaxcala', 'ALTITUD': 2306.5, 'PH': 5.25, 'CE': 0.06499999761581421, 'CO': 0.925000011920929, 'CIC': 17.860000610351562, 'SB': 51.0, 'SNA': 1.7350000143051147, 'K': 1.2450000047683716, 'CA': 5.164999961853027, 'NA': 0.22499999403953552, 'MG': 2.994999885559082, 'CACO3': 0.0, 'CASO4': 0.0, 'DREN_EXT': 5.0, 'DREN_INT': 3.25, 'R': 14.899999618530273, 'L': 11.399999618530273, 'A': 48.70000076293945}, 'cultivos_nuevos': [{'cultivo': 'Durazno', 'value_original': 5.0}, {'cultivo': 'Uva', 'value_original': 4.0}, {'cultivo': 'Ejote', 'value_original': 4.0}, {'cultivo': 'Manzana', 'value_original': 5.0}, {'cultivo': 'Nopal forrajero', 'value_original': 5.0}], 'cultivos_compartidos': [{'cultivo': 'Frijol', 'value_original': 4.0, 'value_similar': 3.0, 'difference': 1.0}, {'cultivo': 'Alfalfa', 'value_original': 4.0, 'value_similar': 3.0, 'difference': 1.0}, {'cultivo': 'Calabacita', 'value_original': 4.0, 'value_similar': 2.0, 'difference': 2.0}, {'cultivo': 'Elote', 'value_original': 4.0, 'value_similar': 3.0, 'difference': 1.0}, {'cultivo': 'Ajo', 'value_original': 4.0, 'value_similar': 2.0, 'difference': 2.0}]}], 'features_suelo_original': {'NOMGEO': 'Asientos', 'NOM_ENT': 'Aguascalientes', 'ALTITUD': 2029.6666259765625, 'PH': 4.39555549621582, 'CE': 0.5327777862548828, 'CO': 0.2750000059604645, 'CIC': 7.955555438995361, 'SB': 56.04222106933594, 'SNA': 4.400000095367432, 'K': 1.264444470405578 ...
# ================================== Ai Message ==================================
#
# Aquí están los lugares más semejantes a 01002 según el análisis de similitud (top 3):
#
# 1) Tangancícuaro, Michoacán (CVEGEO: 16085)
# - Similaridad: 0.8067, Confianza: 99.42%, Score: 80.20
# - Ficha de suelo (resumen): ALTITUD ~2075 m, PH ~6.86, CE ~0.60, CIC ~41.8, DREN_EXT ~4.0
# - Cultivos nuevos recomendados (para explorar en este entorno):
#   - Frijol, Alfalfa, Durazno, Uva, Ejote, Manzana, Ajo, Nopal forrajero
# - Cultivos compartidos (con diferencias de rendimiento entre 01002 y 16085):
#   - Calabacita: 4.0 vs 3.0 (diferencia 1.0)
#   - Elote: 4.0 vs 3.0 (diferencia 1.0)
#
# 2) Ixtacuixtla de Mariano Matamoros, Tlaxcala (CVEGEO: 29015)
# - Similaridad: 0.7989, Confianza: 99.01%, Score: 79.10
# - Ficha de suelo (resumen): ALTITUD ~2424 m, PH ~3.81, CE ~0.05, CIC ~21.45, DREN_EXT ~4.5, DREN_INT ~2.5
# - Cultivos nuevos recomendados:
#   - Durazno, Uva, Ejote, Manzana, Nopal forrajero
# - Cultivos compartidos:
#   - Frijol: 4.0 vs 3.0 (diferencia 1.0)
#   - Alfalfa: 4.0 vs 3.0 (diferencia 1.0)
#   - Calabacita: 4.0 vs 2.0 (diferencia 2.0)
#   - Elote: 4.0 vs 3.0 (diferencia 1.0)
#   - Ajo: 4.0 vs 2.0 (diferencia 2.0)
#
# 3) Tepetitla de Lardizábal, Tlaxcala (CVEGEO: 29019)
# - Similaridad: 0.7976, Confianza: 98.88%, Score: 78.87
# - Ficha de suelo (resumen): ALTITUD ~2307 m, PH ~5.25, CE ~0.065, CIC ~18.0, DREN_EXT ~5.0, DREN_INT ~3.25
# - Cultivos nuevos recomendados:
#   - Durazno, Uva, Ejote, Manzana, Nopal forrajero
# - Cultivos compartidos:
#   - Frijol: 4.0 vs 3.0 (diferencia 1.0)
#   - Alfalfa: 4.0 vs 3.0 (diferencia 1.0)
#   - Calabacita: 4.0 vs 2.0 (diferencia 2.0)
#   - Elote: 4.0 vs 3.0 (diferencia 1.0)
#   - Ajo: 4.0 vs 2.0 (diferencia 2.0)
#
# Notas rápidas de interpretación:
# - Aunque 01002 está en Aguascalientes (con rango de altitud y rangos de pH específicos), los tres lugares más semejantes abarcan principalmente Michoacán y Tlaxcala, mostrando similitudes en elevación (aprox. 2,0–2,5 km) y en una variedad de rangos de pH y drenaje.
# - Tangancícuaro (Michoacán) aparece como el más similar, con un perfil de suelo relativamente neutro-alcalino y buen drenaje, lo que favorece cultivos como durazno, manzana y uva, además de cultivos regionales como frijol y elote.
# - Tlaxcala presenta suelos con pH más ácido en algunos sitios, lo que sugiere necesidad de manejo de acidez (liming) para optimizar ciertos frutales (durazno, manzana, uva) y hortalizas como ejote y ajo, pero comparten varios cultivos con 01002, lo que facilita transferencia de tecnológicas y prácticas de manejo.
#
# Si quieres, puedo:
# - Profundizar en cada lugar (saber qué cuencas, drenaje y manejo del riego se recomiendan).
# - Proponer un plan de prueba (ensayo de campo) con los cultivos nuevos sugeridos y las prácticas de manejo específicas por sitio.
# - Comparar con otros municipios cercanos para ampliar opciones de adaptación local.

# %% [markdown]
# ### Agente que reescribe para evitar problemas

# %%
dict_cvegeo
lista_cultivos
lista_municipios

# %%
len(dict_cvegeo)
# Out:
# 123

# %%
import re

def clean_text(text: str) -> str:
    """
    Normaliza un string:
    - Convierte a minúsculas
    - Quita símbolos innecesarios (excepto ? y !)
    - Elimina espacios múltiples y caracteres innecesarios
    """
    # Convertir a minúsculas
        
    # Quitar símbolos que no sean letras, números, espacios, ?, !
    text = re.sub(r"[^a-z0-9áéíóúüñ\s?!.,;:%+*'\"()\[\]-]", "", text, flags=re.IGNORECASE)
    
    # Reemplazar múltiples espacios por uno solo
    text = re.sub(r'\s+', ' ', text).strip()
    
    return text

# %%
rewriter_prompt = (
    "You are a preprocessing agent for normalizing user queries about crops and municipalities.\n"
    "You are given the full list of crops and the full dictionary of municipalities with CVEGEO:\n"
    f"Cultivos: {lista_cultivos}\n"
    f"Municipios: {dict_cvegeo}\n\n"
    "Step 1: Detect all words in the input that could be crops or municipalities, even if slightly misspelled.\n"
    "Step 2: For each candidate word:\n"
    "        - If it's a crop, select the closest match from the given crops list.\n"
    "        - If it's a municipality, select the closest match from the given municipios dictionary and use ONLY THE CVEGEO key.\n"
    "Step 3: If no REASONABLE match is found for a crop, use 'N/A'. If no reasonable match is found for a municipality, use 'N/A'.\n"
    "Step 4: Output JSON with keys: rephrased_text, original_text, note.\n"
    "Step 5: Keep the note short and concise, mentioning which DB part was used.\n\n"
    
    "Example input: 'Where is the best place to plant manzina in Aldma?'\n"
    "Example output:\n"
    "{\n"
    "  'original_text': 'Where is the best place to plant manzina in Aldma?',\n"
    "  'rephrased_text': 'Where is the best place to plant Manzana in 08002?',\n"
    "  'note': 'crop corrected using crop list; municipality corrected using municipios dictionary'\n"
    "}\n\n"
    
    "Example input: 'Where can I plant Manzana?'\n"
    "Example output:\n"
    "{\n"
    "  'original_text': 'Where can I plant Manzana?',\n"
    "  'rephrased_text': 'Where can I plant Manzana?',\n"
    "  'note': 'crop matched using crop list; municipality is not mentioned'\n"
    "}\n\n"
    
    "Example input: 'I want to grow xyzabc in Asientos'\n"
    "Example output:\n"
    "{\n"
    "  'original_text': 'I want to grow xyzabc in Asientos',\n"
    "  'rephrased_text': 'I want to grow N/A in 01002',\n"
    "  'note': 'crop cannot be corrected using crop list; municipality corrected using municipios dictionary'\n"
    "}\n"
    "Example input: 'I want to grow manzina in shajshkh'\n"
    "Example output:\n"
    "{\n"
    "  'original_text': 'I want to grow manzina in shajshkh',\n"
    "  'rephrased_text': 'I want to grow Manzana in N/A',\n"
    "  'note': 'crop corrected using crop list; municipality cannot be corrected using municipios dictionary'\n"
    "}\n"
    "EXAMPLES OF WRONG ANSWERS: ['Asientos (01002)', 'Asientos'], CORRECT ONE: '01002'"
)

# Inicializa el LLM
rewriter_model = ChatOpenAI(
    model="gpt-5-nano",
    reasoning_effort='low')


rewriter_agent = create_agent(
    model=rewriter_model,
    system_prompt=rewriter_prompt
)

# %%
query = "Tell me similar municipalities to asientos and what crops are the best to plant"
clean_text(query)
# Out:
# 'Tell me similar municipalities to asientos and what crops are the best to plant'

# %%
query = clean_text(query)

for step in rewriter_agent.stream(
    {"messages": [{"role": "user", "content": query}]}
):
    for update in step.values():
        if not update:  # 👈 Evita errores con None
            continue
        for message in update.get("messages", []):
            message.pretty_print()
# Out:
# ================================== Ai Message ==================================
#
# {
#   "original_text": "Tell me similar municipalities to asientos and what crops are the best to plant",
#   "rephrased_text": "Tell me similar municipalities to 01002 and what crops are the best to plant",
#   "note": "municipality corrected using municipios dictionary; similarity data not available in DB; crops suggested from crop list"
# }

# %%
query = "Where is the best place to plant manzina"
clean_text(query)
# Out:
# 'Where is the best place to plant manzina'

# %%
query = clean_text(query)

for step in rewriter_agent.stream(
    {"messages": [{"role": "user", "content": query}]}
):
    for update in step.values():
        if not update:  # 👈 Evita errores con None
            continue
        for message in update.get("messages", []):
            message.pretty_print()
# Out:
# ================================== Ai Message ==================================
#
# {
#   "original_text": "Where is the best place to plant manzina",
#   "rephrased_text": "Where is the best place to plant Manzana",
#   "note": "crop corrected using crop list; municipality is not mentioned"
# }

# %%
query = "Where is the best place to plant manzina in tgsaush"
clean_text(query)
# Out:
# 'Where is the best place to plant manzina in tgsaush'

# %%
query = clean_text(query)

for step in rewriter_agent.stream(
    {"messages": [{"role": "user", "content": query}]}
):
    for update in step.values():
        if not update:  # 👈 Evita errores con None
            continue
        for message in update.get("messages", []):
            message.pretty_print()
# Out:
# ================================== Ai Message ==================================
#
# {
#   "original_text": "Where is the best place to plant manzina in tgsaush",
#   "rephrased_text": "Where is the best place to plant Manzana in N/A",
#   "note": "crop corrected using crop list; municipality cannot be corrected using municipios dictionary"
# }

# %% [markdown]
# ## adding now both rewrite and recommender

# %%
rewriter_prompt = (
    "You are a preprocessing agent for normalizing user queries about crops and municipalities.\n"
    "You are given the full list of crops and the full dictionary of municipalities with CVEGEO:\n"
    f"Cultivos: {lista_cultivos}\n"
    f"Municipios: {dict_cvegeo}\n\n"
    "Step 1: Detect all words in the input that could be crops or municipalities, even if slightly misspelled.\n"
    "Step 2: For each candidate word:\n"
    "        - If it's a crop, select the closest match from the given crops list.\n"
    "        - If it's a municipality, select the closest match from the given municipios dictionary and use ONLY THE CVEGEO key.\n"
    "Step 3: If no REASONABLE match is found for a crop, use 'N/A'. If no reasonable match is found for a municipality, use 'N/A'.\n"
    "Step 4: Output JSON with keys: rephrased_text, original_text, note.\n"
    "Step 5: Keep the note short and concise, mentioning which DB part was used.\n\n"
    
    "Example input: 'Where is the best place to plant manzina in Aldma?'\n"
    "Example output:\n"
    "{\n"
    "  'original_text': 'Where is the best place to plant manzina in Aldma?',\n"
    "  'rephrased_text': 'Where is the best place to plant Manzana in 08002?',\n"
    "  'note': 'crop corrected using crop list; municipality corrected using municipios dictionary'\n"
    "}\n\n"
    
    "Example input: 'Where can I plant Manzana?'\n"
    "Example output:\n"
    "{\n"
    "  'original_text': 'Where can I plant Manzana?',\n"
    "  'rephrased_text': 'Where can I plant Manzana?',\n"
    "  'note': 'crop matched using crop list; municipality is not mentioned'\n"
    "}\n\n"
    
    "Example input: 'I want to grow xyzabc in Asientos'\n"
    "Example output:\n"
    "{\n"
    "  'original_text': 'I want to grow xyzabc in Asientos',\n"
    "  'rephrased_text': 'I want to grow N/A in 01002',\n"
    "  'note': 'crop cannot be corrected using crop list; municipality corrected using municipios dictionary'\n"
    "}\n"
    "Example input: 'I want to grow manzina in shajshkh'\n"
    "Example output:\n"
    "{\n"
    "  'original_text': 'I want to grow manzina in shajshkh',\n"
    "  'rephrased_text': 'I want to grow Manzana in N/A',\n"
    "  'note': 'crop corrected using crop list; municipality cannot be corrected using municipios dictionary'\n"
    "}\n"
    "EXAMPLES OF WRONG ANSWERS: ['Asientos (01002)', 'Asientos'], CORRECT ONE: '01002'"
)

# Inicializa el LLM
rewriter_model = ChatOpenAI(
    model="gpt-5-mini",
    reasoning_effort='minimal')


rewriter_agent = create_agent(
    model=rewriter_model,
    system_prompt=rewriter_prompt
)

# %%
query = "Tell me similar municipalities to asientos and what crops are the best to plant"
query = clean_text(query)
input_data = {"messages": [{"role": "user", "content": query}]}

response = rewriter_agent.invoke(input_data)
response
# Out:
# {'messages': [HumanMessage(content='Tell me similar municipalities to asientos and what crops are the best to plant', additional_kwargs={}, response_metadata={}, id='a36defdd-7950-40a7-89e7-58b8454ee816'),
#   AIMessage(content='{\n  "original_text": "Tell me similar municipalities to asientos and what crops are the best to plant",\n  "rephrased_text": "Tell me similar municipalities to 01002 and what crops are the best to plant",\n  "note": "municipality corrected using municipios dictionary; crop not mentioned"\n}', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 74, 'prompt_tokens': 3858, 'total_tokens': 3932, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 2816}}, 'model_provider': 'openai', 'model_name': 'gpt-5-mini-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-CaU50E6zPS5RtYsAXW8xFGZ2qwCUs', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--ff171762-a0b8-4e39-b2cd-030e1944d93f-0', usage_metadata={'input_tokens': 3858, 'output_tokens': 74, 'total_tokens': 3932, 'input_token_details': {'audio': 0, 'cache_read': 2816}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}

# %%
selector_prompt = (
    "You are an expert agronomy assistant specialized in crop suitability and soil analysis for Mexican municipalities. "
    "All user queries have been preprocessed by a middleware agent which:\n"
    "- Corrects misspelled municipalities to their CVEGEO codes.\n"
    "- Corrects misspelled crops using a reference crop list.\n"
    "- Outputs a JSON with 'rephrased_text', 'original_text', and a short 'note'.\n\n"
    "Important: Each crop has a 'value' score (1-5) indicating suitability, mapped to qualitative levels: "
    "5=Excelente, 4=Bueno, 3=Regular, 2=Malo, 1=Muy Malo, and 'N/A' meaning the crop is not cultivated or lacks data in that municipality.\n\n"
    "Available analytical tools:\n\n"
    "1. recomendar_municipios_por_cultivo(cultivo, min_value=4.0, top_k=3, min_score=0.70):\n"
    "   - Finds municipalities with similar agro-environmental conditions for a given crop.\n"
    "   - Returns current producers (originales) and potential new areas (similares_distintos) with soil features.\n"
    "   - Use results to argue where the crop would likely thrive, referencing soil, similarity, confidence, and score.\n\n"
    "2. recomendar_cultivos_por_municipio(cvegeo, top_n=1, min_value=4.0):\n"
    "   - Identifies top similar regions for a municipality and recommends promising or shared crops.\n"
    "   - Use shared crops as a baseline and reason which new crops could succeed based on soil and environmental similarity.\n"
    "   - You may propose additional crops if justified by soil or environmental similarity, considering the average difference in shared crops.\n\n"
    "3. cultivos_comunes(cvegeo1, cvegeo2):\n"
    "   - Compares two municipalities and lists shared crops with performance differences and qualitative ratings.\n"
    "   - Provide a concise summary of shared crops and implications for their conditions.\n\n"
    "Guidelines:\n"
    "- Always use the preprocessed inputs from the middleware (CVEGEO codes and validated crops).\n"
    "- Select the most relevant tool and interpret outputs critically.\n"
    "- Base your conclusions on both data-driven reasoning and expert agronomic judgment.\n"
    "- When a crop or municipality is marked 'N/A', explain why it cannot be evaluated.\n"
    "- Keep recommendations and reasoning clear and concise, referencing soil, similarity, and suitability scores.\n\n"
    "- Add the 'note' from the input, dont change anything from it"
    "Example middleware output:\n"
    "{\n"
    "  'original_text': 'Tell me similar municipalities to asientos and what crops are the best to plant',\n"
    "  'rephrased_text': 'Tell me similar municipalities to 01002 and what crops are the best to plant',\n"
    "  'note': 'municipality corrected using municipios dictionary; similarity data not available in DB; crops suggested from crop list'\n"
    "}"
)


# Inicializa el LLM
selector_model = ChatOpenAI(
    model="gpt-5-nano",
    reasoning_effort='medium')

selector_agent = create_agent(
    model=selector_model,
    tools=[recomendar_municipios_por_cultivo, recomendar_cultivos_por_municipio, cultivos_comunes],
    system_prompt=selector_prompt
)

# %%
response
# Out:
# {'messages': [HumanMessage(content='Tell me similar municipalities to asientos and what crops are the best to plant', additional_kwargs={}, response_metadata={}, id='a36defdd-7950-40a7-89e7-58b8454ee816'),
#   AIMessage(content='{\n  "original_text": "Tell me similar municipalities to asientos and what crops are the best to plant",\n  "rephrased_text": "Tell me similar municipalities to 01002 and what crops are the best to plant",\n  "note": "municipality corrected using municipios dictionary; crop not mentioned"\n}', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 74, 'prompt_tokens': 3858, 'total_tokens': 3932, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 2816}}, 'model_provider': 'openai', 'model_name': 'gpt-5-mini-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-CaU50E6zPS5RtYsAXW8xFGZ2qwCUs', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--ff171762-a0b8-4e39-b2cd-030e1944d93f-0', usage_metadata={'input_tokens': 3858, 'output_tokens': 74, 'total_tokens': 3932, 'input_token_details': {'audio': 0, 'cache_read': 2816}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}

# %%
from langchain.messages import HumanMessage, AIMessage

# Extraer solo el contenido del AIMessage
ai_content = next(
    (msg.content for msg in response['messages'] if isinstance(msg, AIMessage)),
    None
)

print(ai_content)
# Out:
# {
#   "original_text": "Tell me similar municipalities to asientos and what crops are the best to plant",
#   "rephrased_text": "Tell me similar municipalities to 01002 and what crops are the best to plant",
#   "note": "municipality corrected using municipios dictionary; crop not mentioned"
# }

# %%
response_rewriter = ai_content

for step in selector_agent.stream(
    {"messages": [{"role": "user", "content": response_rewriter}]}
):
    for update in step.values():
        if not update:  # 👈 Evita errores con None
            continue
        for message in update.get("messages", []):
            message.pretty_print()
# Out:
# ================================== Ai Message ==================================
# Tool Calls:
#   recomendar_cultivos_por_municipio (call_8eIw8Iixlc1ORB0lhYbCn0j5)
#  Call ID: call_8eIw8Iixlc1ORB0lhYbCn0j5
#   Args:
#     cvegeo: 01002
#     top_n: 3
#     min_value: 4.0
# ================================= Tool Message =================================
# Name: recomendar_cultivos_por_municipio
#
# {'original': '01002', 'similares': [{'CVEGEO': '16085', 'similarity': 0.8067035, 'confidence': 99.42035, 'score': 80.20274, 'features_suelo': {'NOMGEO': 'Tangancícuaro', 'NOM_ENT': 'Michoacán de Ocampo', 'ALTITUD': 2075.0, 'PH': 6.860000133514404, 'CE': 0.6000000238418579, 'CO': 0.8299999833106995, 'CIC': 41.84000015258789, 'SB': 65.9800033569336, 'SNA': 1.399999976158142, 'K': 0.8399999737739563, 'CA': 6.050000190734863, 'NA': 0.6000000238418579, 'MG': 5.840000152587891, 'CACO3': 0.0, 'CASO4': 0.0, 'DREN_EXT': 4.0, 'DREN_INT': 4.0, 'R': 26.0, 'L': 29.0, 'A': 45.0}, 'cultivos_nuevos': [{'cultivo': 'Frijol', 'value_original': 4.0}, {'cultivo': 'Alfalfa', 'value_original': 4.0}, {'cultivo': 'Durazno', 'value_original': 5.0}, {'cultivo': 'Uva', 'value_original': 4.0}, {'cultivo': 'Ejote', 'value_original': 4.0}, {'cultivo': 'Manzana', 'value_original': 5.0}, {'cultivo': 'Ajo', 'value_original': 4.0}, {'cultivo': 'Nopal forrajero', 'value_original': 5.0}], 'cultivos_compartidos': [{'cultivo': 'Calabacita', 'value_original': 4.0, 'value_similar': 3.0, 'difference': 1.0}, {'cultivo': 'Elote', 'value_original': 4.0, 'value_similar': 3.0, 'difference': 1.0}]}, {'CVEGEO': '29015', 'similarity': 0.7989112, 'confidence': 99.008766, 'score': 79.09921, 'features_suelo': {'NOMGEO': 'Ixtacuixtla de Mariano Matamoros', 'NOM_ENT': 'Tlaxcala', 'ALTITUD': 2423.5, 'PH': 3.8125, 'CE': 0.05000000074505806, 'CO': 1.1124999523162842, 'CIC': 21.450000762939453, 'SB': 38.61249923706055, 'SNA': 0.7250000238418579, 'K': 1.1375000476837158, 'CA': 6.412499904632568, 'NA': 0.20000000298023224, 'MG': 3.9000000953674316, 'CACO3': 0.0, 'CASO4': 0.0, 'DREN_EXT': 4.5, 'DREN_INT': 2.5, 'R': 23.0, 'L': 11.75, 'A': 27.75}, 'cultivos_nuevos': [{'cultivo': 'Durazno', 'value_original': 5.0}, {'cultivo': 'Uva', 'value_original': 4.0}, {'cultivo': 'Ejote', 'value_original': 4.0}, {'cultivo': 'Manzana', 'value_original': 5.0}, {'cultivo': 'Nopal forrajero', 'value_original': 5.0}], 'cultivos_compartidos': [{'cultivo': 'Frijol', 'value_original': 4.0, 'value_similar': 3.0, 'difference': 1.0}, {'cultivo': 'Alfalfa', 'value_original': 4.0, 'value_similar': 3.0, 'difference': 1.0}, {'cultivo': 'Calabacita', 'value_original': 4.0, 'value_similar': 2.0, 'difference': 2.0}, {'cultivo': 'Elote', 'value_original': 4.0, 'value_similar': 3.0, 'difference': 1.0}, {'cultivo': 'Ajo', 'value_original': 4.0, 'value_similar': 2.0, 'difference': 2.0}]}, {'CVEGEO': '29019', 'similarity': 0.79761004, 'confidence': 98.878654, 'score': 78.86661, 'features_suelo': {'NOMGEO': 'Tepetitla de Lardizábal', 'NOM_ENT': 'Tlaxcala', 'ALTITUD': 2306.5, 'PH': 5.25, 'CE': 0.06499999761581421, 'CO': 0.925000011920929, 'CIC': 17.860000610351562, 'SB': 51.0, 'SNA': 1.7350000143051147, 'K': 1.2450000047683716, 'CA': 5.164999961853027, 'NA': 0.22499999403953552, 'MG': 2.994999885559082, 'CACO3': 0.0, 'CASO4': 0.0, 'DREN_EXT': 5.0, 'DREN_INT': 3.25, 'R': 14.899999618530273, 'L': 11.399999618530273, 'A': 48.70000076293945}, 'cultivos_nuevos': [{'cultivo': 'Durazno', 'value_original': 5.0}, {'cultivo': 'Uva', 'value_original': 4.0}, {'cultivo': 'Ejote', 'value_original': 4.0}, {'cultivo': 'Manzana', 'value_original': 5.0}, {'cultivo': 'Nopal forrajero', 'value_original': 5.0}], 'cultivos_compartidos': [{'cultivo': 'Frijol', 'value_original': 4.0, 'value_similar': 3.0, 'difference': 1.0}, {'cultivo': 'Alfalfa', 'value_original': 4.0, 'value_similar': 3.0, 'difference': 1.0}, {'cultivo': 'Calabacita', 'value_original': 4.0, 'value_similar': 2.0, 'difference': 2.0}, {'cultivo': 'Elote', 'value_original': 4.0, 'value_similar': 3.0, 'difference': 1.0}, {'cultivo': 'Ajo', 'value_original': 4.0, 'value_similar': 2.0, 'difference': 2.0}]}], 'features_suelo_original': {'NOMGEO': 'Asientos', 'NOM_ENT': 'Aguascalientes', 'ALTITUD': 2029.6666259765625, 'PH': 4.39555549621582, 'CE': 0.5327777862548828, 'CO': 0.2750000059604645, 'CIC': 7.955555438995361, 'SB': 56.04222106933594, 'SNA': 4.400000095367432, 'K': 1.264444470405578 ...
# ================================== Ai Message ==================================
#
# Here is what the similarity analysis indicates for Asientos (01002) and the crops best aligned with that agro-environment, based on the latest municipality-to-crop recommendations.
#
# Similar municipalities to Asientos (01002)
# - 16085 Tangancícuaro, Michoacán de Ocampo
#   - Similarity: ~0.807; Confidence ~99.4%; Score ~80.2
#   - Key soil context: ALT ~2075 m; pH ~6.86; CE ~0.60; CAF ~6.05; DREN_EXT ~4.0; DREN_INT ~4.0; R ~26, L ~29, A ~45
#   - New promising crops (crops not currently prominent in Asientos but promising here): Durazno (5.0), Manzana (5.0), Nopal forrajero (5.0), Uva (4.0), Ejote (4.0), Frijol (4.0), Ajo (4.0), Alfalfa (4.0)
#   - Shared crops (existing in Asientos and Tangancícuaro with performance data): Calabacita (Asientos 4.0; Tangancícuaro 3.0; diff 1), Elote (Asientos 4.0; Tangancícuaro 3.0; diff 1)
#
# - 29015 Ixtacuixtla de Mariano Matamoros, Tlaxcala
#   - Similarity: ~0.799; Confidence ~99.0%; Score ~79.1
#   - Key soil context: ALT ~2424 m; pH ~3.81; CE ~0.05; CIC ~21.45; SB ~38.6; DREN_EXT ~4.5; DREN_INT ~2.5; R ~23, L ~11.8, A ~27.8
#   - New promising crops: Durazno (5.0), Uva (4.0), Ejote (4.0), Manzana (5.0), Nopal forrajero (5.0)
#   - Shared crops: Frijol (4.0 original; 3.0 similar; diff 1), Alfalfa (4.0; 3.0; diff 1), Calabacita (4.0; 2.0; diff 2), Elote (4.0; 3.0; diff 1), Ajo (4.0; 2.0; diff 2)
#
# - 29019 Tepetitla de Lardizábal, Tlaxcala
#   - Similarity: ~0.798; Confidence ~98.9%; Score ~78.9
#   - Key soil context: ALT ~2307 m; pH ~5.25; CE ~0.065; CIC ~17.86; SB ~51.0; DREN_EXT ~5.0; DREN_INT ~3.25; R ~14.9, L ~11.4, A ~48.7
#   - New promising crops: Durazno (5.0), Uva (4.0), Ejote (4.0), Manzana (5.0), Nopal forrajero (5.0)
#   - Shared crops: Frijol (4.0; 3.0; diff 1), Alfalfa (4.0; 3.0; diff 1), Calabacita (4.0; 2.0; diff 2), Elote (4.0; 3.0; diff 1), Ajo (4.0; 2.0; diff 2)
#
# Contextual notes
# - The original “features_suelo_original” for Asientos shows a very acidic soil (pH ~4.40), which strongly constrains high-pH crops unless liming and soil management are implemented.
# - Similar municipalities provide a range of soil contexts (some more neutral to alkaline in Tangancícuaro; Tlaxcala sites are more acidic as well). This informs the need for liming and soil amendments if you want to realize the high-potential crops (Durazno, Manzana, Nopal forrajero, Uva) indicated by the similarities.
#
# Crops to consider planting now (practical stance for Asientos)
# - Short-term / maintain current suitability: Calabacita and Elote remain common and reasonably suitable, though there is a noticeable difference in their performance between Asientos and the similar municipalities (diff 1–2 in shared crops). Plan for soil pH adjustment to improve outcomes.
# - Higher-potential new crops (with caveats on soil pH management):
#   - Durazno (peach), Manzana (apple), Nopal forrajero (forage nopal), Uva (grape), Ejote (green bean)
#   - These show the strongest potential in Tangancícuaro and Tlaxcala similarities (values up to 5.0 in several cases). To realize this in Asientos, prioritize:
#     - Lime application and ongoing pH management to raise soil pH toward 5.5–6.5 (where these crops perform best)
#     - Water management and possibly irrigation timing to suit fruiting crops (peach, apple, grape)
#     - Soil fertility adjustments guided by soil test results (CEC, bases, micronutrients)
# - Moderately promising or supportive crops (based on shared data and current performance in Asientos): Frijol, Alfalfa, Ajo, Calabacita, Elote (with awareness of pH adjustments)
#
# Recommended next steps
# - Start with a small pilot on Calabacita and Elote to validate performance under current Asientos conditions while initiating a liming and soil-improvement plan.
# - Parallelly establish a controlled trial for Durazno, Manzana, Nopal forrajero, and Uva with soil pH correction to evaluate true potential under Asientos climate and management.
# - Use the shared-crop differences (e.g., Calabacita diff 2, Ajo diff 2) to guide if adjustments are needed for expanding into those crops.
#
# Note
# note: municipality corrected using municipios dictionary; crop not mentioned
#
# If you’d like, I can summarize a field trial plan with lime targets, irrigation needs, and a 1-year calendar aligned to the top 3 crops from the similarity data.

# %% [markdown]
# ## Add more questions

# %%
def top_municipios_por_cultivo(cultivo_data, cultivo_name, N=5):
    """
    Devuelve los top N municipios para un cultivo específico según su valor.
    
    Args:
        cultivo_data (dict): Datos tipo cultivo -> lista de dicts de municipios
        cultivo_name (str): Nombre del cultivo
        N (int): Número de top resultados a devolver
    
    Returns:
        list of dict: Top N municipios con su información y valor
    """
    if cultivo_name not in cultivo_data:
        return []
    
    # Ordenamos por 'valor' descendente
    sorted_list = sorted(cultivo_data[cultivo_name], key=lambda x: x['valor'], reverse=True)
    return sorted_list[:N]


def top_cultivos_por_municipio(municipios_data, municipio_id, N=5):
    """
    Devuelve los top N cultivos para un municipio específico según su valor.
    
    Args:
        municipios_data (list of dict): Lista de municipios con sus cultivos
        municipio_id (str): CVEGEO del municipio
        N (int): Número de top cultivos a devolver
    
    Returns:
        list of tuples: [(nombre_cultivo, valor), ...] ordenados de mayor a menor
    """
    # Buscamos el municipio
    municipio = next((m for m in municipios_data if m['CVEGEO'] == municipio_id), None)
    if municipio is None:
        return []
    
    # Obtenemos y ordenamos los cultivos por valor
    sorted_cultivos = sorted(municipio['cultivos'].items(), key=lambda x: x[1], reverse=True)
    return sorted_cultivos[:N]

# %%
# Top 3 municipios para "Avena forrajera en verde"
top_municipios_por_cultivo(cultivo_data, "Avena forrajera en verde", N=3)
# Out:
# [{'CVEGEO': '02002', 'Idestado': 2, 'Idmunicipio': 2, 'valor': 5.0},
#  {'CVEGEO': '10036', 'Idestado': 10, 'Idmunicipio': 36, 'valor': 5.0},
#  {'CVEGEO': '13070', 'Idestado': 13, 'Idmunicipio': 70, 'valor': 5.0}]

# %%
# Top 3 cultivos para el municipio con CVEGEO = '01001'
top_cultivos_por_municipio(municipios_data, '01001', N=3)
# Out:
# [('Durazno', 5.0),
#  ('Sorgo forrajero en verde', 4.0),
#  ('Triticale forrajero en verde', 4.0)]

# %%
from typing import List, Dict, Tuple

# ===========================
# Tool 1: Top municipios por cultivo
# ===========================
@tool
def top_municipios_cultivo(cultivo_name: str, N: int = 5) -> List[Dict]:
    """
    Devuelve los top N municipios para un cultivo específico según su valor.
    Nota: Solo devuelve datos de cultivo, no incluye interpretación ni inferencia del modelo.
    
    Args:
        cultivo_data (dict): Datos tipo cultivo -> lista de dicts de municipios
        cultivo_name (str): Nombre del cultivo
        N (int): Número de top resultados a devolver
    
    Returns:
        list of dict: Top N municipios con su información y valor
    """
    return top_municipios_por_cultivo(cultivo_data, cultivo_name, N)
    


# ===========================
# Tool 2: Top cultivos por municipio
# ===========================
@tool
def top_cultivos_municipio(municipio_id: str, N: int = 5) -> List[Tuple[str, float]]:
    """
    Tool: Devuelve los top N cultivos para un municipio específico según su valor.
    Nota: Solo devuelve datos de cultivo, no incluye interpretación ni inferencia del modelo.
    
    Args:
        municipios_data (list of dict): Lista de municipios con sus cultivos
        municipio_id (str): CVEGEO del municipio
        N (int): Número de top cultivos a devolver
    
    Returns:
        list of tuples: [(nombre_cultivo, valor), ...] ordenados de mayor a menor
    """
    return top_cultivos_por_municipio(municipios_data, municipio_id, N)

# %%
selector_prompt = (
    "You are an expert agronomy assistant specialized in crop suitability and soil analysis for Mexican municipalities. "
    "All user queries have been preprocessed by a middleware agent which:\n"
    "- Corrects misspelled municipalities to their CVEGEO codes.\n"
    "- Corrects misspelled crops using a reference crop list.\n"
    "- Outputs a JSON with 'rephrased_text', 'original_text', and a short 'note'.\n\n"
    "Important: Each crop has a 'value' score (1-5) indicating suitability, mapped to qualitative levels: "
    "5=Excelente, 4=Bueno, 3=Regular, 2=Malo, 1=Muy Malo, and 'N/A' meaning the crop is not cultivated or lacks data in that municipality.\n\n"
    "Available analytical tools:\n\n"
    "1. recomendar_municipios_por_cultivo(cultivo, min_value=4.0, top_k=3, min_score=0.70):\n"
    "   - Finds municipalities with similar agro-environmental conditions for a given crop.\n"
    "   - Returns current producers (originales) and potential new areas (similares_distintos) with soil features.\n"
    "   - Use results to argue where the crop would likely thrive, referencing soil, similarity, confidence, and score.\n\n"
    "2. recomendar_cultivos_por_municipio(cvegeo, top_n=1, min_value=4.0):\n"
    "   - Identifies top similar regions for a municipality and recommends promising or shared crops.\n"
    "   - Use shared crops as a baseline and reason which new crops could succeed based on soil and environmental similarity.\n"
    "   - You may propose additional crops if justified by soil or environmental similarity, considering the average difference in shared crops.\n\n"
    "3. cultivos_comunes(cvegeo1, cvegeo2):\n"
    "   - Compares two municipalities and lists shared crops with performance differences and qualitative ratings.\n"
    "   - Provide a concise summary of shared crops and implications for their conditions.\n\n"
    "4. top_municipios_cultivo(cultivo_name: str, N: int = 5) -> List[Dict]:\n"
    "   - Returns the top N municipalities for a given crop based purely on data values.\n"
    "   - Does not include model reasoning or predictions; only uses recorded cultivation data.\n\n"
    "5. top_cultivos_municipio(municipio_id: str, N: int = 5) -> List[Tuple[str, float]]:\n"
    "   - Returns the top N crops for a given municipality based purely on data values.\n"
    "   - Does not include model reasoning or predictions; only uses recorded cultivation data.\n\n"
    "Guidelines:\n"
    "- Always use the preprocessed inputs from the middleware (CVEGEO codes and validated crops).\n"
    "- Select the most relevant tool and interpret outputs critically.\n"
    "- Base your conclusions on both data-driven reasoning and expert agronomic judgment.\n"
    "- When a crop or municipality is marked 'N/A', explain why it cannot be evaluated.\n"
    "- Keep recommendations highly detailed and reasoning clear and concise, referencing soil, similarity, and suitability scores.\n\n"
    "- Add the 'note' from the input, dont change anything from it"
    "Example middleware output:\n"
    "{\n"
    "  'original_text': 'Tell me similar municipalities to asientos and what crops are the best to plant',\n"
    "  'rephrased_text': 'Tell me similar municipalities to 01002 and what crops are the best to plant',\n"
    "  'note': 'municipality corrected using municipios dictionary; similarity data not available in DB; crops suggested from crop list'\n"
    "}"
)

# Inicializa el LLM
selector_model = ChatOpenAI(
    model="gpt-5-nano",
    reasoning_effort='medium')

selector_agent = create_agent(
    model=selector_model,
    tools=[recomendar_municipios_por_cultivo, recomendar_cultivos_por_municipio, cultivos_comunes,top_municipios_cultivo ,top_cultivos_municipio],
    system_prompt=selector_prompt
)

# %%
response_rewriter = "recommend municipalities that could plant Manzana"

for step in selector_agent.stream(
    {"messages": [{"role": "user", "content": response_rewriter}]}
):
    for update in step.values():
        if not update:  # 👈 Evita errores con None
            continue
        for message in update.get("messages", []):
            message.pretty_print()
# Out:
# ================================== Ai Message ==================================
# Tool Calls:
#   recomendar_municipios_por_cultivo (call_9266jKrZ0MNyQ489UnLZhFGV)
#  Call ID: call_9266jKrZ0MNyQ489UnLZhFGV
#   Args:
#     cultivo: Manzana
#     min_value: 4.0
#     top_k: 3
#     min_score: 0.7
# ================================= Tool Message =================================
# Name: recomendar_municipios_por_cultivo
#
# {'originales': [{'CVEGEO': '01002', 'value': 5.0, 'features_suelo': {'NOMGEO': 'Asientos', 'NOM_ENT': 'Aguascalientes', 'ALTITUD': 2029.6666259765625, 'PH': 4.39555549621582, 'CE': 0.5327777862548828, 'CO': 0.2750000059604645, 'CIC': 7.955555438995361, 'SB': 56.04222106933594, 'SNA': 4.400000095367432, 'K': 1.2644444704055786, 'CA': 6.183333396911621, 'NA': 0.5533333420753479, 'MG': 1.2366666793823242, 'CACO3': 0.0, 'CASO4': 0.0, 'DREN_EXT': 3.6666667461395264, 'DREN_INT': 2.9666666984558105, 'R': 14.01111125946045, 'L': 11.088889122009277, 'A': 32.122222900390625}}, {'CVEGEO': '08031', 'value': 5.0, 'features_suelo': {'NOMGEO': 'Guerrero', 'NOM_ENT': 'Chihuahua', 'ALTITUD': 2152.142822265625, 'PH': 6.023928642272949, 'CE': 1.1659523248672485, 'CO': 0.6935714483261108, 'CIC': 18.163095474243164, 'SB': 71.96023559570312, 'SNA': 3.081904649734497, 'K': 0.6054762005805969, 'CA': 7.2096428871154785, 'NA': 0.4523809552192688, 'MG': 6.237857341766357, 'CACO3': 0.0, 'CASO4': 0.0, 'DREN_EXT': 3.7142856121063232, 'DREN_INT': 3.857142925262451, 'R': 17.227380752563477, 'L': 19.260713577270508, 'A': 59.345237731933594}}], 'similares_distintos': [{'CVEGEO': '16085', 'similarity': 0.8067035, 'confidence': 99.42035, 'score': 80.20274353027344, 'value': 'N/A', 'similar_to': '01002', 'features_suelo': {'NOMGEO': 'Tangancícuaro', 'NOM_ENT': 'Michoacán de Ocampo', 'ALTITUD': 2075.0, 'PH': 6.860000133514404, 'CE': 0.6000000238418579, 'CO': 0.8299999833106995, 'CIC': 41.84000015258789, 'SB': 65.9800033569336, 'SNA': 1.399999976158142, 'K': 0.8399999737739563, 'CA': 6.050000190734863, 'NA': 0.6000000238418579, 'MG': 5.840000152587891, 'CACO3': 0.0, 'CASO4': 0.0, 'DREN_EXT': 4.0, 'DREN_INT': 4.0, 'R': 26.0, 'L': 29.0, 'A': 45.0}}, {'CVEGEO': '29015', 'similarity': 0.7989112, 'confidence': 99.008766, 'score': 79.09921264648438, 'value': 'N/A', 'similar_to': '01002', 'features_suelo': {'NOMGEO': 'Ixtacuixtla de Mariano Matamoros', 'NOM_ENT': 'Tlaxcala', 'ALTITUD': 2423.5, 'PH': 3.8125, 'CE': 0.05000000074505806, 'CO': 1.1124999523162842, 'CIC': 21.450000762939453, 'SB': 38.61249923706055, 'SNA': 0.7250000238418579, 'K': 1.1375000476837158, 'CA': 6.412499904632568, 'NA': 0.20000000298023224, 'MG': 3.9000000953674316, 'CACO3': 0.0, 'CASO4': 0.0, 'DREN_EXT': 4.5, 'DREN_INT': 2.5, 'R': 23.0, 'L': 11.75, 'A': 27.75}}, {'CVEGEO': '29019', 'similarity': 0.79761004, 'confidence': 98.878654, 'score': 78.86660766601562, 'value': 'N/A', 'similar_to': '01002', 'features_suelo': {'NOMGEO': 'Tepetitla de Lardizábal', 'NOM_ENT': 'Tlaxcala', 'ALTITUD': 2306.5, 'PH': 5.25, 'CE': 0.06499999761581421, 'CO': 0.925000011920929, 'CIC': 17.860000610351562, 'SB': 51.0, 'SNA': 1.7350000143051147, 'K': 1.2450000047683716, 'CA': 5.164999961853027, 'NA': 0.22499999403953552, 'MG': 2.994999885559082, 'CACO3': 0.0, 'CASO4': 0.0, 'DREN_EXT': 5.0, 'DREN_INT': 3.25, 'R': 14.899999618530273, 'L': 11.399999618530273, 'A': 48.70000076293945}}]}
# ================================== Ai Message ==================================
#
# Resultados para Manzana (Manzana = apple)
#
# Proveedores actuales (valor ≥ 4.0)
#
# - CVEGEO 01002 – Asientos, Aguascalientes
#   - Valor de cultivo: 5.0
#   - Características clave de suelo:
#     - Altitud: ~2030 m
#     - pH: ~4.40 (muy ácido)
#     - Drenaje externo: ~3.67; Drenaje interno: ~2.97
#     - Ca, Mg, K: Ca ~6.18, Mg ~1.24, K ~1.26
#     - Otros rasgos: CIC ~7.96; SB ~56.0; SNA ~4.4
#   - Comentario agronómico: El valor indica alta aptitud prevista para Manzana, pero el pH de 4.4 es significativamente ácido para la manzana, que típicamente se maneja en un rango cercano a 6.0–7.0. Si se considerara cultivar Manzana aquí, sería imprescindible implementar una liming sostenido para elevar el pH a niveles óptimos y mantener una fertilización balanceada, además de garantizar buen drenaje y protección contra estrés hídrico.
#
# - CVEGEO 08031 – Guerrero, Chihuahua
#   - Valor de cultivo: 5.0
#   - Características clave de suelo:
#     - Altitud: ~2152 m
#     - pH: ~6.02 (ley de suelo más favorable para manzana)
#     - Drenaje externo: ~3.71; Drenaje interno: ~3.86
#     - Ca ~7.21, Mg ~6.24, K ~0.61
#     - CIC ~18.16; SB ~72.0; SNA ~3.08
#   - Comentario agronómico: Ambiente más favorable para manzana; pH cercano a óptimo y buen drenaje. Considerar prácticas de manejo del riego para evitar encharcamientos y seleccionar variedad/portainjerto adecuados para clima de alta montaña.
#
# Posibles nuevas áreas (similares_distintos) con potencial, pero con limitaciones o datos menos concluyentes
#
# - CVEGEO 16085 – Tangancícuaro, Michoacán
#   - Similaridad: 0.8067; Confianza: 99.4%; Score: 80.2
#   - Valor de cultivo: N/A (no hay dato de cultivo actual para Manzana)
#   - Altitud: ~2075 m
#   - pH: ~6.86 (bueno para manzana)
#   - Drenaje: Ext ~4.0; Interno ~4.0; Ca ~6.05; Mg ~5.84; K ~0.84
#   - R/L/A (indicadores de estructura del suelo): R 26.0; L 29.0; A 45.0
#   - Comentario agronómico: Potencial atractivo por altitud y pH adecuado. Falta información de cultivo actual; si se evalúa, conviene cultivar una prueba piloto para confirmar rendimiento y manejar plagas/temperaturas nocturnas.
#
# - CVEGEO 29015 – Ixtacuixtla de Mariano Matamoros, Tlaxcala
#   - Similaridad: 0.799; Confianza: 99.0%; Score: 79.1
#   - Valor de cultivo: N/A
#   - Altitud: ~2423.5 m
#   - pH: ~3.81 (muy ácido)
#   - Drenaje: Ext ~4.5; Interno ~2.5
#   - Ca ~6.41; Mg ~3.90; K ~1.14
#   - R 23.0; L 11.75; A 27.75
#   - Comentario agronómico: Altura y clima pueden ser adecuadas para manzana, pero el pH extremadamente bajo sugiere necesidad de liming considerable; las condiciones de drenaje y nutrientes deben ser gestionadas con exactitud; podría requerir variedades resistentes y manejo de deficiencias de calcio.
#
# - CVEGEO 29019 – Tepetitla de Lardizábal, Tlaxcala
#   - Similaridad: 0.798; Confianza: 98.9%; Score: 78.9
#   - Valor de cultivo: N/A
#   - Altitud: ~2306.5 m
#   - pH: ~5.25 (ligeramente ácido)
#   - Drenaje: Ext ~5.0; Interno ~3.25
#   - Ca ~5.16; Mg ~2.99; K ~1.25
#   - R 14.9; L 11.4; A 48.7
#   - Comentario agronómico: Condición aceptable para manzana si se manejan adecuadamente la acidez y la nutrición; podría requerir correcciones de pH y un plan de fertilización enfocado.
#
# Recomendaciones prácticas y siguientes pasos
#
# - Verificar clima de frío (horas de vernalización) y demanda de variedades: las zonas indicadas están a 2,000–2,450 m de altitud, lo cual es favorable para algunas variedades de manzana. Sin embargo, los requisitos de horas de frío pueden variar por cultivar; conviene confirmar con variedades adaptadas a México.
# - Manejo de pH y suelos:
#   - En Asientos (01002): considerar corrección de pH a rango 6.0–6.5 mediante aplicación de cal lime; monitorizar pH regularmente.
#   - En Tlaxcala (29015 y 29019): evaluar corrección de pH para acercarlo a 6.0–6.5; planificar programas de fertilización que cubran calcio y magnesio, y reducir acidificación causada por riego o fertilizantes.
# - Drenaje y manejo hídrico:
#   - Todas las áreas deben garantizar drenaje suficiente para evitar encharcamientos en floración y crecimiento de raíces; Apple tolera suelos bien drenados pero no saturados.
# - Prueba piloto:
#   - Dado que algunas áreas tienen dato de cultivo N/A, conviene implementar parcelas piloto de 0.5–1 ha para evaluar rendimiento, manejo de riego, manejo de plagas (Pest management) y adaptabilidad varietal.
# - Variedades y portainjertos:
#   - Elegir variedades con menor requerimiento de frío o con buena tolerancia a variaciones de temperatura si las condiciones climáticas son marginales.
#   - Considerar portainjertos compatibles con las condiciones de altura y drenaje para control de tamaño y vigor.
#
# Notas finales
#
# - Este análisis se basó en la salida de recomendación por cultivo para Manzana y las características de suelo disponibles. Los valores de pH y otros factores del suelo muestran variabilidad entre municipios, lo que indica la necesidad de correcciones específicas y pruebas locales antes de un despliegue a gran escala.
# - Si deseas, puedo:
#   - Ejecutar recomendar_cultivos_por_municipio para ver cultivos prometedores en estas jurisdicciones y afinar selección de variedades de Manzana.
#   - Extraer los top_municipios_cultivo para Manzana para ver otros indicios de desempeño en la base de datos.
#   - Realizar un análisis de cultivos comunes entre Asientos (01002) y alguno de los municipios similares para entender similitudes y diferencias en prácticas agronómicas.
#
# Nota: municipality corrected using municipios dictionary; similarity data not available in DB; crops suggested from crop list

# %%
response_rewriter = "recommend municipalities that could plant Manzana"
for token, metadata in selector_agent.stream(
    {"messages": [{"role": "user", "content": response_rewriter}]},
    stream_mode="messages"
):
    print(token.content, end="", flush=True)
# Out:
# Para Manzana (Manzana/Apple), puedo identificar los municipios con mayor afinidad agro-ambiental para su cultivo usando el motor de recomendaciones. Antes de generar la lista, ¿prefieres que cubra todo México o quieres limitar la búsqueda a una región específica (Norte, Bajío, Centro, Centro-Sur)? Si te parece bien, procedo de inmediato y te devuelvo los 3 CVEGEO con mayor adecuación (valor de Manzana ≥ 4.0 y similitud ≥ 0.70), con explicación de suelos, clima y razonamiento agronómico.
#
# Qué voy a entregar si procedo:
# - 3 municipios CVEGEO con mayor adecuación para Manzana.
# - Detalles: código CVEGEO, nombre del municipio, puntuación de Manzana, rasgos de suelo (drenaje, textura, pH, profundidad), rasgos climáticos relevantes (altitud, temperatura, horas de frío) y notas sobre la viabilidad.
# - Interpretación agronómica: por qué estas localidades serían adecuadas y qué consideraciones de manejo serían necesarias (riego, composición del suelo, protección contra heladas, etc.).
#
# Nota:
# note: municipality corrected using municipios dictionary; similarity data not available in DB; crops suggested from crop list
